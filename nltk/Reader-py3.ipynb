# %%
from nltk.corpus.reader import CategorizedPlaintextCorpusReader
reader = CategorizedPlaintextCorpusReader('/media/storage/dpla-data/new/words-6mill/colls/', r'.*\.txt', cat_pattern=r'(\w+)\.txt')

# %%
reader.categories('gpo.txt')
# Out:
# ['gpo']

# %%
gpowords = reader.words('gpo.txt')

# %%
len(gpowords)
# Out:
# 36646650

# %%
len(set([w.lower() for w in reader.words('gpo.txt')]))
# Out:
# 438479

# %%
import nltk

# %%
cfd = nltk.ConditionalFreqDist(
(genre, word)
for genre in ['gpo', 'artstor']
for word in reader.words(categories=genre))

# %%
cfd.most_common()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-776394e71d50> in <module>()
# ----> 1 cfd.most_common()
#
# AttributeError: 'ConditionalFreqDist' object has no attribute 'most_common'

# %%
fd = nltk.FreqDist((word) for word in reader.words(categories='gpo'))
fd.most_common()
#fd[1]
# Out:
# [('.', 3122674),
#  (',', 1113110),
#  ('(', 1067928),
#  ('States', 888065),
#  ('United', 882808),
#  (')', 805445),
#  ('-', 778433),
#  ('/', 710909),
#  ('--', 640561),
#  (':', 602168),
#  ('the', 581666),
#  ('of', 548544),
#  ('Government', 495055),
#  ('and', 494978),
#  ('to', 397737),
#  ('Office', 385767),
#  ('is', 331992),
#  ('GPO', 315710),
#  ('Printing', 308305),
#  ('Title', 242012),
#  ('in', 235924),
#  ('on', 234539),
#  ('online', 230512),
#  ('OCoLC', 225591),
#  ('S', 210783),
#  ('[', 201524),
#  ('://', 198788),
#  ('http', 198571),
#  ('gov', 198239),
#  ('1', 193344),
#  ('U', 189485),
#  ('gpo', 176334),
#  ('For', 164467),
#  ('17', 162480),
#  ('from', 162264),
#  ('www', 162160),
#  ('resource', 159657),
#  ('information', 157736),
#  ('index', 156813),
#  ('public', 154089),
#  ('file', 153361),
#  ('text', 153094),
#  ('Code', 151913),
#  ('html', 151870),
#  ('protection', 151380),
#  ('not', 151255),
#  ('domain', 151073),
#  ('htm', 150826),
#  ('105', 150432),
#  ('this', 149776),
#  ('more', 149761),
#  ('help', 149601),
#  ('Section', 149583),
#  ('#', 149562),
#  ('subject', 149085),
#  ('copyright', 148822),
#  ('Document', 148712),
#  ('see', 148651),
#  ('Pursuant', 148634),
#  ('please', 148608),
#  ('public_domain_copyright_notice', 148603),
#  ('English', 148281),
#  ('material', 145577),
#  (').', 145035),
#  ('Language', 138861),
#  ('C', 136053),
#  ('D', 134111),
#  ('Washington', 131028),
#  ('p', 128994),
#  ('title', 126506),
#  (']', 125060),
#  ('Book', 123497),
#  ('viewed', 101132),
#  ('P', 99746),
#  ('screen', 94881),
#  ('available', 94312),
#  ('for', 91576),
#  ('Electronic', 91166),
#  ('National', 88050),
#  ('2', 84945),
#  ('Committee', 84085),
#  ('via', 79787),
#  ('Congress', 77889),
#  ('version', 73098),
#  ('G', 72414),
#  ('Includes', 70584),
#  ('access', 69398),
#  ('A', 67476),
#  ('references', 63375),
#  ('bibliographical', 63088),
#  (';', 61589),
#  ('.)', 60341),
#  ('O', 58562),
#  ('4', 58340),
#  ('=', 56612),
#  ('no', 55169),
#  ('cgi', 54660),
#  ('House', 51423),
#  ('as', 51007),
#  ('.]', 48508),
#  (':.', 47074),
#  ('.,', 46414),
#  ('Dept', 46352),
#  ('B', 46286),
#  ('by', 45586),
#  ('3', 44777),
#  ('Administration', 42763),
#  ('Internet', 42555),
#  ('Y', 42551),
#  ('site', 41672),
#  ('current', 40961),
#  ('2008', 39681),
#  ('2009', 39083),
#  ('Also', 39040),
#  ('web', 39025),
#  ('2010', 37416),
#  ('Service', 36508),
#  ('&', 36081),
#  ('Subcommittee', 34755),
#  ('2011', 34652),
#  ('5', 34230),
#  ('2007', 34156),
#  ('number', 34021),
#  ('list', 34017),
#  ('8', 33861),
#  ('Periodicals', 33731),
#  ('pdf', 33585),
#  ('.:', 33548),
#  ('01', 33454),
#  ('?', 32932),
#  ('Shipping', 32928),
#  ('H', 32830),
#  ('report', 32775),
#  ('2012', 32677),
#  ('%', 31954),
#  ('Address', 31739),
#  ('2006', 31632),
#  ('PURL', 31484),
#  ('LC', 31286),
#  ('call', 30923),
#  ('Print', 30892),
#  ('Research', 30773),
#  ('13', 30516),
#  ('7', 29346),
#  ('v', 29194),
#  ('2003', 28439),
#  ('Health', 28412),
#  ('Senate', 28350),
#  ('PDF', 28119),
#  ('Serial', 27851),
#  ("'", 27717),
#  ('10', 27551),
#  ('bin', 27422),
#  ('2004', 27372),
#  ('frwebgate', 27199),
#  ('Department', 27161),
#  ('Law', 26860),
#  ('2005', 26711),
#  ('a', 26534),
#  ('f', 26373),
#  ('microfiche', 26293),
#  ('docid', 26242),
#  ('getdoc', 26239),
#  ('dbname', 26237),
#  ('2001', 25637),
#  ('DLC', 25505),
#  ('MF', 25429),
#  ('N', 25073),
#  ('19', 25014),
#  ('Statistics', 24986),
#  ('R', 24871),
#  ('Act', 24498),
#  ('2013', 24269),
#  ('with', 24150),
#  ('2002', 24141),
#  ('1008', 24092),
#  ('Federal', 23938),
#  ('Supt', 23765),
#  ('Docs', 23732),
#  ('I', 23391),
#  ('Security', 23271),
#  ('2000', 23201),
#  ('GAO', 23013),
#  ('legislation', 22894),
#  ('Services', 22651),
#  ('11', 22521),
#  ('Microfiche', 22504),
#  ('June', 22358),
#  ('July', 22286),
#  ('6', 22196),
#  ('20', 22159),
#  ('Survey', 22029),
#  ('Energy', 21992),
#  ('General', 21782),
#  ('iii', 21624),
#  ('9', 21566),
#  ('before', 21524),
#  ('12', 21167),
#  ('libraries', 20684),
#  ('May', 20552),
#  ('cat', 20396),
#  ('depository', 20358),
#  ('hearing', 20165),
#  ('Environmental', 20132),
#  ('E', 19959),
#  ('Center', 19910),
#  ('session', 19826),
#  ('M', 19583),
#  ('sale', 19556),
#  ('Access', 19265),
#  ('02', 19095),
#  ('s', 19089),
#  ('One', 18883),
#  ('Affairs', 18777),
#  ('Hundred', 18635),
#  ('computer', 18235),
#  ('Maps', 18225),
#  ('Management', 18215),
#  ('Transportation', 18198),
#  ('15', 18172),
#  ('ISBN', 18156),
#  ('Distributed', 17766),
#  ('Geological', 17407),
#  ('policy', 17293),
#  ('DC', 17291),
#  ('Accountability', 17196),
#  ('14', 17169),
#  ('Space', 16872),
#  ('2014', 16871),
#  ('Commerce', 16793),
#  ('W', 16720),
#  ('"--', 16480),
#  ('The', 16444),
#  ('22', 16426),
#  ('110', 16425),
#  ('03', 16159),
#  ('based', 16099),
#  ('some', 15845),
#  ('Accounting', 15806),
#  ('Forest', 15626),
#  ('°', 15586),
#  ('04', 15408),
#  ('Representatives', 15359),
#  ('16', 15009),
#  ('J', 14763),
#  ('Description', 14727),
#  ('109', 14702),
#  ('GA', 14612),
#  ('Foreign', 14586),
#  ('21', 14580),
#  ('Paper', 14546),
#  ('),', 14508),
#  ('County', 14427),
#  ('issue', 14314),
#  ('0546', 14191),
#  ('Public', 14180),
#  ('Agency', 14105),
#  ('September', 14064),
#  ('Information', 13992),
#  ('F', 13852),
#  ('1999', 13850),
#  ('24', 13721),
#  ('26', 13709),
#  (')--', 13485),
#  ('author', 13399),
#  ('pages', 13391),
#  ('Interior', 13343),
#  ('T', 13320),
#  ('Aeronautics', 13281),
#  ('at', 13232),
#  ('aspects', 13216),
#  ('Va', 13166),
#  ('Education', 13071),
#  ('Prevention', 12998),
#  ('New', 12986),
#  ('Bureau', 12915),
#  ('18', 12907),
#  ('management', 12893),
#  ('State', 12792),
#  ('International', 12717),
#  ('Water', 12691),
#  ('Congressional', 12579),
#  ('March', 12551),
#  ('25', 12539),
#  ('Evaluation', 12531),
#  ('Agriculture', 12518),
#  ('River', 12505),
#  ('image', 12370),
#  ('27', 12270),
#  ('05', 12207),
#  ('Protection', 12148),
#  ('30', 12143),
#  ('L', 12072),
#  ('first', 11962),
#  ('Safety', 11920),
#  ('06', 11912),
#  (');', 11878),
#  ('28', 11808),
#  ('security', 11645),
#  ('23', 11592),
#  ('Economic', 11583),
#  ('108', 11580),
#  ('29', 11577),
#  ('.)--', 11542),
#  ('Science', 11501),
#  ('07', 11333),
#  ('1998', 11306),
#  ('etc', 11279),
#  ('Commission', 11196),
#  ('Program', 11144),
#  ('Resources', 11135),
#  ('Institute', 11134),
#  ('April', 11080),
#  ('Finance', 10895),
#  ('Appropriations', 10826),
#  ('North', 10804),
#  ('Homeland', 10740),
#  ('31', 10655),
#  ('industry', 10619),
#  ('Annual', 10499),
#  ('Jan', 10414),
#  ('1997', 10312),
#  ('Nuclear', 10309),
#  ('Aug', 10304),
#  ('Defense', 10245),
#  ('Human', 10183),
#  ('Mar', 10177),
#  ('map', 10159),
#  ('Oct', 10071),
#  ('Technology', 9915),
#  ('consulted', 9868),
#  ('08', 9816),
#  ('([', 9777),
#  ('0830', 9738),
#  ('Sept', 9721),
#  ('Air', 9690),
#  ('KF27', 9685),
#  ('California', 9650),
#  ('body', 9614),
#  ('Veterans', 9438),
#  ('Apr', 9269),
#  ('Latest', 9252),
#  ('Dec', 9225),
#  ('Reston', 9187),
#  ('Addresses', 9109),
#  ('Coast', 9080),
#  ('107', 9078),
#  ('...', 9038),
#  ('Nov', 8982),
#  ('Feb', 8982),
#  ('Wildlife', 8940),
#  ('America', 8913),
#  ('Natural', 8896),
#  ('1996', 8841),
#  ('October', 8829),
#  ('second', 8687),
#  ('water', 8671),
#  ('American', 8588),
#  ('HE', 8498),
#  ('PURLs', 8486),
#  ('Military', 8451),
#  ('data', 8442),
#  ('Alaska', 8401),
#  ('Rules', 8396),
#  ('Justice', 8347),
#  ('nasa', 8341),
#  ('use', 8340),
#  ('iv', 8319),
#  ('Iowa', 8284),
#  ('Oversight', 8274),
#  ('February', 8220),
#  ('̲', 8203),
#  ('Md', 8155),
#  ('government', 8102),
#  ('issuing', 8093),
#  ('measures', 8084),
#  ('August', 8064),
#  ('relations', 8058),
#  ('Development', 8010),
#  ('Pacific', 8000),
#  ('expenditures', 7929),
#  ('distributor', 7883),
#  ('accompany', 7827),
#  ('Army', 7823),
#  ('Caption', 7730),
#  ('1995', 7695),
#  ('No', 7691),
#  ('Division', 7686),
#  ('Labor', 7644),
#  ('Budget', 7634),
#  ('December', 7586),
#  ('Laboratory', 7545),
#  ('00', 7527),
#  ('111', 7505),
#  ('Financial', 7504),
#  ('112', 7498),
#  ('year', 7497),
#  ('Mexico', 7462),
#  ('St', 7361),
#  ('Armed', 7302),
#  ('January', 7251),
#  ('control', 7226),
#  ('Ocean', 7221),
#  ('Microform', 7197),
#  ('November', 7184),
#  ('systems', 7121),
#  ('Online', 7116),
#  ('University', 7110),
#  ('Census', 7084),
#  ('?]', 7059),
#  ('Scale', 7046),
#  ('health', 7016),
#  ('Judiciary', 6990),
#  ('76', 6935),
#  ('NAS', 6935),
#  ('000', 6886),
#  ('0624', 6866),
#  ('HRG', 6835),
#  ('de', 6788),
#  ('Aviation', 6755),
#  ('Social', 6699),
#  ('1990', 6695),
#  ('care', 6678),
#  ('Reform', 6646),
#  ('Cover', 6569),
#  ('Govt', 6549),
#  ('Cartographic', 6530),
#  ('Internal', 6509),
#  ('manuals', 6490),
#  ('NW', 6467),
#  ('Drug', 6413),
#  ('42', 6388),
#  ('Small', 6382),
#  ('Handbooks', 6367),
#  ('Revenue', 6360),
#  ('1994', 6315),
#  ('negative', 6307),
#  ('441', 6260),
#  ('quality', 6251),
#  ('0431', 6239),
#  ('LM', 6230),
#  ('resources', 6224),
#  ('106', 6218),
#  ('Relations', 6216),
#  ('20548', 6192),
#  ('practice', 6169),
#  ('Rm', 6169),
#  ('be', 6140),
#  ('Medical', 6092),
#  ('shown', 6075),
#  ('Technical', 6072),
#  ('99', 6054),
#  ('EPA', 6047),
#  ('09', 6040),
#  ('55', 6031),
#  ('Park', 6017),
#  ('Region', 6009),
#  ('Business', 5977),
#  ('Housing', 5955),
#  ('49', 5911),
#  ('also', 5897),
#  ('Gulf', 5885),
#  ('programs', 5831),
#  ('federal', 5807),
#  ('ed', 5765),
#  ('tax', 5750),
#  ('Recovery', 5744),
#  ('electronic', 5701),
#  ('].', 5696),
#  ('Began', 5694),
#  ('5Fcong', 5685),
#  ('1993', 5665),
#  ('"', 5599),
#  ('Standards', 5599),
#  ('Florida', 5546),
#  ('has', 5536),
#  ('NASA', 5518),
#  ('Report', 5500),
#  ('MD', 5493),
#  ('Emergency', 5465),
#  ('program', 5442),
#  ('development', 5437),
#  ('ii', 5349),
#  ('President', 5345),
#  ('War', 5320),
#  ('distributed', 5294),
#  ('power', 5291),
#  ('issues', 5282),
#  ('page', 5279),
#  ('Iraq', 5245),
#  ('print', 5233),
#  ('trade', 5195),
#  ('TD', 5191),
#  ('an', 5179),
#  ('EP', 5174),
#  ('China', 5172),
#  ('KF26', 5171),
#  ('5Fhearings', 5158),
#  ('Texas', 5135),
#  ('This', 5123),
#  ('fiscal', 5113),
#  ('services', 5111),
#  ('88', 5095),
#  ('Inspector', 5084),
#  ('cost', 5072),
#  ('41', 5067),
#  ('South', 5041),
#  ('system', 5010),
#  ('Board', 5010),
#  ('Marine', 4982),
#  ('ntrs', 4980),
#  ('1992', 4979),
#  ('Trade', 4968),
#  ('Bay', 4961),
#  ('Food', 4954),
#  ('98', 4940),
#  ('32', 4918),
#  ('Computer', 4892),
#  ('Watershed', 4863),
#  ('0575', 4823),
#  ('Relief', 4804),
#  ('York', 4785),
#  ('K', 4769),
#  ('Area', 4766),
#  ('under', 4747),
#  ('analysis', 4717),
#  ('Forces', 4704),
#  ('including', 4699),
#  ('Policy', 4676),
#  ('caption', 4673),
#  ('cover', 4663),
#  ('assistance', 4655),
#  ('Data', 4654),
#  ('Colorado', 4623),
#  ('Atmospheric', 4601),
#  ('Regulatory', 4600),
#  ('97', 4600),
#  ('vi', 4570),
#  ('Issued', 4569),
#  ('energy', 4567),
#  ('36', 4566),
#  ('Mercator', 4550),
#  ('other', 4546),
#  ('West', 4545),
#  ('44', 4543),
#  ('Publications', 4542),
#  ('Terrorism', 4521),
#  ('business', 4520),
#  ('73', 4498),
#  ('state', 4487),
#  ('Tax', 4475),
#  ('Planning', 4425),
#  ('74', 4410),
#  ('Consumer', 4383),
#  ('1934', 4376),
#  ('Spanish', 4338),
#  ('Agricultural', 4278),
#  ('Renewable', 4276),
#  ('insurance', 4274),
#  ('Refuge', 4271),
#  ('Works', 4254),
#  ('History', 4248),
#  ('Colo', 4239),
#  ('81', 4207),
#  ('113', 4201),
#  ('Taxation', 4195),
#  ('maps', 4182),
#  ('Station', 4176),
#  ('Virginia', 4167),
#  ('$', 4148),
#  ('.).', 4139),
#  ('Infrastructure', 4123),
#  ('safety', 4118),
#  ('Force', 4115),
#  ('series', 4103),
#  ('.),', 4102),
#  ('various', 4101),
#  ('Indian', 4099),
#  ('Ohio', 4085),
#  ('aid', 4081),
#  ('Governmental', 4076),
#  ('1991', 4065),
#  ('Civil', 4060),
#  ('VA', 4057),
#  ('education', 4055),
#  ('Atlantic', 4053),
#  ('employees', 4042),
#  ('issued', 4042),
#  ('Lake', 4039),
#  ('estimate', 4038),
#  ('sn', 4029),
#  ('assessment', 4028),
#  ('Available', 4027),
#  ('1016', 4019),
#  ('Libraries', 4015),
#  ('5Freports', 4008),
#  ('published', 3983),
#  ('law', 3972),
#  ('Oceanic', 3968),
#  ('96', 3959),
#  ('0996', 3955),
#  ('V', 3949),
#  ('Some', 3940),
#  ('<', 3916),
#  ('research', 3903),
#  ('pt', 3899),
#  ('cooperation', 3890),
#  ('Control', 3872),
#  ('census', 3869),
#  ('reports', 3855),
#  ('congressional', 3851),
#  ('agencies', 3824),
#  ('Oregon', 3813),
#  ('pagings', 3806),
#  ('status', 3803),
#  ('wais', 3800),
#  ('.--', 3793),
#  ('Land', 3784),
#  ('33', 3758),
#  ('Conservation', 3758),
#  ('1017', 3757),
#  ('conservation', 3753),
#  ('products', 3747),
#  ('Urban', 3740),
#  ('competition', 3737),
#  ('101', 3734),
#  ('ED', 3726),
#  ('1989', 3714),
#  ('national', 3709),
#  ('Idaho', 3705),
#  ('Afghanistan', 3694),
#  ('Northwest', 3689),
#  ('District', 3678),
#  ('survey', 3677),
#  ('Quality', 3675),
#  ('Congresses', 3674),
#  ('publication', 3672),
#  ('technology', 3634),
#  ('In', 3619),
#  ('38', 3617),
#  ('plan', 3617),
#  ('HTML', 3613),
#  ('Columbia', 3613),
#  ('KF32', 3608),
#  ('.?]', 3606),
#  ('Posters', 3599),
#  ('89', 3586),
#  ('35', 3574),
#  ('item', 3568),
#  ('Employment', 3567),
#  ('guide', 3555),
#  ('Tenth', 3555),
#  ('43', 3552),
#  ('At', 3543),
#  ('An', 3523),
#  ('head', 3515),
#  ('code', 3494),
#  ('34', 3493),
#  ('proj', 3486),
#  ('djk', 3483),
#  ('gas', 3481),
#  ('fair', 3481),
#  ('location', 3477),
#  ('CD', 3474),
#  ('laws', 3471),
#  ('pubs', 3469),
#  ('Final', 3448),
#  ('Fish', 3443),
#  ('USGS', 3434),
#  ('95', 3423),
#  ('San', 3422),
#  ('AE', 3411),
#  ('64', 3410),
#  ('Bibliography', 3406),
#  ('or', 3389),
#  ('rev', 3387),
#  ('City', 3368),
#  ('into', 3367),
#  ('Island', 3365),
#  ('economic', 3359),
#  ('CO', 3354),
#  ('Web', 3328),
#  ('Calif', 3326),
#  ('review', 3326),
#  ('models', 3313),
#  ('37', 3305),
#  ('Highway', 3296),
#  ('92', 3295),
#  ('53', 3279),
#  ('System', 3269),
#  ('Carolina', 3264),
#  ('Medicare', 3260),
#  ('Assessment', 3258),
#  ('collection', 3241),
#  ('are', 3222),
#  ('digital', 3221),
#  ('service', 3200),
#  ('that', 3196),
#  ('new', 3183),
#  ('Treasury', 3182),
#  ('0083', 3177),
#  ('40', 3170),
#  ('transverse', 3167),
#  ('ROM', 3166),
#  ('spot', 3165),
#  ('Intelligence', 3160),
#  ('contours', 3155),
#  ('Programs', 3150),
#  ('Officials', 3146),
#  ('107c', 3129),
#  ('through', 3121),
#  ('release', 3117),
#  ('ongṟeports', 3110),
#  ('plants', 3092),
#  ('heights', 3087),
#  ('Sales', 3072),
#  ('impact', 3071),
#  ('Eleventh', 3070),
#  ('statement', 3062),
#  ('ISSN', 3060),
#  ('between', 3048),
#  ('0619', 3045),
#  ('Joint', 3042),
#  ('50', 3041),
#  ('FAA', 3038),
#  ('Bethesda', 3035),
#  ('quadrangle', 3029),
#  ('0621', 3022),
#  ('Denver', 3017),
#  ('51', 3017),
#  ('Wisconsin', 3017),
#  ('Strategic', 3010),
#  ('Africa', 3007),
#  ('annual', 2989),
#  ('gao', 2989),
#  ('approved', 2988),
#  ('John', 2984),
#  ('Disease', 2976),
#  ('Stat', 2960),
#  ('Auditing', 2958),
#  ('Environment', 2953),
#  ('Library', 2951),
#  ('Nevada', 2938),
#  ('93', 2929),
#  ('56', 2927),
#  ('feet', 2917),
#  ('may', 2915),
#  ('microfiches', 2914),
#  ('94', 2907),
#  ('Twelfth', 2899),
#  ('68', 2897),
#  ('Administrative', 2895),
#  ('Central', 2892),
#  ('Community', 2879),
#  ('housing', 2864),
#  ('David', 2863),
#  ('46', 2851),
#  ('operations', 2850),
#  ('Means', 2848),
#  ('sheet', 2845),
#  ('i', 2841),
#  ('52', 2834),
#  ('Ninth', 2834),
#  ('Fisheries', 2812),
#  ('75', 2808),
#  ('Ways', 2808),
#  ('universal', 2799),
#  ('grl', 2780),
#  ('Pictorial', 2774),
#  ('Legal', 2769),
#  ('Corps', 2764),
#  ('performance', 2763),
#  ('related', 2748),
#  ('Islands', 2746),
#  ('Study', 2735),
#  ('Workforce', 2734),
#  ('budget', 2732),
#  ('Europe', 2727),
#  ('East', 2726),
#  ('Arizona', 2720),
#  ('0982', 2715),
#  ('39', 2705),
#  ('1020', 2705),
#  ('Box', 2701),
#  ('Irregular', 2701),
#  ('Commercial', 2693),
#  ('Institutes', 2691),
#  ('Utah', 2681),
#  ('Res', 2673),
#  ('Economics', 2671),
#  ('study', 2671),
#  ('48', 2663),
#  ('only', 2653),
#  ('area', 2647),
#  ('challenges', 2646),
#  ('construction', 2639),
#  ('practices', 2635),
#  ('Pollution', 2635),
#  ('coast', 2631),
#  ('5Fhouse', 2626),
#  ('usgs', 2624),
#  ('Documents', 2620),
#  ('without', 2619),
#  ('Fort', 2616),
#  ('Special', 2610),
#  ('consideration', 2610),
#  ('Analysis', 2609),
#  ('Studies', 2608),
#  ('archive', 2605),
#  ('Great', 2605),
#  ('College', 2593),
#  ('Hawaii', 2592),
#  ('children', 2591),
#  ('oversight', 2590),
#  ('flow', 2589),
#  ('Southern', 2586),
#  ('5Fsenate', 2583),
#  ('NREL', 2575),
#  ('Insurance', 2575),
#  ('format', 2565),
#  ('91', 2554),
#  ('conditions', 2543),
#  ('Photograph', 2543),
#  ('Superintendent', 2539),
#  ('Educational', 2534),
#  ('Global', 2518),
#  ('Corporation', 2507),
#  ('Pt', 2504),
#  ('Asia', 2502),
#  ('Pennsylvania', 2500),
#  ('0430', 2494),
#  ('provided', 2493),
#  ('casi', 2491),
#  ('entitled', 2491),
#  ('processing', 2490),
#  ('1986', 2487),
#  ('Children', 2482),
#  ('Middle', 2479),
#  ('Guard', 2476),
#  ('poster', 2472),
#  ('Valley', 2472),
#  ('Secretary', 2470),
#  ('60', 2456),
#  ('Louisiana', 2455),
#  ('Medicine', 2448),
#  ('63', 2442),
#  ('Child', 2440),
#  ('45', 2437),
#  ('Criminal', 2436),
#  ('World', 2434),
#  ('Investigations', 2433),
#  ('Prepared', 2431),
#  ('studies', 2430),
#  ('Vol', 2427),
#  ('collector', 2422),
#  ('posters', 2420),
#  ('final', 2419),
#  ('passed', 2417),
#  ('Rural', 2416),
#  ('environmental', 2413),
#  ('Golden', 2412),
#  ('Income', 2404),
#  ('Basin', 2404),
#  ('47', 2402),
#  ('Groundwater', 2399),
#  ('science', 2395),
#  ('Rockville', 2391),
#  ('adjoining', 2384),
#  ('Printed', 2383),
#  ('Cancer', 2382),
#  ('people', 2381),
#  ('Geology', 2380),
#  ('income', 2377),
#  ('Springfield', 2376),
#  ('contracts', 2368),
#  ('Navigation', 2364),
#  ('127', 2362),
#  ('Centers', 2360),
#  ('jln', 2359),
#  ('was', 2359),
#  ('bill', 2359),
#  ('0507', 2354),
#  ('quadrangles', 2351),
#  ('restriction', 2350),
#  ('1985', 2347),
#  ('copied', 2345),
#  ('429489521', 2342),
#  ('2011230198', 2342),
#  ('Massachusetts', 2325),
#  ('paper', 2319),
#  ('abuse', 2318),
#  ('Council', 2315),
#  ('Building', 2310),
#  ('purposes', 2310),
#  ('Maryland', 2310),
#  ('Flight', 2310),
#  ('Rights', 2308),
#  ('Diseases', 2304),
#  ('Robert', 2298),
#  ('Postal', 2295),
#  ('77', 2293),
#  ('Fiscal', 2293),
#  ('Publication', 2288),
#  ('Traffic', 2279),
#  ('Project', 2277),
#  ('been', 2273),
#  ('summary', 2271),
#  ('surveys', 2264),
#  ('Border', 2262),
#  ('Fire', 2257),
#  ('viii', 2251),
#  ('needed', 2247),
#  ('Sea', 2242),
#  ('Personnel', 2234),
#  ('countries', 2233),
#  ('century', 2233),
#  ('leaf', 2230),
#  ('es', 2229),
#  ('1037', 2225),
#  ('1988', 2224),
#  ('financial', 2217),
#  ('Tex', 2215),
#  ('1987', 2214),
#  ('IN', 2209),
#  ('57', 2208),
#  ('Russia', 2205),
#  ('Pensions', 2201),
#  ('FY', 2201),
#  ('prevention', 2195),
#  ('administration', 2193),
#  ('testimony', 2179),
#  ('requesters', 2176),
#  ('Executive', 2175),
#  ('024', 2172),
#  ('numbers', 2170),
#  ('held', 2166),
#  ('Providing', 2166),
#  ('Registry', 2162),
#  ('1042', 2150),
#  ('AP', 2147),
#  ('62', 2143),
#  ('minute', 2136),
#  ('NSIAD', 2134),
#  ('Banking', 2134),
#  ('Power', 2133),
#  ('Mississippi', 2127),
#  ('forms', 2113),
#  ('medical', 2112),
#  ('1019', 2112),
#  ('planning', 2111),
#  ('traffic', 2106),
#  ('Text', 2105),
#  ('vii', 2103),
#  ('form', 2102),
#  ('Or', 2098),
#  ('its', 2096),
#  ('waste', 2093),
#  ('evaluation', 2091),
#  ('views', 2085),
#  ('areas', 2085),
#  ('Amendment', 2081),
#  ('rights', 2077),
#  ('future', 2077),
#  ('Wyoming', 2075),
#  ('TF', 2069),
#  ('Eighth', 2062),
#  ('1028', 2059),
#  ('Electric', 2059),
#  ('effects', 2058),
#  ('1009', 2058),
#  ('58', 2053),
#  ('years', 2051),
#  ('about', 2050),
#  ('90', 2050),
#  ('William', 2049),
#  ('Nutrition', 2036),
#  ('1013', 2035),
#  ('Women', 2033),
#  ('Risk', 2033),
#  ('military', 2031),
#  ('82', 2028),
#  ('19uu', 2027),
#  ('library', 2022),
#  ('Training', 2019),
#  ('HS', 2018),
#  ('Gaithersburg', 2015),
#  ('transportation', 2009),
#  ('Post', 2005),
#  ('agreement', 2004),
#  ('together', 2004),
#  ('1st', 2002),
#  ('Set', 1999),
#  ('Investigation', 1998),
#  ('54', 1996),
#  ('Contour', 1988),
#  ('disabilities', 1982),
#  ('property', 1982),
#  ('innovations', 1978),
#  ('Procurement', 1978),
#  ('benefits', 1977),
#  ...]

# %%
#fd.most_common(10)
# %matplotlib inline
fd.plot(50)

# %%
# %matplotlib inline
fd.plot(50, cumulative=True)
