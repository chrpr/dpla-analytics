# %%
import pickle
import nltk

stats = pickle.load( open( "/media/storage/dpla-data/pickles/new/newstats.p", "rb" ) )
common = pickle.load( open( "/media/storage/dpla-data/pickles/new/common.p", "rb" ) )
searcom = pickle.load( open( "/media/storage/dpla-data/pickles/new/sear_common.p", "rb" ) )
searfilt = pickle.load(open( "/media/storage/dpla-data/pickles/new/searches_filtered.p", "rb" ) )

# %%
stats
# Out:
# {'artstor': {'funiq': 60168,
#   'fwc': 5025070,
#   'haps': 29757,
#   'lowerhaps': 24103,
#   'uniq': 60293,
#   'wc': 6972534},
#  'biodiv': {'funiq': 94248,
#   'fwc': 5658739,
#   'haps': 44804,
#   'lowerhaps': 38471,
#   'uniq': 94372,
#   'wc': 6381376},
#  'commonwealth': {'funiq': 204577,
#   'fwc': 11348522,
#   'haps': 159095,
#   'lowerhaps': 154009,
#   'uniq': 204703,
#   'wc': 14022356},
#  'georgia': {'funiq': 150863,
#   'fwc': 32656431,
#   'haps': 89668,
#   'lowerhaps': 79492,
#   'uniq': 150990,
#   'wc': 42031491},
#  'getty': {'funiq': 54355,
#   'fwc': 14251103,
#   'haps': 11663,
#   'lowerhaps': 9767,
#   'uniq': 54474,
#   'wc': 18732730},
#  'gpo': {'funiq': 437646,
#   'fwc': 21860075,
#   'haps': 351637,
#   'lowerhaps': 343619,
#   'uniq': 437770,
#   'wc': 26316103},
#  'harvard': {'funiq': 35918,
#   'fwc': 849987,
#   'haps': 20447,
#   'lowerhaps': 18025,
#   'uniq': 36036,
#   'wc': 968898},
#  'ia': {'funiq': 502974,
#   'fwc': 16996418,
#   'haps': 394559,
#   'lowerhaps': 378206,
#   'uniq': 503101,
#   'wc': 23288038},
#  'illinois': {'funiq': 49018,
#   'fwc': 1829267,
#   'haps': 29755,
#   'lowerhaps': 23849,
#   'uniq': 49143,
#   'wc': 2385501},
#  'kentucky': {'funiq': 30374,
#   'fwc': 6800530,
#   'haps': 14090,
#   'lowerhaps': 11338,
#   'uniq': 30498,
#   'wc': 9405279},
#  'minnesota': {'funiq': 43666,
#   'fwc': 3598870,
#   'haps': 21112,
#   'lowerhaps': 17674,
#   'uniq': 43791,
#   'wc': 4495075},
#  'missouri': {'funiq': 119586,
#   'fwc': 3542143,
#   'haps': 90859,
#   'lowerhaps': 85222,
#   'uniq': 119713,
#   'wc': 4256929},
#  'mwdl': {'funiq': 793849,
#   'fwc': 87424176,
#   'haps': 542772,
#   'lowerhaps': 504876,
#   'uniq': 793976,
#   'wc': 111155337},
#  'nara': {'funiq': 1082133,
#   'fwc': 54355031,
#   'haps': 990235,
#   'lowerhaps': 978968,
#   'uniq': 1082259,
#   'wc': 65649116},
#  'nocar': {'funiq': 258024,
#   'fwc': 27360155,
#   'haps': 165815,
#   'lowerhaps': 157524,
#   'uniq': 258151,
#   'wc': 33487819},
#  'nocoll': {'funiq': 1785,
#   'fwc': 4626,
#   'haps': 1307,
#   'lowerhaps': 1202,
#   'uniq': 1867,
#   'wc': 6192},
#  'rumsey': {'funiq': 47343,
#   'fwc': 8825833,
#   'haps': 14682,
#   'lowerhaps': 12520,
#   'uniq': 47463,
#   'wc': 11667865},
#  'smiths': {'funiq': 432279,
#   'fwc': 51922316,
#   'haps': 182337,
#   'lowerhaps': 157337,
#   'uniq': 432406,
#   'wc': 59927374},
#  'socar': {'funiq': 61687,
#   'fwc': 5809794,
#   'haps': 31055,
#   'lowerhaps': 25606,
#   'uniq': 61813,
#   'wc': 7138136},
#  'texas': {'funiq': 855594,
#   'fwc': 72699549,
#   'haps': 245710,
#   'lowerhaps': 237998,
#   'uniq': 855720,
#   'wc': 88574895},
#  'usc': {'funiq': 259523,
#   'fwc': 41542851,
#   'haps': 108852,
#   'lowerhaps': 94218,
#   'uniq': 259650,
#   'wc': 49296854},
#  'virginia': {'funiq': 41374,
#   'fwc': 1790985,
#   'haps': 32902,
#   'lowerhaps': 31738,
#   'uniq': 41493,
#   'wc': 2248517}}

# %%
import pandas as pd
df = pd.DataFrame(stats)
df.columns = ['ARTstor', 'Biodiversity Heritage Library', 'Digital Commonwealth', 'Digital Library of Georgia',
              'J. Paul Getty Trust', 'United States Government Printing Office (GPO)', 'Harvard Library',
              'Internet Archive', 'University of Illinois at Urbana-Champaign', 'Kentucky Digital Library',
              'Minnesota Digital Library', 'Missouri Hub', 'Mountain West Digital Library',
              'National Archives and Records Administration', 'North Carolina Digital Heritage Center',
              ' ', 'David Rumsey', 'Smithsonian Institution', 'South Carolina Digital Library', 
              'The Portal to Texas History', 'University of Southern California. Libraries',
              'University of Virginia Library']
df.T
df.T.to_csv("nltk.stats.csv")

# %%
df.columns
# Out:
# Index(['artstor', 'biodiv', 'commonwealth', 'georgia', 'getty', 'gpo', 'harvard', 'ia', 'illinois', 'kentucky', 'minnesota', 'missouri', 'mwdl', 'nara', 'nocar', 'nocoll', 'rumsey', 'smiths', 'socar', 'texas', 'usc', 'virginia'], dtype='object')

# %%
#>>> fdist = nltk.FreqDist(ch.lower() for ch in raw if ch.isalpha())
fd = nltk.FreqDist(token.lower() for token in searfilt)
fd.most_common()
# Out:
# [('war', 9316),
#  ('history', 7940),
#  ('new', 7432),
#  ('county', 7030),
#  ('georgia', 6108),
#  ('university', 6024),
#  ('american', 5883),
#  ('library', 5799),
#  ('john', 5015),
#  ('world', 4293),
#  ('women', 4092),
#  ('york', 3972),
#  ('civil', 3853),
#  ('states', 3604),
#  ('united', 3590),
#  ('carolina', 3570),
#  ('de', 3223),
#  ('william', 3148),
#  ('south', 3072),
#  ('art', 2864),
#  ('school', 2734),
#  ('utah', 2726),
#  ('city', 2682),
#  ('north', 2581),
#  ('state', 2563),
#  ('james', 2517),
#  ('public', 2490),
#  ('family', 2335),
#  ('c', 2308),
#  ('boston', 2280),
#  ('george', 2254),
#  ('college', 2159),
#  ('map', 2154),
#  ('atlanta', 2126),
#  ('america', 2103),
#  ('national', 2032),
#  ('thomas', 1979),
#  ('virginia', 1950),
#  ('great', 1883),
#  ('charles', 1825),
#  ('st', 1820),
#  ('texas', 1818),
#  ('ga', 1804),
#  ('california', 1801),
#  ('washington', 1801),
#  ('african', 1779),
#  ('robert', 1727),
#  ('minnesota', 1722),
#  ('rights', 1708),
#  ('genealogy', 1702),
#  ('book', 1680),
#  ('digital', 1634),
#  ('lat', 1617),
#  ('church', 1616),
#  ('black', 1614),
#  ('massachusetts', 1588),
#  ('henry', 1587),
#  ('king', 1584),
#  ('education', 1581),
#  ('j', 1581),
#  ('life', 1577),
#  ('books', 1568),
#  ('d', 1525),
#  ('archives', 1522),
#  ('maps', 1500),
#  ('music', 1472),
#  ('century', 1468),
#  ('west', 1450),
#  ('la', 1434),
#  ('b', 1430),
#  ('e', 1429),
#  ('park', 1420),
#  ('david', 1411),
#  ('railroad', 1370),
#  ('island', 1354),
#  ('ohio', 1343),
#  ('museum', 1335),
#  ('photographs', 1328),
#  ('house', 1314),
#  ('chicago', 1304),
#  ('children', 1289),
#  ('h', 1288),
#  ('social', 1287),
#  ('street', 1254),
#  ('science', 1250),
#  ('san', 1244),
#  ('society', 1214),
#  ('illinois', 1206),
#  ('f', 1205),
#  ('lake', 1187),
#  ('works', 1174),
#  ('w', 1168),
#  ('law', 1162),
#  ('revolution', 1161),
#  ('martin', 1157),
#  ('indian', 1149),
#  ('indians', 1139),
#  ('river', 1139),
#  ('english', 1132),
#  ('americans', 1126),
#  ('libraries', 1100),
#  ('architecture', 1091),
#  ('mary', 1089),
#  ('l', 1088),
#  ('m', 1084),
#  ('ny', 1080),
#  ('historical', 1079),
#  ('paul', 1065),
#  ('kentucky', 1053),
#  ('michigan', 1044),
#  ('records', 1042),
#  ('fiction', 1040),
#  ('joseph', 1040),
#  ('high', 1031),
#  ('ii', 1020),
#  ('r', 1019),
#  ('center', 1009),
#  ('37', 1007),
#  ('government', 999),
#  ('mass', 989),
#  ('louis', 988),
#  ('china', 983),
#  ('act', 969),
#  ('native', 966),
#  ('996162679728116', 957),
#  ('edward', 955),
#  ('slavery', 941),
#  ('vietnam', 930),
#  ('company', 921),
#  ('business', 919),
#  ('smith', 919),
#  ('lincoln', 916),
#  ('literature', 899),
#  ('death', 899),
#  ('japanese', 897),
#  ('woman', 894),
#  ('language', 882),
#  ('fire', 878),
#  ('white', 876),
#  ('day', 870),
#  ('buildings', 865),
#  ('richard', 860),
#  ('pennsylvania', 853),
#  ('chinese', 851),
#  ('early', 845),
#  ('spanish', 844),
#  ('luther', 840),
#  ('kennedy', 840),
#  ('slave', 831),
#  ('roosevelt', 826),
#  ('ma', 816),
#  ('brown', 812),
#  ('general', 809),
#  ('missouri', 809),
#  ('design', 807),
#  ('florida', 807),
#  ('o', 806),
#  ('frank', 806),
#  ('first', 805),
#  ('collection', 805),
#  ('french', 802),
#  ('child', 801),
#  ('n', 797),
#  ('pa', 796),
#  ('management', 795),
#  ('military', 792),
#  ('old', 790),
#  ('england', 781),
#  ('lewis', 779),
#  ('army', 774),
#  ('mountain', 769),
#  ('southern', 769),
#  ('us', 767),
#  ('los', 764),
#  ('2', 762),
#  ('u', 761),
#  ('jackson', 759),
#  ('labor', 755),
#  ('indiana', 754),
#  ('bible', 752),
#  ('health', 752),
#  ('immigration', 750),
#  ('colorado', 749),
#  ('ca', 747),
#  ('mexico', 746),
#  ('battle', 742),
#  ('depression', 742),
#  ('red', 740),
#  ('union', 736),
#  ('harvard', 730),
#  ('lee', 728),
#  ('baseball', 725),
#  ('samuel', 723),
#  ('man', 722),
#  ('g', 717),
#  ('nc', 716),
#  ('1865', 716),
#  ('east', 716),
#  ('hill', 713),
#  ('air', 710),
#  ('home', 705),
#  ('p', 705),
#  ('image', 704),
#  ('arizona', 702),
#  ('1', 701),
#  ('research', 701),
#  ('maine', 699),
#  ('alabama', 699),
#  ('journal', 698),
#  ('wisconsin', 695),
#  ('people', 693),
#  ('technology', 693),
#  ('franklin', 692),
#  ('tennessee', 689),
#  ('ancient', 680),
#  ('men', 680),
#  ('fort', 679),
#  ('theater', 672),
#  ('little', 668),
#  ('schools', 667),
#  ('food', 665),
#  ('france', 657),
#  ('mn', 653),
#  ('culture', 652),
#  ('pictorial', 647),
#  ('connecticut', 642),
#  ('politics', 641),
#  ('newspapers', 634),
#  ('collections', 633),
#  ('work', 626),
#  ('1918', 625),
#  ('francisco', 625),
#  ('smithsonian', 624),
#  ('oregon', 622),
#  ('charleston', 621),
#  ('movement', 618),
#  ('medical', 617),
#  ('german', 614),
#  ('travel', 613),
#  ('special', 613),
#  ('johnson', 608),
#  ('germany', 607),
#  ('portrait', 605),
#  ('angeles', 602),
#  ('1920', 602),
#  ('elizabeth', 600),
#  ('peter', 597),
#  ('information', 596),
#  ('rock', 595),
#  ('gold', 595),
#  ('1800', 594),
#  ('scott', 591),
#  ('1861', 588),
#  ('1914', 586),
#  ('computer', 585),
#  ('mining', 585),
#  ('1945', 585),
#  ('harry', 585),
#  ('benjamin', 584),
#  ('suffrage', 581),
#  ('camp', 575),
#  ('kansas', 575),
#  ('india', 574),
#  ('magazine', 573),
#  ('clark', 572),
#  ('v', 570),
#  ('power', 568),
#  ('alexander', 566),
#  ('human', 566),
#  ('service', 565),
#  ('michael', 563),
#  ('iowa', 563),
#  ('photography', 562),
#  ('letter', 562),
#  ('religion', 561),
#  ('medicine', 560),
#  ('building', 557),
#  ('portraits', 555),
#  ('project', 554),
#  ('department', 554),
#  ('van', 549),
#  ('water', 547),
#  ('hall', 546),
#  ('trade', 546),
#  ('1939', 546),
#  ('mississippi', 544),
#  ('valley', 541),
#  ('industry', 541),
#  ('co', 540),
#  ('philadelphia', 539),
#  ('london', 538),
#  ('etc', 537),
#  ('young', 537),
#  ('arts', 537),
#  ('institute', 535),
#  ('poetry', 535),
#  ('horse', 533),
#  ('arthur', 532),
#  ('japan', 531),
#  ('frederick', 531),
#  ('columbia', 530),
#  ('20th', 529),
#  ('political', 526),
#  ('race', 525),
#  ('minneapolis', 524),
#  ('sports', 524),
#  ('jersey', 523),
#  ('maryland', 523),
#  ('space', 522),
#  ('dr', 521),
#  ('report', 521),
#  ('mark', 520),
#  ('students', 520),
#  ('deal', 516),
#  ('administration', 514),
#  ('soldiers', 513),
#  ('jr', 512),
#  ('yale', 512),
#  ('international', 511),
#  ('road', 511),
#  ('jones', 510),
#  ('independence', 509),
#  ('herald', 508),
#  ('farm', 507),
#  ('1900', 507),
#  ('colonial', 506),
#  ('nevada', 504),
#  ('jane', 501),
#  ('irish', 501),
#  ('newspaper', 500),
#  ('modern', 500),
#  ('dog', 500),
#  ('psychology', 498),
#  ('pacific', 498),
#  ('jefferson', 497),
#  ('salt', 496),
#  ('va', 493),
#  ('williams', 493),
#  ('theory', 490),
#  ('system', 490),
#  ('fair', 490),
#  ('letters', 490),
#  ('group', 489),
#  ('saint', 489),
#  ('green', 487),
#  ('land', 483),
#  ('russian', 482),
#  ('abraham', 481),
#  ('free', 481),
#  ('cherokee', 481),
#  ('time', 479),
#  ('field', 478),
#  ('adams', 475),
#  ('guide', 475),
#  ('africa', 474),
#  ('british', 473),
#  ('bill', 470),
#  ('radio', 470),
#  ('pictures', 470),
#  ('sc', 470),
#  ('central', 469),
#  ('beach', 469),
#  ('domain', 468),
#  ('1940', 467),
#  ('andrew', 464),
#  ('walter', 462),
#  ('louisiana', 460),
#  ('theatre', 459),
#  ('one', 458),
#  ('francis', 453),
#  ('girl', 452),
#  ('hospital', 452),
#  ('springs', 452),
#  ('wilson', 449),
#  ('police', 449),
#  ('ford', 448),
#  ('rumsey', 448),
#  ('customs', 448),
#  ('el', 447),
#  ('stephen', 447),
#  ('christian', 446),
#  ('brooklyn', 445),
#  ('jack', 443),
#  ('albert', 443),
#  ('shakespeare', 443),
#  ('spain', 440),
#  ('workers', 439),
#  ('heritage', 438),
#  ('wright', 437),
#  ('hotel', 436),
#  ('k', 433),
#  ('immigrants', 433),
#  ('wwii', 432),
#  ('engineering', 432),
#  ('media', 432),
#  ('daniel', 431),
#  ('19th', 429),
#  ('study', 428),
#  ('gallery', 428),
#  ('photos', 427),
#  ('two', 427),
#  ('laws', 426),
#  ('march', 425),
#  ('periodicals', 425),
#  ('y', 421),
#  ('postcard', 420),
#  ('montana', 419),
#  ('squadron', 419),
#  ('philosophy', 419),
#  ('dance', 417),
#  ('salem', 416),
#  ('industrial', 416),
#  ('western', 416),
#  ('1950', 415),
#  ('jewish', 415),
#  ('hitler', 415),
#  ('images', 414),
#  ('president', 412),
#  ('tom', 411),
#  ('parks', 411),
#  ('gay', 409),
#  ('economics', 409),
#  ('mexican', 409),
#  ('creek', 408),
#  ('al', 408),
#  ('football', 408),
#  ('edgar', 406),
#  ('gordon', 406),
#  ('howard', 405),
#  ('allen', 405),
#  ('census', 405),
#  ('club', 404),
#  ('detroit', 403),
#  ('domestic', 401),
#  ('construction', 400),
#  ('association', 399),
#  ('reading', 399),
#  ('biography', 398),
#  ('congress', 398),
#  ('age', 397),
#  ('lawrence', 395),
#  ('community', 394),
#  ('forest', 393),
#  ('von', 392),
#  ('sex', 392),
#  ('love', 391),
#  ('bridge', 390),
#  ('game', 389),
#  ('description', 389),
#  ('arkansas', 389),
#  ('development', 388),
#  ('declaration', 388),
#  ('des', 388),
#  ('security', 387),
#  ('historic', 387),
#  ('town', 387),
#  ('may', 386),
#  ('margaret', 386),
#  ('soviet', 386),
#  ('federal', 385),
#  ('11', 385),
#  ('davis', 385),
#  ('greek', 384),
#  ('long', 383),
#  ('tribune', 383),
#  ('big', 383),
#  ('miller', 380),
#  ('natural', 380),
#  ('control', 379),
#  ('news', 379),
#  ('dakota', 378),
#  ('stone', 373),
#  ('1930', 373),
#  ('hampshire', 372),
#  ('europe', 370),
#  ('anne', 370),
#  ('globe', 370),
#  ('newton', 370),
#  ('paris', 369),
#  ('animal', 368),
#  ('navy', 367),
#  ('britain', 366),
#  ('fashion', 366),
#  ('santa', 365),
#  ('slaves', 364),
#  ('alice', 363),
#  ('diary', 363),
#  ('charlotte', 362),
#  ('film', 362),
#  ('policy', 362),
#  ('avenue', 362),
#  ('empire', 362),
#  ('dept', 362),
#  ('catholic', 360),
#  ('constitution', 360),
#  ('relations', 360),
#  ('cat', 359),
#  ('columbus', 359),
#  ('negro', 359),
#  ('jean', 358),
#  ('il', 358),
#  ('ireland', 358),
#  ('post', 357),
#  ('photo', 357),
#  ('garden', 357),
#  ('corps', 357),
#  ('russell', 356),
#  ('oklahoma', 356),
#  ('russia', 356),
#  ('car', 355),
#  ('warren', 354),
#  ('physical', 354),
#  ('mill', 353),
#  ('analysis', 352),
#  ('party', 352),
#  ('canada', 351),
#  ('medieval', 351),
#  ('nebraska', 350),
#  ('sea', 350),
#  ('idaho', 349),
#  ('freedom', 349),
#  ('learning', 348),
#  ('oil', 348),
#  ('painting', 348),
#  ('agriculture', 348),
#  ('duluth', 347),
#  ('augusta', 347),
#  ('poster', 346),
#  ('1960', 346),
#  ('ship', 345),
#  ('cotton', 344),
#  ('conservation', 342),
#  ('aerial', 342),
#  ('papers', 342),
#  ('video', 341),
#  ('times', 340),
#  ('cold', 340),
#  ('archive', 340),
#  ('directory', 340),
#  ('poe', 339),
#  ('railroads', 339),
#  ('bay', 338),
#  ('ann', 338),
#  ('review', 337),
#  ('houses', 336),
#  ('transportation', 335),
#  ('ky', 335),
#  ('grand', 334),
#  ('strike', 334),
#  ('vermont', 333),
#  ('jim', 333),
#  ('twain', 330),
#  ('photograph', 330),
#  ('games', 330),
#  ('insignia', 330),
#  ('theodore', 330),
#  ('roman', 329),
#  ('advertising', 328),
#  ('train', 327),
#  ('middle', 326),
#  ('trail', 324),
#  ('fishing', 324),
#  ('dead', 324),
#  ('revolutionary', 322),
#  ('point', 321),
#  ('religious', 321),
#  ('snow', 320),
#  ('story', 320),
#  ('falls', 319),
#  ('carter', 319),
#  ('wood', 319),
#  ('le', 319),
#  ('rush', 319),
#  ('prohibition', 318),
#  ('italy', 318),
#  ('fish', 317),
#  ('orleans', 316),
#  ('harbor', 315),
#  ('bird', 314),
#  ('uss', 313),
#  ('walker', 313),
#  ('carl', 313),
#  ('artstor', 313),
#  ('rome', 312),
#  ('propaganda', 311),
#  ('egypt', 311),
#  ('resources', 311),
#  ('nj', 310),
#  ('office', 309),
#  ('jews', 309),
#  ('anti', 308),
#  ('teaching', 308),
#  ('clothing', 307),
#  ('canal', 306),
#  ('emily', 306),
#  ('coal', 306),
#  ('greece', 306),
#  ('reform', 306),
#  ('berlin', 306),
#  ('hawaii', 305),
#  ('wells', 304),
#  ('italian', 304),
#  ('physics', 304),
#  ('landscape', 302),
#  ('boy', 302),
#  ('fitzgerald', 302),
#  ('division', 302),
#  ('mormon', 300),
#  ('dp', 300),
#  ('atlas', 300),
#  ('writing', 298),
#  ('bell', 298),
#  ('douglas', 297),
#  ('colored', 297),
#  ('nmnh', 296),
#  ('female', 295),
#  ('baltimore', 295),
#  ('holocaust', 295),
#  ('square', 294),
#  ('foreign', 294),
#  ('iron', 294),
#  ('memorial', 293),
#  ('station', 293),
#  ('data', 293),
#  ('urban', 293),
#  ('renaissance', 293),
#  ('cross', 293),
#  ('da', 292),
#  ('hemingway', 292),
#  ('helen', 292),
#  ('girls', 291),
#  ('program', 291),
#  ('taylor', 291),
#  ('1963', 291),
#  ('press', 290),
#  ('sources', 290),
#  ('crime', 289),
#  ('robinson', 289),
#  ('philip', 288),
#  ('nuclear', 288),
#  ('code', 288),
#  ('oral', 287),
#  ('marriage', 287),
#  ('moon', 287),
#  ('chemistry', 286),
#  ('las', 286),
#  ('rhode', 285),
#  ('x', 285),
#  ('board', 285),
#  ('christmas', 284),
#  ('marshall', 284),
#  ('cod', 284),
#  ('ernest', 283),
#  ('alaska', 283),
#  ('internment', 283),
#  ('mission', 283),
#  ('use', 282),
#  ('views', 282),
#  ('market', 282),
#  ('protest', 282),
#  ('anthony', 281),
#  ('madison', 281),
#  ('jazz', 281),
#  ('murray', 281),
#  ('brothers', 281),
#  ('et', 280),
#  ('potter', 280),
#  ('internet', 280),
#  ('queen', 279),
#  ('dogs', 279),
#  ('dick', 279),
#  ('studies', 279),
#  ('personal', 279),
#  ('camps', 279),
#  ('dress', 279),
#  ('walt', 279),
#  ('court', 278),
#  ('posters', 278),
#  ('second', 278),
#  ('mills', 278),
#  ('1961', 278),
#  ('confederate', 277),
#  ('blue', 277),
#  ('1929', 276),
#  ('machine', 276),
#  ('austin', 276),
#  ('republic', 276),
#  ('obituaries', 275),
#  ('grant', 274),
#  ('del', 274),
#  ('glass', 274),
#  ('emblem', 274),
#  ('savannah', 273),
#  ('marketing', 273),
#  ('brazil', 272),
#  ('manual', 272),
#  ('programs', 271),
#  ('baptist', 271),
#  ('picture', 271),
#  ('richmond', 271),
#  ('years', 271),
#  ('du', 270),
#  ('nelson', 269),
#  ('basketball', 269),
#  ('mount', 269),
#  ('anderson', 269),
#  ('pearl', 269),
#  ('student', 268),
#  ('nursing', 268),
#  ('antonio', 268),
#  ('automobile', 267),
#  ('ct', 267),
#  ('star', 267),
#  ('electric', 266),
#  ('interior', 266),
#  ('cache', 265),
#  ('christopher', 265),
#  ('murder', 264),
#  ('jesus', 264),
#  ('1920s', 263),
#  ('tree', 263),
#  ('stories', 263),
#  ('earth', 262),
#  ('august', 262),
#  ('com', 262),
#  ('model', 262),
#  ('der', 262),
#  ('korean', 261),
#  ('text', 261),
#  ('alfred', 260),
#  ('usa', 260),
#  ('economic', 260),
#  ('dallas', 260),
#  ('ellis', 259),
#  ('communication', 259),
#  ('temple', 258),
#  ('joe', 258),
#  ('league', 258),
#  ('isaac', 258),
#  ('champaign', 257),
#  ('eagle', 257),
#  ('sarah', 256),
#  ('sound', 256),
#  ('witch', 256),
#  ('housing', 256),
#  ('year', 256),
#  ('force', 255),
#  ('harriet', 255),
#  ('ww2', 255),
#  ('brain', 255),
#  ('statistics', 255),
#  ('civilian', 255),
#  ('cleveland', 255),
#  ('introduction', 255),
#  ('training', 255),
#  ('delaware', 254),
#  ('railway', 254),
#  ('animals', 254),
#  ('nature', 254),
#  ('buffalo', 253),
#  ('massacre', 253),
#  ('line', 251),
#  ('programming', 251),
#  ('birds', 251),
#  ('television', 251),
#  ('peace', 251),
#  ('cities', 250),
#  ('3', 250),
#  ('jacob', 250),
#  ('card', 250),
#  ('mathematics', 249),
#  ('1775', 249),
#  ('dickens', 249),
#  ('plant', 248),
#  ('search', 248),
#  ('golden', 247),
#  ('ray', 247),
#  ('dream', 246),
#  ('boys', 246),
#  ('assassination', 246),
#  ('insurance', 245),
#  ('rice', 245),
#  ('hamilton', 244),
#  ('ethics', 244),
#  ('harlem', 244),
#  ('class', 244),
#  ('morgan', 244),
#  ('cuba', 243),
#  ('ice', 243),
#  ('1860', 243),
#  ('care', 243),
#  ('1917', 243),
#  ('bowl', 243),
#  ('mine', 243),
#  ('mines', 242),
#  ('nh', 242),
#  ('herbert', 242),
#  ('speech', 242),
#  ('rose', 242),
#  ('families', 242),
#  ('duke', 242),
#  ('monroe', 242),
#  ('vs', 241),
#  ('horses', 241),
#  ('ut', 241),
#  ('geology', 241),
#  ('douglass', 240),
#  ('1910', 240),
#  ('prince', 240),
#  ('canyon', 240),
#  ('catalog', 239),
#  ('good', 239),
#  ('liberty', 239),
#  ('god', 239),
#  ('reconstruction', 238),
#  ('criticism', 237),
#  ('cats', 237),
#  ('winter', 237),
#  ('july', 237),
#  ('naval', 237),
#  ('night', 237),
#  ('test', 237),
#  ('dictionary', 236),
#  ('wpa', 236),
#  ('womens', 236),
#  ('correspondence', 236),
#  ('movie', 236),
#  ('morris', 235),
#  ('plan', 235),
#  ('ruth', 235),
#  ('country', 234),
#  ('self', 234),
#  ('albany', 234),
#  ('cooper', 234),
#  ('mrs', 234),
#  ('primary', 234),
#  ('finance', 233),
#  ('color', 233),
#  ('1970', 233),
#  ('1975', 233),
#  ('manuscripts', 233),
#  ('lowell', 233),
#  ('http', 233),
#  ('thompson', 233),
#  ('rico', 233),
#  ('district', 232),
#  ('tea', 232),
#  ('sam', 232),
#  ('manhattan', 232),
#  ('puerto', 231),
#  ('pittsburgh', 231),
#  ('plants', 231),
#  ('elementary', 231),
#  ('disney', 231),
#  ('korea', 231),
#  ('birth', 230),
#  ('era', 230),
#  ('cars', 230),
#  ('churches', 229),
#  ('urbana', 228),
#  ('drug', 228),
#  ('patrick', 227),
#  ('lord', 227),
#  ('heart', 226),
#  ('houston', 226),
#  ('lloyd', 226),
#  ('planning', 226),
#  ('seattle', 226),
#  ('energy', 225),
#  ('plantation', 225),
#  ('paper', 225),
#  ('susan', 224),
#  ('systems', 224),
#  ('change', 224),
#  ('audio', 223),
#  ('fred', 223),
#  ('eugene', 222),
#  ('bob', 222),
#  ('light', 222),
#  ('colleges', 222),
#  ('academy', 222),
#  ('annual', 221),
#  ('committee', 220),
#  ('record', 220),
#  ('haven', 220),
#  ('bureau', 219),
#  ('bomb', 219),
#  ('moore', 219),
#  ('ships', 219),
#  ('eacute', 219),
#  ('sanborn', 219),
#  ('disease', 219),
#  ('botany', 218),
#  ('sculpture', 218),
#  ('sugar', 218),
#  ('motion', 218),
#  ('racing', 218),
#  ('flight', 217),
#  ('manuals', 217),
#  ('cooking', 217),
#  ('commission', 216),
#  ('making', 216),
#  ('cemetery', 216),
#  ('wars', 215),
#  ('9', 215),
#  ('chester', 215),
#  ('campbell', 215),
#  ('ocean', 215),
#  ('kill', 215),
#  ('tn', 215),
#  ('cultural', 215),
#  ('period', 215),
#  ('olympics', 214),
#  ('karl', 214),
#  ('marie', 214),
#  ('1968', 214),
#  ('three', 214),
#  ('soldier', 213),
#  ('methodist', 213),
#  ('org', 213),
#  ('cook', 213),
#  ('money', 213),
#  ('montgomery', 213),
#  ('dickinson', 213),
#  ('wall', 213),
#  ('lost', 212),
#  ('latin', 212),
#  ('store', 212),
#  ('trials', 212),
#  ('amendment', 211),
#  ('drawings', 211),
#  ('holmes', 211),
#  ('costume', 211),
#  ('bank', 211),
#  ('anatomy', 210),
#  ('survey', 210),
#  ('encyclopedia', 210),
#  ('funeral', 210),
#  ('1890', 209),
#  ('wayne', 209),
#  ('beverly', 209),
#  ('baker', 209),
#  ('maria', 209),
#  ('segregation', 209),
#  ('postcards', 208),
#  ('nude', 208),
#  ('denver', 208),
#  ('ralph', 208),
#  ('atlantic', 208),
#  ('environmental', 208),
#  ('mountains', 208),
#  ('grammar', 208),
#  ('dust', 207),
#  ('mitchell', 207),
#  ('1850', 207),
#  ('gettysburg', 206),
#  ('di', 206),
#  ('mo', 206),
#  ('show', 206),
#  ('ben', 206),
#  ('mental', 206),
#  ('1870', 206),
#  ('harold', 205),
#  ('poland', 205),
#  ('web', 205),
#  ('flowers', 205),
#  ('einstein', 205),
#  ('atomic', 205),
#  ('september', 204),
#  ('register', 204),
#  ('1980', 204),
#  ('graham', 204),
#  ('truman', 204),
#  ('greenville', 204),
#  ('therapy', 204),
#  ('crisis', 204),
#  ('property', 204),
#  ('series', 204),
#  ('1964', 204),
#  ('en', 203),
#  ('juan', 203),
#  ('gun', 203),
#  ('tx', 203),
#  ('evolution', 203),
#  ('northern', 202),
#  ('1912', 202),
#  ('www', 202),
#  ('printing', 201),
#  ('joyce', 201),
#  ('newport', 201),
#  ('summer', 201),
#  ('4', 201),
#  ('prison', 201),
#  ('tobacco', 201),
#  ('7', 200),
#  ('simon', 200),
#  ('ward', 199),
#  ('clinton', 199),
#  ('electronic', 199),
#  ('reno', 199),
#  ...]

# %%
searcom
# Out:
# {'searches': [('war', 6123),
#   ('Georgia', 4924),
#   ('University', 4640),
#   ('new', 4310),
#   ('History', 4022),
#   ('history', 3874),
#   ('Library', 3845),
#   ('county', 3588),
#   ('County', 3381),
#   ('War', 3115),
#   ('New', 3067),
#   ('United', 3021),
#   ('States', 3014),
#   ('de', 2998),
#   ('women', 2986),
#   ('american', 2959),
#   ('American', 2886),
#   ('world', 2633),
#   ('john', 2542),
#   ('John', 2415),
#   ('civil', 2404),
#   ('Carolina', 2290),
#   ('york', 2231),
#   ('Utah', 2083),
#   ('library', 1934),
#   ('South', 1910),
#   ('map', 1831),
#   ('school', 1786),
#   ('family', 1751),
#   ('York', 1699),
#   ('C', 1653),
#   ('World', 1639),
#   ('lat', 1616),
#   ('William', 1605),
#   ('art', 1583),
#   ('Atlanta', 1575),
#   ('State', 1534),
#   ('william', 1519),
#   ('rights', 1479),
#   ('city', 1475),
#   ('North', 1475),
#   ('Civil', 1414),
#   ('university', 1365),
#   ('century', 1364),
#   ('public', 1352),
#   ('book', 1349),
#   ('National', 1322),
#   ('james', 1312),
#   ('books', 1288),
#   ('life', 1262),
#   ('Art', 1261),
#   ('carolina', 1256),
#   ('boston', 1252),
#   ('black', 1222),
#   ('Archives', 1197),
#   ('City', 1189),
#   ('James', 1188),
#   ('genealogy', 1172),
#   ('georgia', 1171),
#   ('music', 1160),
#   ('College', 1155),
#   ('south', 1143),
#   ('la', 1142),
#   ('george', 1138),
#   ('great', 1136),
#   ('Public', 1131),
#   ('George', 1101),
#   ('north', 1091),
#   ('washington', 1089),
#   ('Women', 1083),
#   ('America', 1070),
#   ('education', 1056),
#   ('J', 1042),
#   ('virginia', 1034),
#   ('works', 1020),
#   ('king', 1020),
#   ('Boston', 1018),
#   ('state', 1012),
#   ('america', 1009),
#   ('37', 1007),
#   ('california', 1001),
#   ('college', 1000),
#   ('thomas', 977),
#   ('Thomas', 976),
#   ('st', 964),
#   ('996162679728116', 957),
#   ('children', 950),
#   ('texas', 949),
#   ('School', 935),
#   ('charles', 934),
#   ('ohio', 933),
#   ('Digital', 928),
#   ('African', 908),
#   ('island', 907),
#   ('robert', 899),
#   ('Virginia', 893),
#   ('house', 890),
#   ('railroad', 885),
#   ('H', 884),
#   ('Photographs', 884),
#   ('Minnesota', 869),
#   ('Charles', 868),
#   ('Museum', 859),
#   ('Church', 859),
#   ('african', 856),
#   ('Ga', 851),
#   ('minnesota', 850),
#   ('Texas', 850),
#   ('St', 847),
#   ('west', 842),
#   ('science', 827),
#   ('Massachusetts', 826),
#   ('Robert', 821),
#   ('henry', 820),
#   ('II', 811),
#   ('park', 809),
#   ('chicago', 805),
#   ('fiction', 800),
#   ('maps', 792),
#   ('d', 791),
#   ('revolution', 789),
#   ('California', 786),
#   ('david', 780),
#   ('Mass', 780),
#   ('Libraries', 777),
#   ('san', 775),
#   ('W', 771),
#   ('language', 770),
#   ('English', 769),
#   ('B', 768),
#   ('2', 762),
#   ('massachusetts', 757),
#   ('Henry', 755),
#   ('church', 751),
#   ('E', 751),
#   ('Great', 743),
#   ('woman', 740),
#   ('D', 734),
#   ('Society', 729),
#   ('Historical', 720),
#   ('1865', 716),
#   ('ny', 716),
#   ('Center', 713),
#   ('literature', 710),
#   ('law', 709),
#   ('Washington', 705),
#   ('national', 704),
#   ('1', 701),
#   ('street', 699),
#   ('slave', 698),
#   ('digital', 694),
#   ('Maps', 692),
#   ('slavery', 691),
#   ('records', 687),
#   ('native', 684),
#   ('Indians', 681),
#   ('e', 678),
#   ('act', 678),
#   ('martin', 676),
#   ('M', 675),
#   ('ga', 673),
#   ('b', 662),
#   ('c', 655),
#   ('image', 650),
#   ('social', 644),
#   ('Illinois', 643),
#   ('high', 641),
#   ('utah', 639),
#   ('Social', 638),
#   ('R', 628),
#   ('Americans', 626),
#   ('1918', 625),
#   ('L', 625),
#   ('michigan', 624),
#   ('day', 623),
#   ('F', 623),
#   ('David', 622),
#   ('design', 615),
#   ('river', 609),
#   ('death', 609),
#   ('indian', 609),
#   ('Park', 607),
#   ('management', 605),
#   ('U', 605),
#   ('fire', 604),
#   ('1920', 602),
#   ('Pictorial', 601),
#   ('vietnam', 598),
#   ('Lake', 597),
#   ('child', 597),
#   ('labor', 594),
#   ('1800', 594),
#   ('1861', 588),
#   ('West', 588),
#   ('1914', 586),
#   ('1945', 585),
#   ('lake', 584),
#   ('f', 582),
#   ('immigration', 580),
#   ('states', 580)]}

# %%
import pickle
import nltk

p = pickle.load( open( "/media/storage/dpla-data/pickles/virginia.p", "rb" ) )

### >>> fdist = nltk.FreqDist(ch.lower() for ch in raw if ch.isalpha())
fd = nltk.FreqDist((token) for token in p['virginia']['filtered'])
fd.most_common()
# Out:
# [('Virginia', 150814),
#  ('University', 107608),
#  ('Library', 64281),
#  ('Charlottesville', 54329),
#  ('lib', 40564),
#  ('image', 35840),
#  ('Va', 35371),
#  ('Holsinger', 31644),
#  ('Collection', 30216),
#  ('Collections', 26682),
#  ('uva', 24670),
#  ('Special', 23381),
#  ('Visual', 22457),
#  ('History', 22141),
#  ('ca', 21622),
#  ('material', 21482),
#  ('Studio', 21083),
#  ('States', 17398),
#  ('United', 17389),
#  ('use', 15941),
#  ('information', 15905),
#  ('go', 15900),
#  ('please', 15896),
#  ('search', 15895),
#  ('http', 15894),
#  ('virginia', 15894),
#  ('edu', 15894),
#  ('terms', 15894),
#  ('negatives', 12167),
#  ('Regions', 12101),
#  ('states', 12023),
#  ('W', 12001),
#  ('name', 11944),
#  ('Davis', 11606),
#  ('Jackson', 11421),
#  ('1825', 11044),
#  ('present', 10990),
#  ('Online', 10977),
#  ('1890', 10538),
#  ('1938', 10459),
#  ('index', 10378),
#  ('volume', 10376),
#  ('plus', 10376),
#  ('photographic', 10376),
#  ('Negatives', 10376),
#  ('studio', 10376),
#  ('1930', 9763),
#  ('1866', 9685),
#  ('Rufus', 9632),
#  ('Glass', 9513),
#  ('African', 9456),
#  ('Portraits', 9248),
#  ('Visitors', 8899),
#  ('may', 8870),
#  ('without', 8870),
#  ('must', 8869),
#  ('Rector', 8864),
#  ('additional', 8863),
#  ('permission', 8863),
#  ('credited', 8863),
#  ('reproduced', 8863),
#  ('Plate', 7977),
#  ('white', 7705),
#  ('condition', 7646),
#  ('Black', 7628),
#  ('good', 7621),
#  ('works', 6786),
#  ('built', 6284),
#  ('Single', 6266),
#  ('American', 6206),
#  ('photographs', 6040),
#  ('People', 6015),
#  ('1882', 5640),
#  ('1947', 5617),
#  ('5x7', 5607),
#  ('Photographs', 5524),
#  ('Photography', 5521),
#  ('restrictions', 5518),
#  ('accessing', 5518),
#  ('County', 5086),
#  ('music', 4908),
#  ('South', 4851),
#  ('function', 4839),
#  ('U', 4228),
#  ('group', 4104),
#  ('1915', 3833),
#  ('8x10', 3826),
#  ('ethnic', 3411),
#  ('UVA', 3360),
#  ('Americans', 3335),
#  ('Digital', 3319),
#  ('Record', 3318),
#  ('Text', 3317),
#  ('DPLA', 3317),
#  ('School', 3015),
#  ('Print', 2959),
#  ('Cities', 2789),
#  ('towns', 2782),
#  ('C', 2709),
#  ('notated', 2549),
#  ('Schools', 2402),
#  ('Contact', 2338),
#  ('Group', 2282),
#  ('Unknown', 2089),
#  ('Children', 2018),
#  ('Use', 2012),
#  ('Conditions', 2012),
#  ('New', 1992),
#  ('English', 1922),
#  ('N', 1918),
#  ('1917', 1818),
#  ('Date', 1792),
#  ('piano', 1773),
#  ('03', 1768),
#  ('York', 1738),
#  ('Untitled', 1689),
#  ('07', 1628),
#  ('09', 1616),
#  ('11', 1609),
#  ('prints', 1594),
#  ('04', 1572),
#  ('J', 1526),
#  ('12', 1508),
#  ('05', 1497),
#  ('1916', 1486),
#  ('01', 1475),
#  ('1918', 1474),
#  ('10', 1454),
#  ('08', 1441),
#  ('1914', 1438),
#  ('Mrs', 1426),
#  ('06', 1386),
#  ('Popular', 1333),
#  ('Songs', 1322),
#  ('Miss', 1267),
#  ('elements', 1259),
#  ('H', 1238),
#  ('02', 1193),
#  ('UVa', 1193),
#  ('Co', 1166),
#  ('buildings', 1159),
#  ('St', 1158),
#  ('Piano', 1125),
#  ('Richard', 1110),
#  ('spaces', 1100),
#  ('E', 1085),
#  ('1912', 1077),
#  ('gender', 1040),
#  ('Education', 1029),
#  ('Students', 1016),
#  ('Architecture', 1012),
#  ('John', 1009),
#  ('content', 1005),
#  ('linguistic', 1004),
#  ('Rotunda', 965),
#  ('Anderson', 954),
#  ('1940', 942),
#  ('F', 926),
#  ('Ralph', 910),
#  ('sciences', 889),
#  ('Training', 886),
#  ('Social', 878),
#  ('Film', 877),
#  ('Boston', 858),
#  ('G', 853),
#  ('Carolina', 845),
#  ('1913', 824),
#  ('M', 798),
#  ('overall', 791),
#  ('William', 789),
#  ('Hall', 778),
#  ('Institutional', 778),
#  ('Trees', 776),
#  ('Africa', 767),
#  ('Babies', 764),
#  ('Philadelphia', 743),
#  ('B', 743),
#  ('L', 739),
#  ('1919', 732),
#  ('subject', 723),
#  ('Unidentified', 718),
#  ('Buildings', 718),
#  ('R', 718),
#  ('Open', 708),
#  ('Charles', 701),
#  ('College', 678),
#  ('site', 670),
#  ('D', 662),
#  ('Army', 647),
#  ('George', 642),
#  ('emulsion', 640),
#  ('damage', 632),
#  ('Portrait', 630),
#  ('Sports', 625),
#  ('Faculty', 623),
#  ('Tex', 614),
#  ('Industrial', 610),
#  ('hand', 610),
#  ('War', 608),
#  ('World', 595),
#  ('Institute', 566),
#  ('Domestic', 559),
#  ('de', 557),
#  ('18', 543),
#  ('Alderman', 538),
#  ('Landscape', 524),
#  ('Soldiers', 520),
#  ('Uniforms', 519),
#  ('age', 518),
#  ('Men', 517),
#  ('plate', 508),
#  ('Mr', 506),
#  ('Fraternity', 501),
#  ('right', 492),
#  ('form', 483),
#  ('Football', 477),
#  ('16', 476),
#  ('1920', 476),
#  ('silver', 474),
#  ('Gelatin', 470),
#  ('Thomas', 466),
#  ('21', 465),
#  ('Furniture', 460),
#  ('Washington', 453),
#  ('instrumental', 451),
#  ('North', 446),
#  ('left', 443),
#  ('photo', 442),
#  ('Colored', 441),
#  ('Lawn', 440),
#  ('shrubs', 438),
#  ('James', 437),
#  ('Colleges', 434),
#  ('8X10', 433),
#  ('type', 430),
#  ('Hats', 429),
#  ('House', 429),
#  ('P', 425),
#  ('types', 421),
#  ('24', 420),
#  ('Henry', 417),
#  ('Dr', 410),
#  ('Ga', 407),
#  ('East', 407),
#  ('26', 401),
#  ('school', 398),
#  ('14', 397),
#  ('Engravings', 393),
#  ('Emulsion', 392),
#  ('Rooms', 391),
#  ('17', 390),
#  ('along', 389),
#  ('Continents', 388),
#  ('20', 386),
#  ('text', 382),
#  ('Interior', 381),
#  ('Land', 379),
#  ('High', 376),
#  ('15', 376),
#  ('13', 376),
#  ('1921', 374),
#  ('Texas', 373),
#  ('Elizabeth', 372),
#  ('27', 370),
#  ('vehicles', 367),
#  ('Summer', 363),
#  ('cartographic', 363),
#  ('players', 361),
#  ('Albemarle', 361),
#  ('Women', 357),
#  ('Y', 357),
#  ('22', 356),
#  ('25', 356),
#  ('19', 355),
#  ('West', 353),
#  ('Automobiles', 351),
#  ('Materials', 351),
#  ('context', 350),
#  ('bottom', 348),
#  ('City', 347),
#  ('28', 347),
#  ('1924', 345),
#  ('Middle', 341),
#  ('Smith', 341),
#  ('Robert', 340),
#  ('29', 340),
#  ('schools', 339),
#  ('Baltimore', 337),
#  ('30', 337),
#  ('people', 336),
#  ('side', 334),
#  ('11x14', 332),
#  ('Animals', 328),
#  ('Building', 327),
#  ('Ala', 326),
#  ('houses', 324),
#  ('Horses', 321),
#  ('Countries', 318),
#  ('architecture', 317),
#  ('Houses', 316),
#  ('voice', 315),
#  ('occupation', 314),
#  ('Architectural', 313),
#  ('Jr', 313),
#  ('corner', 313),
#  ('French', 312),
#  ('O', 312),
#  ('State', 309),
#  ('23', 309),
#  ('Union', 308),
#  ('family', 308),
#  ('Academy', 307),
#  ('1974', 307),
#  ('Ark', 306),
#  ('Landforms', 305),
#  ('Agricultural', 303),
#  ('Ditson', 298),
#  ('1891', 297),
#  ('Gardens', 293),
#  ('Mississippi', 291),
#  ('La', 290),
#  ('Company', 287),
#  ('Church', 286),
#  ('Negro', 284),
#  ('Edward', 284),
#  ('Evening', 284),
#  ('Oliver', 280),
#  ('Events', 279),
#  ('gowns', 278),
#  ('Families', 278),
#  ('Two', 278),
#  ('1925', 272),
#  ('Teachers', 271),
#  ('Old', 271),
#  ('visible', 266),
#  ('Saint', 265),
#  ('Vocal', 264),
#  ('Schirmer', 263),
#  ('Tenn', 263),
#  ('Caroline', 263),
#  ('Baseball', 262),
#  ('Universities', 262),
#  ('Color', 258),
#  ('Sq', 258),
#  ('activity', 258),
#  ('Chestnut', 257),
#  ('Georgia', 257),
#  ('Costume', 257),
#  ('top', 256),
#  ('missing', 255),
#  ('Joseph', 251),
#  ('Structural', 250),
#  ('relationship', 250),
#  ('White', 249),
#  ('4', 249),
#  ('Bettis', 249),
#  ('Mary', 245),
#  ('France', 244),
#  ('Taylor', 242),
#  ('Edgefield', 241),
#  ('Trenton', 239),
#  ('Home', 238),
#  ('Normal', 238),
#  ('Girls', 238),
#  ('landscapes', 237),
#  ('1895', 236),
#  ('Roads', 232),
#  ('Penn', 232),
#  ('Alabama', 231),
#  ('Dwellings', 231),
#  ('Walker', 230),
#  ('Arranged', 227),
#  ('songs', 227),
#  ('Preachers', 227),
#  ('Broadway', 226),
#  ('1972', 226),
#  ('n', 225),
#  ('Views', 225),
#  ('1977', 224),
#  ('Photogravures', 223),
#  ('Lee', 221),
#  ('31', 221),
#  ('football', 220),
#  ('story', 220),
#  ('Hench', 218),
#  ('Atcheson', 217),
#  ('Cumberland', 217),
#  ('Laughlin', 217),
#  ('1922', 216),
#  ('Railroads', 215),
#  ('1928', 215),
#  ('Street', 214),
#  ('Operas', 210),
#  ('1923', 206),
#  ('Brothers', 205),
#  ('clothes', 205),
#  ('Costumes', 204),
#  ('building', 204),
#  ('colleges', 204),
#  ('Arkansas', 203),
#  ('Louis', 202),
#  ('Couples', 202),
#  ('Henrico', 201),
#  ('Jefferson', 200),
#  ('Frank', 199),
#  ('specific', 198),
#  ('Europe', 196),
#  ('districts', 196),
#  ('session', 193),
#  ('voices', 193),
#  ('Paul', 192),
#  ('water', 191),
#  ('Richmond', 190),
#  ('Map', 190),
#  ('Boxing', 188),
#  ('Arthur', 187),
#  ('Alexander', 187),
#  ('Fla', 186),
#  ('1970', 186),
#  ('Waltzes', 184),
#  ('Farms', 184),
#  ('Parish', 184),
#  ('Finals', 183),
#  ('Choruses', 182),
#  ('Music', 182),
#  ('Pavilion', 181),
#  ('Paris', 181),
#  ('Flowers', 181),
#  ('Edwin', 179),
#  ('house', 179),
#  ('President', 178),
#  ('Sir', 178),
#  ('Ruth', 177),
#  ('Railroad', 177),
#  ('Pa', 176),
#  ('Hill', 176),
#  ('d', 175),
#  ('Monticello', 175),
#  ('Class', 174),
#  ('14x17', 173),
#  ('view', 173),
#  ('Players', 172),
#  ('Mixed', 172),
#  ('Warner', 171),
#  ('Delta', 170),
#  ('Tennessee', 169),
#  ('Cabell', 168),
#  ('general', 167),
#  ('1966', 167),
#  ('1896', 166),
#  ('Porches', 166),
#  ('1969', 166),
#  ('1889', 165),
#  ('fields', 164),
#  ('Hampton', 161),
#  ('King', 159),
#  ('Helena', 159),
#  ('worn', 158),
#  ('Island', 158),
#  ('Mass', 158),
#  ('Phi', 157),
#  ('Cultural', 157),
#  ('Central', 156),
#  ('upper', 155),
#  ('1858', 155),
#  ('Hospital', 155),
#  ('Mammals', 154),
#  ('men', 154),
#  ('Sacred', 154),
#  ('35', 154),
#  ('construction', 153),
#  ('Farm', 152),
#  ('Horse', 152),
#  ('composition', 152),
#  ('Physical', 152),
#  ('Gloucester', 151),
#  ('1885', 150),
#  ('Club', 150),
#  ('Chicago', 150),
#  ('Railway', 150),
#  ('1968', 150),
#  ('near', 148),
#  ('Ohio', 148),
#  ('1819', 148),
#  ('unidentified', 146),
#  ('Stores', 146),
#  ('Sigma', 144),
#  ('components', 144),
#  ('1870', 144),
#  ('Engineering', 144),
#  ('Equipment', 143),
#  ('Secular', 142),
#  ('room', 141),
#  ('1911', 140),
#  ('1937', 140),
#  ('Chesterfield', 139),
#  ('1976', 139),
#  ('1875', 139),
#  ('1929', 139),
#  ('Louisiana', 138),
#  ('parts', 138),
#  ('1830', 138),
#  ('Weddings', 138),
#  ('business', 137),
#  ('Medical', 137),
#  ('Components', 136),
#  ('Conference', 136),
#  ('Florida', 136),
#  ('Exhibitions', 135),
#  ('Scott', 134),
#  ('Brown', 134),
#  ('Range', 133),
#  ('techniques', 133),
#  ('Snow', 132),
#  ('Pageants', 132),
#  ('1900', 132),
#  ('Main', 132),
#  ('1863', 131),
#  ('Saalfield', 131),
#  ('1872', 131),
#  ('Beaufort', 130),
#  ('Southern', 129),
#  ('portraits', 129),
#  ('man', 129),
#  ('deteriorating', 129),
#  ('1971', 129),
#  ('Track', 129),
#  ('Albert', 129),
#  ('Allen', 128),
#  ('Mountains', 128),
#  ('Cincinnati', 128),
#  ('Basketball', 127),
#  ('Field', 127),
#  ('activities', 127),
#  ('Africans', 127),
#  ('Helen', 127),
#  ('la', 126),
#  ('1905', 126),
#  ('Public', 126),
#  ('Boys', 125),
#  ('Point', 125),
#  ('head', 125),
#  ('Vocational', 124),
#  ('Brides', 124),
#  ('Md', 124),
#  ('Retail', 124),
#  ('1975', 124),
#  ('1950', 124),
#  ('London', 124),
#  ('1813', 124),
#  ('Bodies', 124),
#  ('religion', 123),
#  ('1927', 123),
#  ('score', 122),
#  ('1850', 121),
#  ('1935', 121),
#  ('England', 121),
#  ('plants', 120),
#  ('Accessories', 120),
#  ('Superintendent', 120),
#  ('Willig', 120),
#  ('Dance', 119),
#  ('View', 119),
#  ('Sweet', 119),
#  ('1926', 119),
#  ('Wood', 118),
#  ('1839', 118),
#  ('b', 117),
#  ('Low', 116),
#  ('1809', 116),
#  ('Francis', 116),
#  ('entirely', 116),
#  ('rooms', 115),
#  ('Clark', 115),
#  ('Green', 115),
#  ('Construction', 114),
#  ('Martin', 114),
#  ('Memorial', 114),
#  ('Kenya', 114),
#  ('1856', 113),
#  ('1892', 113),
#  ('Randolph', 113),
#  ('Gordon', 113),
#  ('students', 113),
#  ('1964', 113),
#  ('1876', 113),
#  ('Medium', 113),
#  ('arr', 112),
#  ('Webb', 112),
#  ('Edgar', 112),
#  ('2', 112),
#  ('1848', 111),
#  ('1859', 111),
#  ('Wilson', 111),
#  ('Mountain', 110),
#  ('field', 110),
#  ('1910', 110),
#  ('Orleans', 110),
#  ('aerial', 110),
#  ('Slight', 108),
#  ('1901', 108),
#  ('broken', 108),
#  ('1826', 108),
#  ('Statues', 108),
#  ('Harry', 107),
#  ('one', 107),
#  ('concepts', 107),
#  ('1967', 107),
#  ('Fourth', 106),
#  ('Daughters', 106),
#  ('Scenes', 106),
#  ('Chi', 105),
#  ('Team', 105),
#  ('Graded', 105),
#  ('Dogs', 105),
#  ('Walter', 105),
#  ('Nottoway', 104),
#  ('Camp', 104),
#  ('Exhibits', 103),
#  ('Kappa', 103),
#  ('Harrison', 103),
#  ('Briar', 103),
#  ('Coats', 103),
#  ('K', 103),
#  ('None', 103),
#  ('1963', 103),
#  ('1909', 102),
#  ('Marion', 102),
#  ('1874', 102),
#  ('Harris', 102),
#  ('Bowling', 102),
#  ('duets', 101),
#  ('Franz', 101),
#  ('edge', 100),
#  ('land', 100),
#  ('1984', 100),
#  ('1936', 100),
#  ('Dormitories', 100),
#  ('1880', 99),
#  ('1941', 99),
#  ('Day', 99),
#  ('1827', 99),
#  ('old', 99),
#  ('1600', 99),
#  ('Natural', 98),
#  ('1852', 98),
#  ('Veils', 98),
#  ('Personal', 98),
#  ('V', 97),
#  ('Fur', 97),
#  ('1865', 97),
#  ('1833', 97),
#  ('1797', 97),
#  ('Fences', 96),
#  ('1828', 96),
#  ('Pageant', 96),
#  ('processes', 96),
#  ('Chapel', 96),
#  ('Grounds', 95),
#  ('Exhibit', 95),
#  ('1400', 95),
#  ('joining', 95),
#  ('areas', 95),
#  ('Additive', 95),
#  ('Samuel', 94),
#  ('Graduation', 94),
#  ('1861', 94),
#  ('Frederick', 94),
#  ('garments', 94),
#  ('Toys', 94),
#  ('Frogmore', 92),
#  ('geographic', 92),
#  ('1867', 92),
#  ('1939', 92),
#  ('Clergy', 91),
#  ('1980', 91),
#  ('Carter', 91),
#  ('1871', 91),
#  ('1877', 91),
#  ('Peters', 90),
#  ('Morris', 90),
#  ('chipped', 90),
#  ('Jones', 90),
#  ('Campbell', 90),
#  ('General', 90),
#  ('Party', 89),
#  ('Marches', 89),
#  ('Dillard', 89),
#  ('Madison', 89),
#  ('1986', 89),
#  ('1869', 89),
#  ('Center', 89),
#  ('1965', 89),
#  ('Makers', 88),
#  ('across', 88),
#  ('events', 88),
#  ('Monroe', 88),
#  ('National', 88),
#  ('1979', 88),
#  ('Beta', 88),
#  ('home', 87),
#  ('David', 87),
#  ('pageants', 87),
#  ('Alfred', 87),
#  ('1860', 87),
#  ('von', 87),
#  ('277', 87),
#  ('Mount', 87),
#  ('Food', 87),
#  ('du', 86),
#  ('Park', 86),
#  ('1987', 86),
#  ('Okla', 86),
#  ('Montgomery', 86),
#  ('interior', 86),
#  ('Office', 85),
#  ('Dormitory', 85),
#  ('1899', 85),
#  ('children', 85),
#  ('Academic', 85),
#  ('Corinne', 84),
#  ('map', 84),
#  ('Albumen', 84),
#  ('Chairs', 84),
#  ('Steps', 84),
#  ('Bridge', 84),
#  ('1945', 84),
#  ('1832', 84),
#  ('Road', 84),
#  ('Marshall', 83),
#  ('Cleveland', 83),
#  ('Station', 83),
#  ('1837', 83),
#  ('Liberia', 83),
#  ('Books', 83),
#  ('Stingray', 83),
#  ('1883', 82),
#  ('Sumter', 82),
#  ('1847', 82),
#  ('1857', 82),
#  ('Lewis', 82),
#  ('Middlesex', 82),
#  ('Carl', 82),
#  ('1849', 81),
#  ('1888', 81),
#  ('Son', 81),
#  ('Jean', 81),
#  ('Alumni', 81),
#  ('Miller', 81),
#  ('1907', 81),
#  ('obscuring', 81),
#  ('Lawns', 81),
#  ('1862', 80),
#  ('Yards', 80),
#  ('consumer', 79),
#  ('1897', 79),
#  ('Board', 79),
#  ('hands', 79),
#  ('Groups', 79),
#  ('Machinery', 78),
#  ('Bowles', 78),
#  ('Halifax', 78),
#  ('et', 78),
#  ('Shrubs', 78),
#  ('Ave', 78),
#  ('l', 78),
#  ('1864', 77),
#  ('Ky', 77),
#  ('laboratory', 77),
#  ('Residence', 76),
#  ('1886', 76),
#  ('1973', 76),
#  ('process', 76),
#  ('1308', 76),
#  ('1893', 76),
#  ('1829', 76),
#  ('Court', 76),
#  ('love', 76),
#  ('e', 76),
#  ('Rosenwald', 75),
#  ('Williams', 75),
#  ('new', 75),
#  ('Churches', 75),
#  ('showing', 75),
#  ('artifacts', 75),
#  ('German', 75),
#  ('Brick', 74),
#  ('Nurses', 74),
#  ('Anne', 74),
#  ('costume', 74),
#  ('Sea', 74),
#  ('stations', 73),
#  ('1810', 73),
#  ('River', 73),
#  ('Serpentine', 73),
#  ('Pond', 73),
#  ('1978', 72),
#  ('1835', 72),
#  ('Peter', 72),
#  ('Society', 72),
#  ('1846', 71),
#  ('1840', 71),
#  ('Stadiums', 71),
#  ('Lawrenceville', 71),
#  ('1842', 71),
#  ('Christian', 71),
#  ('1855', 71),
#  ('Navy', 71),
#  ('Conferences', 71),
#  ('1868', 71),
#  ('Johnson', 71),
#  ('party', 71),
#  ('Love', 70),
#  ('Lyon', 70),
#  ('des', 70),
#  ('Islands', 70),
#  ('Wm', 70),
#  ('Containers', 70),
#  ('Stephen', 69),
#  ('Russell', 69),
#  ('II', 69),
#  ('Tables', 69),
#  ('1985', 69),
#  ('Fruit', 69),
#  ('Shelby', 69),
#  ('Berry', 69),
#  ('Prince', 68),
#  ('1887', 68),
#  ('location', 68),
#  ('Frederic', 68),
#  ('1884', 68),
#  ('Rock', 68),
#  ('Minor', 68),
#  ('Watercraft', 68),
#  ('Ridge', 68),
#  ('Art', 68),
#  ('41', 68),
#  ('Warren', 68),
#  ('Rural', 68),
#  ('1807', 67),
#  ('drawn', 67),
#  ('1908', 67),
#  ('1903', 67),
#  ('Adams', 67),
#  ('organ', 67),
#  ('Norfolk', 67),
#  ('Gillingham', 67),
#  ('1873', 67),
#  ('1841', 66),
#  ('Rogers', 66),
#  ('Forest', 66),
#  ('Oh', 66),
#  ('Apples', 66),
#  ('frame', 66),
#  ('1981', 66),
#  ('front', 66),
#  ('Professor', 66),
#  ('1808', 65),
#  ('player', 65),
#  ('Accelerator', 65),
#  ('Military', 65),
#  ('1982', 65),
#  ('1949', 65),
#  ('Queen', 65),
#  ('July', 65),
#  ('architectural', 65),
#  ('Brunswick', 65),
#  ('student', 65),
#  ('walls', 65),
#  ('1962', 65),
#  ('Association', 64),
#  ('1844', 64),
#  ('1812', 64),
#  ('snow', 64),
#  ('Clarke', 64),
#  ('Oak', 64),
#  ('1934', 64),
#  ('Poe', 64),
#  ('Michael', 64),
#  ('Crowds', 64),
#  ('team', 64),
#  ('c1866', 64),
#  ('Chesapeake', 64),
#  ('sonatas', 63),
#  ('America', 63),
#  ('Theodore', 63),
#  ('Oklahoma', 63),
#  ('Continuing', 63),
#  ('night', 63),
#  ('Grove', 63),
#  ('quartets', 63),
#  ('since', 62),
#  ('Horsemanship', 62),
#  ('rural', 62),
#  ('Fayette', 62),
#  ('woman', 62),
#  ('1818', 62),
#  ('Stone', 62),
#  ('Shannon', 62),
#  ('state', 62),
#  ('Canada', 62),
#  ('Rivers', 62),
#  ('Manassas', 62),
#  ('1823', 62),
#  ('Room', 62),
#  ('Tuskegee', 62),
#  ('Built', 62),
#  ('Trio', 62),
#  ('Maria', 62),
#  ('work', 61),
#  ('class', 61),
#  ('center', 61),
#  ('Wives', 61),
#  ('Schmidt', 61),
#  ('Bible', 61),
#  ('1836', 61),
#  ('1831', 61),
#  ('451', 60),
#  ('Weber', 60),
#  ('Boxer', 60),
#  ('tape', 60),
#  ('Red', 60),
#  ('Hancock', 60),
#  ('Affairs', 60),
#  ('Sons', 60),
#  ('1898', 60),
#  ('mostly', 60),
#  ('Funeral', 60),
#  ('Charlotte', 60),
#  ('1786', 59),
#  ('1983', 59),
#  ('c1889', 59),
#  ('98', 59),
#  ('Orchards', 59),
#  ('Moore', 59),
#  ('Tyler', 59),
#  ('Underwood', 59),
#  ('Mark', 58),
#  ('1851', 58),
#  ('Alpha', 58),
#  ('1988', 58),
#  ('Duke', 58),
#  ('Water', 58),
#  ('Benjamin', 58),
#  ('1820', 58),
#  ('Shakespeare', 58),
#  ('Parties', 58),
#  ('Herbaceous', 58),
#  ('One', 58),
#  ('Landscapes', 58),
#  ('Printed', 58),
#  ('Canning', 57),
#  ('Law', 57),
#  ('lower', 57),
#  ('statue', 57),
#  ('Maryland', 57),
#  ('1853', 57),
#  ('exhibits', 57),
#  ('Edwards', 57),
#  ('trade', 57),
#  ('Canned', 57),
#  ('Woodberry', 57),
#  ('1834', 57),
#  ('Howard', 57),
#  ('Biology', 56),
#  ('1843', 56),
#  ('1933', 56),
#  ('1894', 56),
#  ('Evans', 56),
#  ('Department', 56),
#  ('1817', 56),
#  ('Blue', 56),
#  ('1932', 56),
#  ('two', 56),
#  ('Classrooms', 56),
#  ('Travis', 56),
#  ('CRB', 56),
#  ('Cookery', 56),
#  ('Ash', 56),
#  ('Theta', 55),
#  ('Baton', 55),
#  ('Epsilon', 55),
#  ('1854', 55),
#  ('Dean', 55),
#  ('1806', 55),
#  ('half', 55),
#  ('Rouge', 55),
#  ('Robinson', 55),
#  ('Earl', 55),
#  ('Guadalupe', 55),
#  ('area', 55),
#  ('Clay', 55),
#  ('Relief', 54),
#  ('figures', 54),
#  ('approximately', 54),
#  ('slightly', 54),
#  ('Williamsburg', 54),
#  ('1779', 54),
#  ('Mayo', 54),
#  ('Greene', 54),
#  ...]

# %%
len(fd.most_common(100))
# Out:
# 100

# %%
colls = ["artstor","biodiv","rumsey","commonwealth","georgia","harvard",
        "ia","getty","kentucky","minnesota","missouri","mwdl",
        "nara","nocar","smiths","socar","texas","gpo","illinois","usc","virginia","nocoll"]

import pickle

for c in colls:
    p = pickle.load( open( "/media/storage/dpla-data/pickles/"+c+".p", "rb" ) )
    print("\nGathering Stats for " + c)
    stats = p[c]['stats']
    print(stats)
    print("percent unique:")
    print(round((p[c]['stats']['uniq'] / p[c]['stats']['wc']),5), "%") 
    print("filtered percent unique:")
    print(round((p[c]['stats']['funiq'] / p[c]['stats']['fwc']),5), "%")
    print("*********")
# Out:
# Gathering Stats for artstor
# {'uniq': 60760, 'wc': 8466030, 'funiq': 60635, 'fwc': 6518566}
# percent unique:
# 0.00718 %
# filtered percent unique:
# 0.0093 %
# *********
#
# Gathering Stats for biodiv
# {'uniq': 94755, 'wc': 8361216, 'funiq': 94631, 'fwc': 7638579}
# percent unique:
# 0.01133 %
# filtered percent unique:
# 0.01239 %
# *********
#
# Gathering Stats for rumsey
# {'uniq': 47763, 'wc': 15404401, 'funiq': 47643, 'fwc': 12562369}
# percent unique:
# 0.0031 %
# filtered percent unique:
# 0.00379 %
# *********
#
# Gathering Stats for commonwealth
# {'uniq': 205346, 'wc': 17539494, 'funiq': 205220, 'fwc': 14865660}
# percent unique:
# 0.01171 %
# filtered percent unique:
# 0.0138 %
# *********
#
# Gathering Stats for georgia
# {'uniq': 151906, 'wc': 53640439, 'funiq': 151779, 'fwc': 44265379}
# percent unique:
# 0.00283 %
# filtered percent unique:
# 0.00343 %
# *********
#
# Gathering Stats for harvard
# {'uniq': 36383, 'wc': 1245233, 'funiq': 36265, 'fwc': 1126322}
# percent unique:
# 0.02922 %
# filtered percent unique:
# 0.0322 %
# *********
#
# Gathering Stats for ia
# {'uniq': 504635, 'wc': 29337722, 'funiq': 504508, 'fwc': 23046102}
# percent unique:
# 0.0172 %
# filtered percent unique:
# 0.02189 %
# *********
#
# Gathering Stats for getty
# {'uniq': 54848, 'wc': 24917539, 'funiq': 54729, 'fwc': 20435912}
# percent unique:
# 0.0022 %
# filtered percent unique:
# 0.00268 %
# *********
#
# Gathering Stats for kentucky
# {'uniq': 30759, 'wc': 11329055, 'funiq': 30635, 'fwc': 8724306}
# percent unique:
# 0.00272 %
# filtered percent unique:
# 0.00351 %
# *********
#
# Gathering Stats for minnesota
# {'uniq': 44443, 'wc': 5401682, 'funiq': 44318, 'fwc': 4505477}
# percent unique:
# 0.00823 %
# filtered percent unique:
# 0.00984 %
# *********
#
# Gathering Stats for missouri
# {'uniq': 120872, 'wc': 5586540, 'funiq': 120745, 'fwc': 4871754}
# percent unique:
# 0.02164 %
# filtered percent unique:
# 0.02478 %
# *********
#
# Gathering Stats for mwdl
# {'uniq': 805127, 'wc': 140177464, 'funiq': 805000, 'fwc': 116446303}
# percent unique:
# 0.00574 %
# filtered percent unique:
# 0.00691 %
# *********
#
# Gathering Stats for nara
# {'uniq': 1082259, 'wc': 65649116, 'funiq': 1082133, 'fwc': 54355031}
# percent unique:
# 0.01649 %
# filtered percent unique:
# 0.01991 %
# *********
#
# Gathering Stats for nocar
# {'uniq': 258151, 'wc': 33487819, 'funiq': 258024, 'fwc': 27360155}
# percent unique:
# 0.00771 %
# filtered percent unique:
# 0.00943 %
# *********
#
# Gathering Stats for smiths
# {'uniq': 432406, 'wc': 59927374, 'funiq': 432279, 'fwc': 51922316}
# percent unique:
# 0.00722 %
# filtered percent unique:
# 0.00833 %
# *********
#
# Gathering Stats for socar
# {'uniq': 61813, 'wc': 7138136, 'funiq': 61687, 'fwc': 5809794}
# percent unique:
# 0.00866 %
# filtered percent unique:
# 0.01062 %
# *********
#
# Gathering Stats for texas
# {'uniq': 855720, 'wc': 88574895, 'funiq': 855594, 'fwc': 72699549}
# percent unique:
# 0.00966 %
# filtered percent unique:
# 0.01177 %
# *********
#
# Gathering Stats for gpo
# {'uniq': 437770, 'wc': 26316103, 'funiq': 437646, 'fwc': 21860075}
# percent unique:
# 0.01664 %
# filtered percent unique:
# 0.02002 %
# *********
#
# Gathering Stats for illinois
# {'uniq': 49143, 'wc': 2385501, 'funiq': 49018, 'fwc': 1829267}
# percent unique:
# 0.0206 %
# filtered percent unique:
# 0.0268 %
# *********
#
# Gathering Stats for usc
# {'uniq': 259650, 'wc': 49296854, 'funiq': 259523, 'fwc': 41542851}
# percent unique:
# 0.00527 %
# filtered percent unique:
# 0.00625 %
# *********
#
# Gathering Stats for virginia
# {'uniq': 41493, 'wc': 2248517, 'funiq': 41374, 'fwc': 1790985}
# percent unique:
# 0.01845 %
# filtered percent unique:
# 0.0231 %
# *********
#
# Gathering Stats for nocoll
# {'uniq': 1867, 'wc': 6192, 'funiq': 1785, 'fwc': 4626}
# percent unique:
# 0.30152 %
# filtered percent unique:
# 0.38586 %
# *********

# %%
#type(fd)
#haps = fd.hapaxes()
len(fd.hapaxes())
# Out:
# 32902

# %%
longwords = {}
for k,v in fd.items():
    if len(k) > 10: longwords[k] = v

# %%
longwords
# Out:
# {'Accelerator': 65,
#  'Accessories': 120,
#  'Accomodates': 2,
#  'Accompanying': 1,
#  'Adjustments': 1,
#  'Administration': 2,
#  'Administrative': 13,
#  'Adminstration': 1,
#  'Aduertissement': 1,
#  'Advertisement': 2,
#  'Advertising': 5,
#  'Aerodynamics': 2,
#  'Aeronautical': 5,
#  'Aeronautics': 37,
#  'Agricultural': 303,
#  'Agriculture': 13,
#  'Alterations': 1,
#  'Amabassador': 1,
#  'Amazonenvitt': 1,
#  'Amphitheater': 2,
#  'Amphitheaters': 9,
#  'Amphitheatre': 43,
#  'Ampitheatre': 4,
#  'Amstelodami': 1,
#  'Anniversaries': 5,
#  'Anniversary': 22,
#  'Announcement': 1,
#  'Antiquities': 2,
#  'Apologetics': 1,
#  'Apparizione': 1,
#  'Appointment': 1,
#  'Archdeacons': 1,
#  'Architectural': 313,
#  'Architecture': 1012,
#  'Aristomenes': 1,
#  'Arrangements': 1,
#  'Assassination': 2,
#  'Association': 64,
#  'Associations': 7,
#  'Astronomical': 1,
#  'Auditoriums': 4,
#  'Aufforderung': 4,
#  'Automobiles': 351,
#  'Automoblies': 1,
#  'Badarzewska': 3,
#  'Balustrades': 5,
#  'Barboursville': 18,
#  'Barcarolles': 2,
#  'Barhamsville': 12,
#  'Bartholomew': 6,
#  'Battlements': 1,
#  'Baylorsville': 5,
#  'Beaujoyeulx': 1,
#  'Beckenstein': 3,
#  'Beuckenstein': 2,
#  'Bibliographical': 1,
#  'Bibliopolas': 1,
#  'Biscaccianti': 1,
#  'Bishopville': 2,
#  'Bjørnstjerne': 1,
#  'Blackboards': 6,
#  'Blacksmiths': 1,
#  'Blankenship': 2,
#  'Blennerhassett': 1,
#  'Blessington': 2,
#  'Bloomington': 1,
#  'Blumentritt': 1,
#  'Bodybuilders': 41,
#  'Bodybuilding': 4,
#  'Bonaventure': 2,
#  'Bonnycastle': 1,
#  'Bookbinders': 2,
#  'Bookbinding': 2,
#  'Bookshelves': 2,
#  'Brandeville': 1,
#  'Brandstetter': 3,
#  'Breckinridge': 2,
#  'Bridegrooms': 24,
#  'Bridgeforth': 1,
#  'Bridgewater': 1,
#  'Brockenbraugh': 1,
#  'Brownsville': 23,
#  'Brueschweiler': 1,
#  'Buentivolio': 1,
#  'Businessmen': 1,
#  'Butterflies': 1,
#  'COLLECTIONS': 1,
#  'Cadwallader': 1,
#  'Calcografia': 1,
#  'Calculating': 1,
#  'Cannonballs': 1,
#  'Canzonettas': 1,
#  'Cartersville': 39,
#  'Cartographic': 2,
#  'Castiglione': 4,
#  'Catholiques': 1,
#  'Cazouillement': 1,
#  'Celebration': 27,
#  'Celebrations': 3,
#  'Certificate': 2,
#  'Certificates': 2,
#  'Chamberlain': 9,
#  'Chamberlayne': 20,
#  'Chancellors': 1,
#  'Chandeliers': 2,
#  'Charakterstu': 1,
#  'Charlemagne': 2,
#  'Charlestown': 1,
#  'Charlottesviile': 1,
#  'Charlottesville': 54329,
#  'Chartseller': 1,
#  'Chatterbrick': 1,
#  'Chesterfield': 139,
#  'Christening': 3,
#  'Christianity': 2,
#  'Christiansburg': 11,
#  'Christopher': 14,
#  'Churchyards': 1,
#  'Clarksville': 2,
#  'Classification': 1,
#  'Clatterbrick': 1,
#  'Clinchfield': 2,
#  'Clotheslines': 1,
#  'Cobblestone': 1,
#  'Collections': 26682,
#  'Combination': 1,
#  'Commencement': 24,
#  'Commencements': 14,
#  'Commentaires': 1,
#  'Commisioner': 1,
#  'Commissioned': 2,
#  'Commissioner': 1,
#  'Commissioners': 3,
#  'Commisssioners': 1,
#  'Comparative': 1,
#  'Competition': 1,
#  'Confederacy': 1,
#  'Confederate': 52,
#  'Conferences': 71,
#  'Confidentially': 1,
#  'Confirmation': 1,
#  'Confirmations': 1,
#  'Congregation': 2,
#  'Congressional': 2,
#  'Conservatories': 1,
#  'Considerations': 1,
#  'Consolation': 2,
#  'Consolidated': 14,
#  'Consolidating': 1,
#  'Constantine': 2,
#  'Constitution': 2,
#  'Constitutional': 1,
#  'Construction': 114,
#  'Continental': 8,
#  'Continuation': 3,
#  'Contreblasons': 1,
#  'Convenience': 1,
#  'Conversation': 1,
#  'Convocation': 3,
#  'Cooperation': 8,
#  'Cooperative': 20,
#  'Coopersmith': 1,
#  'Coordinated': 1,
#  'Cornachione': 1,
#  'Coronations': 2,
#  'Corporation': 11,
#  'Corporations': 1,
#  'Corporative': 1,
#  'Correctional': 1,
#  'Corrections': 1,
#  'Correspondence': 1,
#  'Corrugating': 5,
#  'Cosmographie': 1,
#  'Cosstaphney': 1,
#  'Courlaender': 1,
#  'Courthouses': 32,
#  'Cowperthwait': 1,
#  'Critchenberger': 2,
#  'Critenbarger': 2,
#  'Crutchfield': 2,
#  'Dardensburg': 1,
#  'Declaration': 36,
#  'Declaratory': 2,
#  'Decorations': 2,
#  'Dedications': 1,
#  'Demonstation': 1,
#  'Demonstration': 32,
#  'Demonstrations': 16,
#  'Demonstrator': 1,
#  'Demonstrators': 1,
#  'Departments': 1,
#  'Description': 15,
#  'Destruction': 1,
#  'Development': 12,
#  'Diepenbeeck': 1,
#  'Discoloration': 3,
#  'Dispensations': 2,
#  'Disposition': 1,
#  'Distinguished': 10,
#  'Distributed': 2,
#  'Divertissement': 1,
#  'Documentary': 3,
#  'Dodelinette': 1,
#  'Dormitories': 100,
#  'Dressmakers': 2,
#  'Dressmaking': 1,
#  'Dunfermline': 1,
#  'Educational': 15,
#  'Electricity': 2,
#  'Elefterious': 1,
#  'Emancipation': 2,
#  'Embroidering': 1,
#  'Encarnacion': 1,
#  'Enchantment': 1,
#  'Encyclopaedia': 2,
#  'Engineering': 144,
#  'Entablatures': 1,
#  'Entertainers': 2,
#  'Entertainment': 46,
#  'Environments': 44,
#  'Equestrians': 3,
#  'Ergenbright': 2,
#  'Establishment': 3,
#  'Estudiantina': 1,
#  'Eternamente': 1,
#  'Euangelistes': 1,
#  'Eucharistie': 1,
#  'Evangelical': 2,
#  'Exhibitions': 135,
#  'Experimental': 25,
#  'Fairgrounds': 3,
#  'Fantasiestu': 3,
#  'Faschingsschwank': 1,
#  'Fayerweather': 28,
#  'Fayetteville': 19,
#  'Fenchtenberger': 1,
#  'Fieuberlake': 1,
#  'Fiskerjenten': 1,
#  'Fitzpatrick': 4,
#  'Fleetstreet': 8,
#  'Folkelivsbilleder': 1,
#  'Fontainebleau': 2,
#  'Footbridges': 4,
#  'Foraarstoner': 1,
#  'Fortification': 6,
#  'Fortifications': 1,
#  'Foundations': 8,
#  'Fountainebleau': 1,
#  'Fraternities': 39,
#  'Fredericksburg': 23,
#  'Freemasonry': 8,
#  'Freiligrath': 1,
#  'Friedenwald': 1,
#  'Furnishings': 18,
#  'Gainesville': 1,
#  'Gainsborough': 1,
#  'Gallicanism': 1,
#  'Gendarmerie': 1,
#  'Generations': 2,
#  'Geographical': 2,
#  'Giambattista': 1,
#  'Gildersleeve': 16,
#  'Gillenwater': 3,
#  'Goldschmetterlinge': 1,
#  'Goldschmidt': 1,
#  'Gordonsville': 1,
#  'Granddaughter': 1,
#  'Grandfather': 3,
#  'Grandfathers': 2,
#  'Grandmother': 4,
#  'Grandmothers': 1,
#  'Grandparents': 1,
#  'Grandsaigne': 1,
#  'Grandstands': 14,
#  'Graniteville': 1,
#  'Greeleyville': 6,
#  'Greenhouses': 2,
#  'Greensville': 3,
#  'Grigorʹevich': 1,
#  'Grillparzer': 3,
#  'Groundbreakings': 4,
#  'Hairdressing': 4,
#  'Hallettsville': 4,
#  'Hammarstrand': 2,
#  'Hanfstaengl': 1,
#  'Harpsichord': 26,
#  'Harrisonburg': 8,
#  'Hattiesburg': 11,
#  'Headquarters': 3,
#  'Hecatongraphie': 1,
#  'Hendrickson': 2,
#  'Heppenheimer': 2,
#  'Herrodsburg': 1,
#  'Herzallerliebsten': 2,
#  'Hetherington': 2,
#  'Hippocrates': 2,
#  'Hirondelles': 1,
#  'Historiarum': 1,
#  'Hodgkinsonne': 1,
#  'Hollingsworth': 2,
#  'Homesickness': 1,
#  'Honeysuckle': 1,
#  'Horsemanship': 62,
#  'Hortenstein': 1,
#  'Hortensteine': 1,
#  'Horticultural': 3,
#  'Horticulture': 7,
#  'Humoresques': 2,
#  'Hydrographer': 1,
#  'Hydrographical': 2,
#  'Identifying': 18,
#  'Illustrated': 2,
#  'Illustrations': 2,
#  'Improvement': 11,
#  'Improvisations': 1,
#  'Inaguration': 1,
#  'Inauguration': 17,
#  'Incorporated': 2,
#  'Independance': 1,
#  'Independence': 32,
#  'Independent': 6,
#  'Indianapolis': 4,
#  'Industrialization': 1,
#  'Infirmaries': 3,
#  'Information': 44,
#  'Infrastructural': 9,
#  'Infrastructure': 1,
#  'Inheritance': 1,
#  'Inscriptions': 1,
#  'Institution': 1,
#  'Institutional': 778,
#  'Institutions': 1,
#  'Instruction': 1,
#  'Instrumental': 1,
#  'Insurrection': 1,
#  'Integration': 1,
#  'Intelligence': 1,
#  'Interallied': 1,
#  'Intermediate': 1,
#  'International': 2,
#  'Internationally': 2,
#  'Interscholastic': 1,
#  'Intersection': 1,
#  'Intracoastal': 1,
#  'Introduktion': 1,
#  'Investigation': 1,
#  'Jacksonville': 17,
#  'JeanesTeachers': 1,
#  'Jeffersonville': 1,
#  'Katzenstein': 1,
#  'Kiinderscenen': 1,
#  'Kindergarten': 4,
#  'Kinderscenen': 1,
#  'Kirkpatrick': 2,
#  'Knickerbockers': 1,
#  'Kompositionen': 1,
#  'Laboratories': 13,
#  'Lamentations': 1,
#  'Landscaping': 1,
#  'Lawrenceville': 71,
#  'Legislative': 2,
#  'Legislators': 1,
#  'Legislature': 2,
#  'Lescribleur': 1,
#  'Letterheads': 2,
#  'Liebestrank': 1,
#  'Liebestraum': 1,
#  'Liebeswonne': 1,
#  'Lindencrone': 1,
#  'Lindenmeyer': 1,
#  'Lindpaintner': 3,
#  'Litchtenberg': 1,
#  'Lithographed': 3,
#  'Lithographic': 2,
#  'Lithographing': 2,
#  'Lithographs': 22,
#  'Lithography': 3,
#  'Livingstone': 4,
#  'Locomotives': 21,
#  'Mademoiselle': 1,
#  'Madisonville': 2,
#  'Mandolinata': 1,
#  'Mantelpiece': 2,
#  'Manufactures': 1,
#  'Manufacturing': 3,
#  'Manuscripts': 1,
#  'Marguerites': 1,
#  'Marigliotta': 2,
#  'Marketplaces': 10,
#  'Marlborough': 2,
#  'Marseillaise': 1,
#  'Masquerades': 2,
#  'Massachusetts': 12,
#  'Mathematics': 1,
#  'Maximillian': 7,
#  'McMinnville': 2,
#  'Mecklenburg': 1,
#  'Mediterranei': 2,
#  'Medringhaus': 2,
#  'Meistersinger': 2,
#  'Membranophones': 3,
#  'Mendelssohn': 29,
#  'Menosprecio': 1,
#  'Meriwtether': 1,
#  'Metalworking': 2,
#  'Middelburgum': 1,
#  'Middleditch': 2,
#  'Miscellaneous': 3,
#  'Missionaries': 3,
#  'Mississippi': 291,
#  'Mollenhauer': 2,
#  'Mondenschein': 1,
#  'Monseigneur': 2,
#  'Montecastle': 2,
#  'Montmorency': 1,
#  'Morningside': 6,
#  'Morrissette': 1,
#  'Mountaineer': 1,
#  'Multiplication': 1,
#  'Musikalische': 1,
#  'Napolitaine': 1,
#  'Naturalization': 1,
#  'Nebuchadnezzar': 1,
#  'Neighborhood': 2,
#  'Netherlands': 13,
#  'Newfoundland': 1,
#  'Newspictures': 3,
#  'Nightengale': 1,
#  'Nightingale': 3,
#  'Nonprescription': 1,
#  'Nonprojected': 3,
#  'Northampton': 24,
#  'Northumberland': 1,
#  'Northwestern': 1,
#  'Nouuellement': 3,
#  'Nullification': 1,
#  'Observatories': 10,
#  'Observatory': 17,
#  'Occidentales': 1,
#  'Occidentalioribus': 1,
#  'Offertories': 5,
#  'Opernthemas': 1,
#  'Oppugnation': 1,
#  'Organisations': 1,
#  'Organizations': 4,
#  'Orientation': 9,
#  'Orthography': 4,
#  'Outbuilding': 1,
#  'Outbuildings': 19,
#  'Outerbridge': 9,
#  'Outstanding': 1,
#  'Overexposed': 2,
#  'Oxfordshire': 21,
#  'Pagenstecker': 1,
#  'Pantagrueline': 2,
#  'Paraphrases': 1,
#  'Participation': 1,
#  'Pedestrians': 3,
#  'Penitential': 2,
#  'Pennsylvania': 35,
#  'Pennyslvania': 1,
#  'Pensilvania': 1,
#  'Performances': 12,
#  'Periodicals': 13,
#  'Peterborough': 1,
#  'Philadelphia': 743,
#  'Phildelphia': 1,
#  'Phillibrown': 16,
#  'Photocopies': 5,
#  'Photographed': 1,
#  'Photographers': 40,
#  'Photographic': 10,
#  'Photographs': 5524,
#  'Photography': 5521,
#  'Photogravure': 1,
#  'Photogravures': 223,
#  'Piccolomini': 1,
#  'Plaetsnyder': 1,
#  'Plantations': 4,
#  'Playgrounds': 17,
#  'Polytechnical': 2,
#  'Poniatowski': 1,
#  'Poplarville': 8,
#  'Posselwhite': 3,
#  'Preliminary': 3,
#  'Presbyteriain': 1,
#  'Presbyterian': 3,
#  'Presbyterians': 1,
#  'Presentation': 3,
#  'Presentazione': 1,
#  'Presidential': 16,
#  'Printseller': 9,
#  'Printsellers': 1,
#  'Privateering': 1,
#  'Proceedings': 1,
#  'Processions': 28,
#  'Prohibition': 4,
#  'Propagation': 1,
#  'Proprietors': 1,
#  'Protectionism': 1,
#  'Protestantism': 1,
#  'Protestation': 1,
#  'Psychotropic': 1,
#  'Publications': 5,
#  'Punchinello': 1,
#  'Punctuation': 1,
#  'Quesenberry': 1,
#  'RailroadCompany': 1,
#  'Rappahannock': 7,
#  'Ravenscroft': 1,
#  'Recollections': 1,
#  'Reconciliation': 1,
#  'Reconstruction': 3,
#  'Recreational': 10,
#  'Reflections': 1,
#  'Reformation': 1,
#  'Reformatories': 4,
#  'Reformatory': 8,
#  'Refreshments': 1,
#  'Refridgerators': 1,
#  'Refrigerator': 1,
#  'Refrigerators': 3,
#  'Registration': 19,
#  'Regulations': 1,
#  'Rehabilitation': 2,
#  'Remembrance': 1,
#  'Reminiscences': 2,
#  'Remonstrance': 4,
#  'Rentiesville': 2,
#  'Representations': 3,
#  'Residential': 1,
#  'Restaurants': 14,
#  'Restoration': 5,
#  'Resurrection': 2,
#  'Revolutionary': 2,
#  'Rheinberger': 3,
#  'Ritournelle': 1,
#  'Rittenhouse': 3,
#  'Riverfronts': 2,
#  'Rockefeller': 2,
#  'Rondolettos': 1,
#  'Rorzwaukaski': 2,
#  'Rosenbecker': 1,
#  'Rudersdorff': 2,
#  'Saltonstall': 2,
#  'Sandersville': 24,
#  'Satterfield': 1,
#  'Satterthwaite': 3,
#  'Saunnaituis': 2,
#  'Scarborough': 1,
#  'Scharfenberg': 13,
#  'Schleiffarth': 1,
#  'Schlepegrell': 1,
#  'Schlesinger': 1,
#  'Schnatterly': 1,
#  'Schoolbuildings': 1,
#  'Schoolhouse': 15,
#  'Schottisches': 17,
#  'Schottishce': 1,
#  'Schwalbenbotschaft': 1,
#  'Schwanengesang': 10,
#  'Searchlights': 1,
#  'Sebastianum': 1,
#  'Segregation': 18,
#  'Seneviratne': 1,
#  'Sesquicentennial': 7,
#  'Settlements': 45,
#  'Seventeenth': 4,
#  'Shackelford': 12,
#  'Shackleford': 2,
#  'Shaftesbury': 2,
#  'Shakespeare': 58,
#  'Shakespearean': 2,
#  'Shepherdstown': 3,
#  'Sherrington': 2,
#  'Shipbuilding': 1,
#  'Shoalwalter': 1,
#  'Silhouettes': 11,
#  'Smokestacks': 1,
#  'Somersville': 2,
#  'Sommernachtstraum': 2,
#  'Southampton': 10,
#  'Southwestern': 3,
#  'Spielmannslieder': 1,
#  'Spotslyvania': 1,
#  'Spotsylvania': 9,
#  'Spottsylvania': 1,
#  'Springfield': 6,
#  'Stadtkirche': 1,
#  'Stalactites': 3,
#  'Stallknecht': 2,
#  'Stepmothers': 1,
#  'Stereoscope': 1,
#  'Stereoscopic': 2,
#  'Stockbridge': 2,
#  'Storefronts': 3,
#  'Storytellers': 1,
#  'Streetscapes': 3,
#  'Stringfellow': 8,
#  'Stringfield': 1,
#  'Superintendent': 120,
#  'Superintendents': 12,
#  'Supervising': 2,
#  'Supervisors': 1,
#  'Supterintendent': 1,
#  'Surrounding': 2,
#  'Switzerland': 13,
#  'Tablecloths': 2,
#  'Tallahassee': 13,
#  'Tanzmomente': 1,
#  'Tanzskizzen': 1,
#  'Tappahannock': 1,
#  'Tarantellas': 3,
#  'Tchaikovsky': 2,
#  'Terraqueous': 1,
#  'Territorial': 2,
#  'Teschemacher': 1,
#  'Testimonial': 1,
#  'Thanksgiving': 1,
#  'Theological': 21,
#  'Therapentics': 1,
#  'Therapeutics': 2,
#  'Theyendanagea': 1,
#  'Thomasville': 1,
#  'Thunderbolt': 5,
#  'Tillinghast': 1,
#  'Timmonsville': 1,
#  'Topographic': 1,
#  'Topographical': 2,
#  'Transfusion': 1,
#  'Transilvania': 1,
#  'Translating': 1,
#  'Transparencies': 23,
#  'Transportation': 35,
#  'Transvestism': 28,
#  'Triosonatas': 1,
#  'Typographos': 1,
#  'Ueberwasser': 1,
#  'Unaccompanied': 10,
#  'Undentified': 1,
#  'Undergraduate': 8,
#  'Undergraduates': 8,
#  'Underground': 12,
#  'Unidentfied': 1,
#  'Unidentifed': 9,
#  'Unidentified': 718,
#  'Universitat': 1,
#  'Universities': 262,
#  'Universitut': 1,
#  'Universtity': 1,
#  'Unsatisfactory': 2,
#  'Unterhaltung': 1,
#  'Variationen': 1,
#  'Velimirovic': 2,
#  'Versification': 3,
#  'Villefranche': 1,
#  'Violoncello': 2,
#  'VirginiaFraternity': 1,
#  'Waccowochie': 1,
#  'Wagenknight': 3,
#  'Wallerstein': 3,
#  'Washingtons': 1,
#  'Watercolors': 3,
#  'Waterfronts': 3,
#  'Watermelons': 30,
#  'Weatherford': 2,
#  'Weissenborn': 1,
#  'Wertenbacker': 1,
#  'Wertenbaker': 12,
#  'Westerville': 1,
#  'Westmoreland': 4,
#  'Wheelbarrows': 5,
#  'Wheelchairs': 1,
#  'Wheelwright': 1,
#  'Wheelwrights': 1,
#  'Whitechurch': 1,
#  'Wiggleworth': 2,
#  'Williamsburg': 54,
#  'Williamsport': 2,
#  'Winsborough': 1,
#  'Winterhalter': 1,
#  'Wollenhaupt': 8,
#  'Woodworking': 13,
#  'Worthington': 4,
#  'Wrigglesworth': 2,
#  'accelerator': 1,
#  'accessories': 6,
#  'accommodating': 2,
#  'accommodations': 8,
#  'administration': 27,
#  'administrators': 2,
#  'adolescence': 1,
#  'advertisement': 2,
#  'advertising': 2,
#  'agricultural': 27,
#  'agriculture': 5,
#  'anniversary': 7,
#  'appassionata': 1,
#  'application': 1,
#  'appreciation': 1,
#  'approximately': 54,
#  'archeuesque': 2,
#  'architectural': 65,
#  'architecture': 317,
#  'artistiques': 1,
#  'association': 1,
#  'associations': 3,
#  'authorities': 2,
#  'automobiles': 1,
#  'automoblile': 1,
#  'battlefield': 1,
#  'beautifying': 3,
#  'benediction': 1,
#  'bottomlands': 1,
#  'caertmaecker': 1,
#  'capriccioso': 3,
#  'cartographic': 363,
#  'celebrating': 1,
#  'celebration': 1,
#  'celebrations': 9,
#  'chrestienne': 1,
#  'clarissimum': 1,
#  'combination': 1,
#  'communications': 1,
#  'composition': 152,
#  'comprehension': 1,
#  'confirmirte': 1,
#  'congregation': 1,
#  'connections': 6,
#  'consequences': 1,
#  'conservatory': 1,
#  'consolation': 1,
#  'consolidated': 3,
#  'consolidation': 1,
#  'constructed': 1,
#  'construction': 153,
#  'convocation': 2,
#  'cornerstone': 1,
#  'cultivation': 1,
#  'damoyselles': 1,
#  'declaration': 3,
#  'declination': 1,
#  'dedications': 1,
#  'deliberately': 1,
#  'demonstrates': 1,
#  'demonstration': 19,
#  'demonstrator': 1,
#  'demonstrators': 1,
#  'departments': 1,
#  'deportemens': 1,
#  'description': 4,
#  'destruction': 1,
#  'detereriorating': 5,
#  'deterioraing': 1,
#  'deteriorate': 1,
#  'deteriorating': 129,
#  'deterioration': 2,
#  'development': 21,
#  'developments': 1,
#  'dignitaries': 1,
#  'dilapidated': 1,
#  'disciplines': 10,
#  'discoloration': 22,
#  'discolorations': 1,
#  'discoveries': 4,
#  'disposition': 1,
#  'distinguished': 1,
#  'diversified': 7,
#  'educational': 1,
#  'eliminating': 1,
#  'engineering': 5,
#  'enseignemens': 1,
#  'enterprises': 3,
#  'entertainers': 4,
#  'entertainment': 2,
#  'environment': 1,
#  'environments': 9,
#  'eradicating': 1,
#  'exhibitions': 1,
#  'exploration': 3,
#  'expositions': 3,
#  'facinoribus': 1,
#  'furnishings': 2,
#  'generations': 1,
#  'geographischen': 1,
#  'governments': 1,
#  'granddaughter': 1,
#  'groundbreaking': 20,
#  'handwriting': 2,
#  'harpsichord': 3,
#  'headquarters': 1,
#  'hecatodistichon': 2,
#  'hlingsglaube': 1,
#  'horizontally': 2,
#  'hydrographica': 2,
#  'identifiable': 6,
#  'identifying': 1,
#  'illustrissime': 1,
#  'importables': 1,
#  'improvement': 9,
#  'improvements': 6,
#  'inauguration': 1,
#  'independant': 1,
#  'information': 15905,
#  'inhabitants': 1,
#  'inscription': 1,
#  'installation': 1,
#  'institution': 2,
#  'institutions': 2,
#  'instruction': 2,
#  'instructives': 1,
#  'instrumental': 451,
#  'instruments': 25,
#  'insurrections': 1,
#  'intellectual': 1,
#  'interdisciplinary': 2,
#  'interesting': 1,
#  'interjacentiumq': 1,
#  'interpretation': 1,
#  'interpreting': 1,
#  'introductio': 1,
#  'irregularly': 1,
#  'irresesitible': 1,
#  'irresistable': 1,
#  'lVniuersite': 1,
#  'laboratories': 1,
#  'laboratoryatue': 1,
#  'legislation': 2,
#  'legislature': 1,
#  'linstitution': 1,
#  'lithographer': 1,
#  'lithographs': 1,
#  'locomotives': 1,
#  'magnificence': 1,
#  'magnificque': 2,
#  'manufacture': 1,
#  'manufacturer': 1,
#  'manufacturing': 1,
#  'mathematics': 3,
#  'membranophones': 1,
#  'mercimoniis': 1,
#  'merveilleux': 1,
#  'mousquetaire': 1,
#  'napolitaine': 1,
#  'naturalization': 1,
#  'neighborhood': 3,
#  'nightingale': 1,
#  'nouuellement': 1,
#  'nstlerleben': 1,
#  'observations': 1,
#  'obstruction': 5,
#  'opportunity': 1,
#  'organization': 2,
#  'orientalioribus': 1,
#  'orientation': 2,
#  'oscilloscope': 1,
#  'overagainst': 1,
#  'overlooking': 1,
#  'participate': 1,
#  'particularly': 1,
#  'performances': 1,
#  'periodicals': 1,
#  'photographic': 10376,
#  'photographs': 6040,
#  'photography': 7,
#  'picturesque': 1,
#  'plantations': 2,
#  'practically': 1,
#  'predominantly': 1,
#  'preparation': 2,
#  'presentation': 5,
#  'principales': 1,
#  'printmaking': 1,
#  'productions': 32,
#  'prognostication': 2,
#  'progressives': 1,
#  'promptuaire': 1,
#  'promulgation': 1,
#  'prononciation': 1,
#  'provinciarum': 3,
#  'publication': 1,
#  'quarterback': 5,
#  'recognizable': 1,
#  'reconstruction': 7,
#  'recreations': 1,
#  'refreshments': 1,
#  'regulations': 1,
#  'relationship': 250,
#  'remembering': 1,
#  'representatives': 2,
#  'reproduction': 1,
#  'reproductions': 48,
#  'resiouissance': 2,
#  'respectibus': 1,
#  'resplendent': 1,
#  'restrictions': 5518,
#  'resurrection': 1,
#  'reverendissime': 1,
#  'sacrificateur': 1,
#  'sanctissima': 1,
#  'satisfactory': 3,
#  'schoolbuildings': 29,
#  'schottische': 3,
#  'sentimentale': 1,
#  'septemtrionale': 1,
#  'septentrionale': 1,
#  'settlements': 16,
#  'shareholder': 1,
#  'shopkeepers': 1,
#  'siciliennes': 1,
#  'sioujssances': 2,
#  'slenderness': 1,
#  'spectabilis': 1,
#  'spirituelles': 1,
#  'stalagmites': 3,
#  'stockholders': 1,
#  'strengthened': 1,
#  'subdivision': 1,
#  'superintendence': 1,
#  'supervising': 2,
#  'supervisors': 1,
#  'supplementary': 1,
#  'surrounding': 5,
#  'sweethearts': 2,
#  'temperaments': 1,
#  'temptations': 1,
#  'territories': 3,
#  'thanksgiving': 1,
#  'theological': 1,
#  'topographical': 1,
#  'traditional': 1,
#  'transgressions': 2,
#  'transparencies': 31,
#  'transportation': 3,
#  'transported': 2,
#  'transporting': 4,
#  'treschrestien': 5,
#  'tresexcellente': 1,
#  'tresillustre': 1,
#  'trespuissant': 1,
#  'triangulation': 1,
#  'triumphante': 3,
#  'ultracentrifuge': 2,
#  'unclassified': 1,
#  'undentified': 3,
#  'underground': 1,
#  'undernourished': 1,
#  'unidentifed': 4,
#  'unidentifiable': 1,
#  'unidentified': 146,
#  'universities': 1,
#  'unprotected': 1,
#  'unrecognizable': 1,
#  'ventilating': 1,
#  'vingthuictieme': 1,
#  'violoncello': 30,
#  'violoncellos': 1,
#  'waterfronts': 2,
#  'watermelons': 7,
#  'weatherboarded': 1,
#  'whitewashing': 1}

# %%
filtered['ia']['stats']
# Out:
# {'funiq': 504508, 'fwc': 23046102, 'uniq': 504635, 'wc': 29337722}

# %%
print(percent unique:)
filtered['ia']['stats']['uniq'] / filtered['ia']['stats']['wc']
print(filtered percent unique:)
filtered['ia']['stats']['funiq'] / filtered['ia']['stats']['fwc']

# %%
import nltk
text = nltk.Text(filtered)

# %%
#next (iter (filtered.keys()))
type(filtered['harvard']['filtered'])
# Out:
# list

# %%
from nltk.collocations import *
finder = BigramCollocationFinder.from_words(filtered['ia']['filtered'])
bigram_measures = nltk.collocations.BigramAssocMeasures()
scored = finder.score_ngrams(bigram_measures.raw_freq)
sorted(bigram for bigram, score in scored)

# %%
#This thing here just hangs forevs. I wonder if it's possible to do it without the notebook?
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = BigramCollocationFinder.from_words(filteredgpo)
finder.nbest(bigram_measures.pmi, 10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b9fb691b9028> in <module>()
#       3 trigram_measures = nltk.collocations.TrigramAssocMeasures()
#       4 finder = BigramCollocationFinder.from_words(filteredgpo)
# ----> 5 finder.nbest(bigram_measures.pmi, 10)
#
# /home/charper/anaconda/envs/py3k/lib/python3.3/site-packages/nltk/collocations.py in nbest(self, score_fn, n)
#     110     def nbest(self, score_fn, n):
#     111         """Returns the top n ngrams when scored by the given function."""
# --> 112         return [p for p, s in self.score_ngrams(score_fn)[:n]]
#     113
#     114     def above_score(self, score_fn, min_score):
#
# /home/charper/anaconda/envs/py3k/lib/python3.3/site-packages/nltk/collocations.py in score_ngrams(self, score_fn)
#     106         lowest score, as determined by the scoring function provided.
#     107         """
# --> 108         return sorted(self._score_ngrams(score_fn), key=lambda t: (-t[1], t[0]))
#     109
#     110     def nbest(self, score_fn, n):
#
# /home/charper/anaconda/envs/py3k/lib/python3.3/site-packages/nltk/collocations.py in _score_ngrams(self, score_fn)
#      98         """
#      99         for tup in self.ngram_fd:
# --> 100             score = self.score_ngram(score_fn, *tup)
#     101             if score is not None:
#     102                 yield tup, score
#
# /home/charper/anaconda/envs/py3k/lib/python3.3/site-packages/nltk/collocations.py in score_ngram(self, score_fn, w1, w2)
#     161         a factor of 1/(window_size - 1).
#     162         """
# --> 163         n_all = self.word_fd.N()
#     164         n_ii = self.ngram_fd[(w1, w2)] / (self.window_size - 1.0)
#     165         if not n_ii:
#
# /home/charper/anaconda/envs/py3k/lib/python3.3/site-packages/nltk/probability.py in N(self)
#     115         :rtype: int
#     116         """
# --> 117         return sum(self.values())
#     118
#     119     def B(self):
#
# KeyboardInterrupt:

# %%
import pickle
import nltk

colls = ["biodiv","rumsey","commonwealth","georgia","harvard",
        "ia","getty","kentucky","minnesota","missouri","mwdl",
        "nara","nocar","smiths","socar","texas","gpo","illinois",
         "usc","virginia","nocoll"]

#colls = ["biodiv"]

fd = pickle.load( open( "/media/storage/dpla-data/pickles/new/artstor_fd.p", "rb" ) )
fds = {}
print(len(fd))
for coll in colls:
    tmp = pickle.load( open( "/media/storage/dpla-data/pickles/new/"+coll+"_fd.p", "rb" ) )
    print("updating FD with " + coll)
    fds[coll] = tmp
    fd.update(tmp)
    print(len(fd))
# Out:
# 60168
# updating FD with biodiv
# 131704
# updating FD with rumsey
# 153719
# updating FD with commonwealth
# 323186
# updating FD with georgia
# 428524
# updating FD with harvard
# 444294
# updating FD with ia
# 853180
# updating FD with getty
# 874037
# updating FD with kentucky
# 879550
# updating FD with minnesota
# 892810
# updating FD with missouri
# 965647
# updating FD with mwdl
# 1589542
# updating FD with nara
# 2556336
# updating FD with nocar
# 2689928
# updating FD with smiths
# 2948721
# updating FD with socar
# 2960280
# updating FD with texas
# 3709827
# updating FD with gpo
# 4056106
# updating FD with illinois
# 4066429
# updating FD with usc
# 4167642
# updating FD with virginia
# 4193316
# updating FD with nocoll
# 4193393

# %%
fd.most_common()
# Out:
# [('library', 6117895),
#  ('university', 4474393),
#  ('digital', 4393278),
#  ('county', 4101874),
#  ('archives', 3912296),
#  ('image', 3856146),
#  ('http', 3622052),
#  ('utah', 3508437),
#  ('texas', 3088382),
#  ('states', 3034554),
#  ('united', 2980122),
#  ('records', 2940508),
#  ('collection', 2933041),
#  ('edu', 2869869),
#  ('text', 2743094),
#  ('u', 2735080),
#  ('1', 2651930),
#  ('national', 2627569),
#  ('use', 2369332),
#  ('c', 2323676),
#  ('state', 2222489),
#  ('office', 2198024),
#  ('libraries', 2112146),
#  ('north', 2089362),
#  ('carolina', 2021982),
#  ('georgia', 2013630),
#  ('ark', 1940101),
#  ('california', 1810572),
#  ('images', 1793602),
#  ('unt', 1793154),
#  ('history', 1785922),
#  ('public', 1720702),
#  ('department', 1687369),
#  ('english', 1663863),
#  ('southern', 1559202),
#  ('death', 1533958),
#  ('d', 1516996),
#  ('copyright', 1463445),
#  ('67531', 1454858),
#  ('photographs', 1451551),
#  ('texashistory', 1432924),
#  ('information', 1398449),
#  ('washington', 1308460),
#  ('x', 1220153),
#  ('smithsonian', 1199436),
#  ('available', 1197530),
#  ('research', 1195215),
#  ('center', 1163841),
#  ('government', 1150791),
#  ('institution', 1147249),
#  ('collections', 1140774),
#  ('content', 1116803),
#  ('newspapers', 1106143),
#  ('west', 1094535),
#  ('ga', 1093339),
#  ('ut', 1090170),
#  ('administration', 1068841),
#  ('college', 1065094),
#  ('los', 1059295),
#  ('angeles', 1047333),
#  ('photograph', 1045279),
#  ('ca', 1025436),
#  ('local', 1007516),
#  ('census', 1003194),
#  ('terms', 996437),
#  ('service', 988342),
#  ('portal', 967273),
#  ('american', 961283),
#  ('mountain', 960732),
#  ('may', 940055),
#  ('made', 934848),
#  ('statistics', 914170),
#  ('special', 886509),
#  ('defense', 868309),
#  ('disk', 866632),
#  ('ed', 862066),
#  ('p', 856817),
#  ('vital', 853095),
#  ('agency', 852556),
#  ('2', 845176),
#  ('5', 841400),
#  ('archive', 839173),
#  ('gordon', 826933),
#  ('usc', 782346),
#  ('museum', 775978),
#  ('see', 773608),
#  ('historical', 772560),
#  ('dept', 764440),
#  ('j', 761928),
#  ('n', 757319),
#  ('magnetic', 747803),
#  ('title', 747283),
#  ('tex', 734878),
#  ('america', 722533),
#  ('photographic', 721011),
#  ('part', 719264),
#  ('including', 718627),
#  ('1905', 715122),
#  ('3', 713008),
#  ('unrestricted', 706048),
#  ('contact', 677717),
#  ('w', 676065),
#  ('md', 668947),
#  ('study', 664102),
#  ('park', 663796),
#  ('nmnh', 649509),
#  ('maps', 647804),
#  ('b', 643911),
#  ('cgi', 641422),
#  ('10', 638652),
#  ('south', 635438),
#  ('secretary', 634762),
#  ('1958', 631306),
#  ('4', 625355),
#  ('newspaper', 620590),
#  ('please', 616244),
#  ('map', 613643),
#  ('01', 606953),
#  ('include', 605423),
#  ('1939', 605294),
#  ('permission', 602815),
#  ('new', 602509),
#  ('anthropology', 597459),
#  ('project', 587240),
#  ('private', 587021),
#  ('created', 583921),
#  ('org', 582788),
#  ('2008', 579928),
#  ('8', 579199),
#  ('lib', 571698),
#  ('certificates', 567808),
#  ('rights', 566483),
#  ('certificate', 560875),
#  ('health', 560430),
#  ('contents', 559924),
#  ('e', 557717),
#  ('heritage', 550587),
#  ('cm', 549198),
#  ('atlanta', 547042),
#  ('teaching', 544659),
#  ('botany', 542307),
#  ('7', 541722),
#  ('full', 537197),
#  ('general', 523510),
#  ('sound', 516121),
#  ('holding', 515365),
#  ('video', 507502),
#  ('11', 504369),
#  ('society', 501581),
#  ('12', 498668),
#  ('calhoun', 494892),
#  ('gpo', 492130),
#  ('2007', 489677),
#  ('17', 484438),
#  ('recordings', 484166),
#  ('mission', 482853),
#  ('publicly', 481311),
#  ('partners', 480262),
#  ('thumbnail', 477850),
#  ('itemurl', 477639),
#  ('thumbnailurl', 477639),
#  ('advertising', 475246),
#  ('art', 473332),
#  ('identifier', 473008),
#  ('pictures', 472344),
#  ('domain', 471126),
#  ('military', 469395),
#  ('l', 467158),
#  ('h', 466419),
#  ('assigned', 465535),
#  ('specol', 465295),
#  ('still', 463899),
#  ('material', 462158),
#  ('memorial', 461098),
#  ('city', 455185),
#  ('us', 444041),
#  ('boston', 440872),
#  ('war', 438395),
#  ('includes', 433659),
#  ('resource', 432396),
#  ('number', 432306),
#  ('213', 415973),
#  ('news', 411263),
#  ('arizona', 409384),
#  ('internet', 408349),
#  ('21', 406888),
#  ('law', 406216),
#  ('m', 401417),
#  ('de', 400958),
#  ('bureau', 392174),
#  ('print', 385810),
#  ('john', 385392),
#  ('laws', 385150),
#  ('22', 381806),
#  ('www', 379402),
#  ('white', 378232),
#  ('business', 378114),
#  ('90089', 377826),
#  ('20', 376706),
#  ('13', 376208),
#  ('massachusetts', 375639),
#  ('files', 374845),
#  ('daily', 372969),
#  ('09', 372792),
#  ('january', 371526),
#  ('1921', 368779),
#  ('item', 368361),
#  ('wpa', 368349),
#  ('03', 366716),
#  ('century', 365267),
#  ('doheny', 364968),
#  ('drive', 364385),
#  ('0189', 363865),
#  ('household', 363696),
#  ('commercial', 363215),
#  ('international', 361430),
#  ('02', 361132),
#  ('division', 359732),
#  ('kentucky', 358883),
#  ('15', 357764),
#  ('school', 356600),
#  ('inc', 355061),
#  ('printing', 353855),
#  ('gov', 352039),
#  ('16', 348978),
#  ('hard', 348575),
#  ('lake', 344570),
#  ('6', 343146),
#  ('documents', 339507),
#  ('06', 335715),
#  ('07', 335134),
#  ('14', 334743),
#  ('file', 334434),
#  ('page', 332226),
#  ('05', 331733),
#  ('9', 329820),
#  ('places', 328713),
#  ('04', 328619),
#  ('institute', 328372),
#  ('1982', 325214),
#  ('1994', 325061),
#  ('f', 324959),
#  ('air', 324400),
#  ('oclc', 322550),
#  ('purposes', 322339),
#  ('vol', 321707),
#  ('protection', 321439),
#  ('getty', 320777),
#  ('bin', 320732),
#  ('works', 320621),
#  ('hutzel', 315352),
#  ('died', 315245),
#  ('house', 314953),
#  ('forces', 314721),
#  ('g', 314565),
#  ('r', 314401),
#  ('visual', 312926),
#  ('18', 311659),
#  ('black', 310081),
#  ('24', 309774),
#  ('agreement', 308813),
#  ('23', 307921),
#  ('one', 307763),
#  ('2006', 304967),
#  ('company', 303990),
#  ('retained', 303438),
#  ('services', 302549),
#  ('education', 301797),
#  ('intellectual', 301731),
#  ('photo', 301328),
#  ('hill', 301178),
#  ('30', 300117),
#  ('35', 299784),
#  ('cont', 297790),
#  ('reserve', 297783),
#  ('2014', 297528),
#  ('cards', 295644),
#  ('pages', 294533),
#  ('st', 293662),
#  ('exceptions', 293184),
#  ('25', 292434),
#  ('view', 290866),
#  ('housing', 289670),
#  ('finance', 287345),
#  ('improve', 285861),
#  ('combined', 283872),
#  ('proof', 283816),
#  ('access', 283798),
#  ('san', 282709),
#  ('district', 282093),
#  ('development', 281951),
#  ('08', 281868),
#  ('fill', 280758),
#  ('street', 280641),
#  ('certification', 279874),
#  ('1960', 279644),
#  ('gaps', 278142),
#  ('management', 277529),
#  ('familysearch', 277402),
#  ('indexesresults', 277397),
#  ('runwhat', 277397),
#  ('idxfiles', 277397),
#  ('keypath', 277397),
#  ('v', 277391),
#  ('william', 275976),
#  ('2011', 275061),
#  ('economics', 271972),
#  ('geography', 271143),
#  ('online', 268800),
#  ('forest', 268767),
#  ('2013', 267752),
#  ('materials', 266942),
#  ('communications', 266869),
#  ('book', 266353),
#  ('negative', 264987),
#  ('19', 264908),
#  ('salt', 264653),
#  ('plants', 264340),
#  ('28', 263042),
#  ('dpla', 262957),
#  ('color', 262938),
#  ('along', 262712),
#  ('environmental', 259654),
#  ('jones', 259337),
#  ('1940', 258904),
#  ('obituaries', 258478),
#  ('2000', 256307),
#  ('mm', 254211),
#  ('type', 254072),
#  ('virginia', 253372),
#  ('italy', 252068),
#  ('index', 251253),
#  ('athens', 250838),
#  ('program', 249468),
#  ('document', 249230),
#  ('must', 248981),
#  ('2003', 246499),
#  ('minnesota', 246439),
#  ('abilene', 245618),
#  ('26', 244854),
#  ('29', 243883),
#  ('register', 242169),
#  ('young', 241482),
#  ('early', 239921),
#  ('fax', 239667),
#  ('educational', 239320),
#  ('chapel', 238765),
#  ('co', 238304),
#  ('publications', 238114),
#  ('system', 236973),
#  ('periodicals', 235930),
#  ('plantae', 235889),
#  ('george', 234770),
#  ('publication', 233713),
#  ('association', 233414),
#  ('2001', 232500),
#  ('york', 232489),
#  ('html', 230373),
#  ('max', 230254),
#  ('two', 229834),
#  ('historic', 229645),
#  ('phone', 228783),
#  ('ocolc', 226412),
#  ('world', 225206),
#  ('board', 225179),
#  ('david', 225159),
#  ('zoology', 224905),
#  ('0', 224735),
#  ('digitized', 224072),
#  ('27', 223035),
#  ('leslie', 222591),
#  ('prints', 222392),
#  ('journalism', 221812),
#  ('survey', 221666),
#  ('events', 221545),
#  ('required', 220720),
#  ('published', 220199),
#  ('pictorial', 219600),
#  ('o', 219307),
#  ('report', 218246),
#  ('federal', 217026),
#  ('officials', 216327),
#  ('activities', 215985),
#  ('site', 212735),
#  ('lccn', 212473),
#  ('people', 212459),
#  ('2005', 212395),
#  ('negatives', 212081),
#  ('non', 211659),
#  ('1900', 210990),
#  ('life', 210606),
#  ('1990', 210331),
#  ('usa', 210289),
#  ('multimedia', 209791),
#  ('740', 209446),
#  ('reserved', 209199),
#  ('2010', 208823),
#  ('microfilm', 208575),
#  ('also', 207242),
#  ('flowering', 206963),
#  ('subject', 206775),
#  ('1920', 206671),
#  ('contentdm', 206566),
#  ('dallas', 206113),
#  ('ferns', 204716),
#  ('areas', 203520),
#  ('821', 203110),
#  ('relating', 202918),
#  ('2343', 201969),
#  ('2366', 201736),
#  ('1950', 200446),
#  ('atlas', 199019),
#  ('medical', 198449),
#  ('31', 197786),
#  ('cultural', 197434),
#  ('section', 197143),
#  ('without', 196840),
#  ('surveys', 196775),
#  ('portraits', 196242),
#  ('louis', 196128),
#  ('nc', 195737),
#  ('series', 195587),
#  ('ill', 195430),
#  ('church', 195243),
#  ('jan', 194458),
#  ('architecture', 193697),
#  ('paper', 192058),
#  ('james', 191054),
#  ('portrait', 190915),
#  ('net', 188361),
#  ('physical', 187254),
#  ('aug', 187237),
#  ('first', 187147),
#  ('river', 186862),
#  ('code', 186740),
#  ('agriculture', 186244),
#  ('electronic', 186066),
#  ('attorney', 185874),
#  ('building', 184663),
#  ('block', 184394),
#  ('courtesy', 184024),
#  ('commerce', 184016),
#  ('1860', 182868),
#  ('animalia', 182830),
#  ('handle', 182051),
#  ('resources', 181443),
#  ('relation', 181137),
#  ('protected', 180416),
#  ('civil', 180409),
#  ('design', 180214),
#  ('women', 179205),
#  ('dicotyledonae', 179177),
#  ('nevada', 179151),
#  ('interior', 179110),
#  ('social', 178571),
#  ('enumeration', 178186),
#  ('willard', 176096),
#  ('weekly', 175513),
#  ('family', 175324),
#  ('buildings', 175169),
#  ('space', 175042),
#  ('paul', 174826),
#  ('water', 174802),
#  ('box', 174733),
#  ('2004', 174469),
#  ('men', 174309),
#  ('card', 173753),
#  ('hdl', 173582),
#  ('work', 172733),
#  ('region', 172700),
#  ('personal', 172563),
#  ('accession', 171192),
#  ('marriott', 171158),
#  ('edward', 170423),
#  ('photography', 169921),
#  ('ethnology', 168295),
#  ('86', 167746),
#  ('help', 166729),
#  ('1947', 166686),
#  ('rumsey', 166593),
#  ('provided', 166261),
#  ('invertebrate', 165889),
#  ('charles', 165838),
#  ('10020', 165827),
#  ('jun', 165621),
#  ('descriptions', 165543),
#  ('indians', 165270),
#  ('regulations', 165133),
#  ('oct', 164313),
#  ('105', 163809),
#  ('2002', 162990),
#  ('fort', 162660),
#  ('language', 162111),
#  ('brigham', 161673),
#  ('student', 161631),
#  ('group', 161578),
#  ('scholarship', 161302),
#  ('missouri', 160794),
#  ('repository', 160549),
#  ('ink', 159649),
#  ('granted', 159447),
#  ('employee', 159238),
#  ('1945', 158703),
#  ('go', 157813),
#  ('right', 157809),
#  ('photographer', 157783),
#  ('press', 157356),
#  ('1910', 156652),
#  ('basel', 156514),
#  ('written', 156014),
#  ('governed', 155957),
#  ('received', 155705),
#  ('htm', 155475),
#  ('pursuant', 154863),
#  ('jul', 154733),
#  ('volumes', 154694),
#  ('clipping', 154343),
#  ('left', 154335),
#  ('unknown', 154220),
#  ('thomas', 154133),
#  ('field', 153549),
#  ('2009', 153404),
#  ('glass', 153129),
#  ('sep', 153080),
#  ('medieval', 152980),
#  ('idaho', 152927),
#  ('1930', 152870),
#  ('risk', 152495),
#  ('1911', 152192),
#  ('arte', 151898),
#  ('entomology', 151555),
#  ('etc', 150509),
#  ('2012', 150425),
#  ('antonio', 150363),
#  ('id', 149367),
#  ('used', 149299),
#  ('distribution', 149213),
#  ('indian', 149011),
#  ('public_domain_copyright_notice', 148603),
#  ('pdf', 148440),
#  ('dwellings', 148387),
#  ('foto', 147761),
#  ('minore', 147644),
#  ('jpg', 146458),
#  ('34', 146391),
#  ('customs', 146179),
#  ('freely', 146062),
#  ('gallery', 145645),
#  ('la', 145560),
#  ('brothers', 144934),
#  ('hosted', 144340),
#  ('area', 143776),
#  ('solely', 142953),
#  ('front', 142895),
#  ('students', 141998),
#  ('papers', 141136),
#  ('date', 140889),
#  ('byu', 140345),
#  ('displayed', 140175),
#  ('mexico', 140084),
#  ('cornell', 140057),
#  ('committee', 140028),
#  ('subsequent', 139334),
#  ('german', 139105),
#  ('1865', 138987),
#  ('1980', 138962),
#  ('property', 138813),
#  ('biodiversity', 138775),
#  ('bhl', 138362),
#  ('four', 137459),
#  ('118', 136952),
#  ('natural', 136814),
#  ('control', 136766),
#  ('commonwealth', 136381),
#  ('pencil', 136271),
#  ('east', 136139),
#  ('urban', 135941),
#  ('henry', 135170),
#  ('accordance', 134266),
#  ('reproduction', 133619),
#  ('landscape', 133579),
#  ('well', 133358),
#  ('el', 132876),
#  ('june', 132790),
#  ('children', 132419),
#  ('views', 132410),
#  ('1861', 132273),
#  ('lee', 131946),
#  ('pacific', 131651),
#  ('unit', 131097),
#  ('mass', 130764),
#  ('creative', 130420),
#  ('known', 130333),
#  ('collected', 129987),
#  ('address', 129929),
#  ('extensive', 129875),
#  ('mar', 129691),
#  ('born', 129618),
#  ('record', 129343),
#  ('held', 129204),
#  ('operations', 128698),
#  ('african', 128237),
#  ('presented', 128205),
#  ('searched', 127683),
#  ('electronically', 127637),
#  ('owning', 127478),
#  ('kyvl', 127243),
#  ('kdl', 127243),
#  ('illinois', 126520),
#  ('trust', 126373),
#  ('apr', 125606),
#  ('year', 125582),
#  ('sheet', 125238),
#  ('form', 125225),
#  ('y', 125130),
#  ('restrictions', 125105),
#  ('brown', 125012),
#  ('robert', 124580),
#  ('1931', 124444),
#  ('open', 124106),
#  ('army', 124086),
#  ('tewksbury', 123514),
#  ('1961', 122806),
#  ('inches', 122774),
#  ('1944', 122669),
#  ('1901', 122437),
#  ('geological', 122048),
#  ('americans', 121953),
#  ('unc', 121856),
#  ('silver', 121508),
#  ('data', 121190),
#  ('man', 121139),
#  ('identification', 121112),
#  ('greensboro', 121093),
#  ('letter', 121034),
#  ('original', 120867),
#  ('congress', 120865),
#  ('force', 120828),
#  ('economic', 120746),
#  ('web', 120539),
#  ('33', 120428),
#  ('1988', 120197),
#  ('version', 120127),
#  ('july', 120049),
#  ('smith', 119910),
#  ('wilson', 118842),
#  ('jackson', 118782),
#  ('postcards', 118525),
#  ('feb', 118024),
#  ('branch', 117825),
#  ('yale', 117823),
#  ('charleston', 117478),
#  ('marine', 117433),
#  ('march', 117428),
#  ('japan', 117362),
#  ('breckenridge', 117142),
#  ('president', 116931),
#  ('journal', 116872),
#  ('1897', 116517),
#  ('austin', 116517),
#  ('20th', 116413),
#  ('geographic', 116068),
#  ('high', 115940),
#  ('underwood', 115422),
#  ('1929', 115352),
#  ('construction', 115301),
#  ('affairs', 114797),
#  ('dc', 114710),
#  ('cdm', 114165),
#  ('forms', 114104),
#  ('houston', 114065),
#  ('1968', 113695),
#  ('photographers', 113481),
#  ('galveston', 113434),
#  ('reproduced', 113272),
#  ('current', 112959),
#  ('day', 112493),
#  ('000', 112018),
#  ('mrs', 111773),
#  ('studio', 111396),
#  ('1977', 111183),
#  ('savannah', 110938),
#  ('commission', 110714),
#  ('columbia', 110364),
#  ('topographic', 110106),
#  ('arts', 110082),
#  ('annual', 110025),
#  ('near', 109753),
#  ('1913', 109285),
#  ('headquarters', 108867),
#  ('1898', 108827),
#  ('1870', 108769),
#  ('scale', 108352),
#  ('1884', 107901),
#  ('director', 107781),
#  ('hall', 107747),
#  ('arthropoda', 107737),
#  ('dec', 107661),
#  ('1974', 107275),
#  ('viewed', 106833),
#  ('1970', 106778),
#  ('impa', 106393),
#  ('joseph', 105617),
#  ('publishing', 105220),
#  ('1960s', 105116),
#  ('assignment', 105086),
#  ('commons', 105012),
#  ('campus', 104760),
#  ('johnson', 104500),
#  ('personnel', 104442),
#  ('regents', 104304),
#  ('gelatin', 104134),
#  ('case', 103803),
#  ('consortium', 103687),
#  ('navy', 103680),
#  ('cite', 103655),
#  ('1880', 103470),
#  ('paso', 103317),
#  ('almshouse', 103020),
#  ('montana', 102957),
#  ('attribution', 102937),
#  ('agricultural', 102773),
#  ('senate', 102581),
#  ('road', 102546),
#  ('printed', 102276),
#  ('french', 102025),
#  ('cooper', 101934),
#  ('1890', 101527),
#  ('postcard', 101328),
#  ('anderson', 101323),
#  ('film', 101230),
#  ('harold', 101015),
#  ('central', 100930),
#  ('18th', 100896),
#  ('screen', 100874),
#  ('sculpture', 100776),
#  ('station', 100669),
#  ('1967', 100337),
#  ('wpacards', 100170),
#  ('m38843', 99924),
#  ('home', 99757),
#  ('community', 99321),
#  ('unidentified', 99280),
#  ('1976', 99236),
#  ('nov', 99147),
#  ('objects', 99025),
#  ('legislature', 99007),
#  ('beyond', 98849),
#  ('des', 98797),
#  ('april', 98551),
#  ('nature', 98401),
#  ('bombus', 98357),
#  ('funds', 98269),
#  ('orange', 98133),
#  ('clark', 97991),
#  ('showing', 97933),
#  ('aircraft', 97735),
#  ('col', 97424),
#  ('fair', 97124),
#  ('september', 97042),
#  ('classified', 97042),
#  ('london', 96900),
#  ('1914', 96875),
#  ('october', 96659),
#  ('given', 96657),
#  ('three', 96618),
#  ('administrative', 96053),
#  ('monument', 95935),
#  ('et', 95815),
#  ('taylor', 95739),
#  ('supported', 95486),
#  ('old', 95416),
#  ('paris', 95191),
#  ('technology', 94990),
#  ('uses', 94581),
#  ('back', 94566),
#  ('valley', 94549),
#  ('photos', 94251),
#  ('post', 94063),
#  ('1909', 93737),
#  ('years', 93596),
#  ('saint', 93247),
#  ('1912', 93169),
#  ('province', 93153),
#  ('administrator', 93103),
#  ('mary', 93021),
#  ('western', 92921),
#  ('32', 92583),
#  ('documentation', 92467),
#  ('div', 92395),
#  ('mr', 91921),
#  ('obituary', 91676),
#  ('via', 91507),
#  ('transportation', 91502),
#  ('monuments', 91381),
#  ('science', 91042),
#  ('town', 90978),
#  ('africa', 90791),
#  ('mission21', 90786),
#  ('complex', 90711),
#  ('references', 90398),
#  ('documenting', 89892),
#  ('administered', 89517),
#  ('industry', 89006),
#  ('1904', 88889),
#  ('1985', 88667),
#  ('governor', 88513),
#  ('shows', 88507),
#  ('sa', 88390),
#  ('1917', 88367),
#  ('1938', 88319),
#  ('1934', 88316),
#  ('temple', 88292),
#  ('plant', 88071),
#  ('homeplace', 87990),
#  ('music', 87664),
#  ('lsta', 87615),
#  ('island', 87472),
#  ('com', 87179),
#  ('february', 86945),
#  ('1895', 86620),
#  ('woman', 86612),
#  ('uintah', 86384),
#  ('corps', 86376),
#  ('1936', 86243),
#  ('requests', 86169),
#  ('php', 86149),
#  ('herald', 86109),
#  ('architectural', 86035),
#  ('staff', 86024),
#  ('1949', 85957),
#  ('china', 85920),
#  ('renaissance', 85865),
#  ('1886', 85680),
#  ('november', 85606),
#  ('1918', 85453),
#  ('fire', 85333),
#  ('dr', 85104),
#  ('august', 84869),
#  ('native', 84753),
#  ('arthur', 84674),
#  ('legal', 84631),
#  ('medicine', 84585),
#  ('country', 84526),
#  ('1975', 84336),
#  ('asia', 84283),
#  ('1935', 84264),
#  ('land', 84007),
#  ('sc', 83995),
#  ('schools', 83983),
#  ('1907', 83978),
#  ('1951', 83959),
#  ('lowell', 83688),
#  ('assistant', 83635),
#  ('42', 83578),
#  ('intake', 83383),
#  ('1956', 83372),
#  ('specimen', 83361),
#  ('time', 83317),
#  ('description', 83261),
#  ('small', 83247),
#  ('1989', 83077),
#  ('result', 83032),
#  ('notes', 82788),
#  ('reno', 82539),
#  ('hewitt', 82525),
#  ('va', 82463),
#  ('tichnor', 82428),
#  ('photographed', 82332),
#  ('user', 82259),
#  ('1942', 82008),
#  ('obtained', 81803),
#  ('list', 81773),
#  ('baroque', 81668),
#  ('side', 81633),
#  ('appalachian', 81544),
#  ('ii', 81526),
#  ('organized', 81510),
#  ('1933', 81503),
#  ('programs', 81467),
#  ('licenses', 81248),
#  ('shipler', 81143),
#  ('ocean', 80955),
#  ('restricted', 80953),
#  ('1987', 80923),
#  ('frank', 80794),
#  ('hospital', 80752),
#  ('bibliographical', 80726),
#  ('sites', 80710),
#  ('1941', 80699),
#  ('creativecommons', 80600),
#  ('k', 80502),
#  ('confederate', 80171),
#  ('1915', 80024),
#  ('power', 79771),
#  ('walter', 79710),
#  ('december', 79684),
#  ('1850', 79519),
#  ('individuals', 79174),
#  ('prior', 79050),
#  ('1943', 79023),
#  ('eight', 79006),
#  ('red', 78747),
#  ('based', 78642),
#  ('1908', 78581),
#  ('gift', 78580),
#  ('class', 78575),
#  ('gothic', 78574),
#  ('archaeology', 78568),
#  ('richard', 78498),
#  ('issued', 78486),
#  ('session', 78459),
#  ('members', 78346),
#  ('romanesque', 78254),
#  ('geologic', 78225),
#  ('referred', 78141),
#  ('nail', 78137),
#  ('copy', 78007),
#  ('examiner', 77946),
#  ('1919', 77801),
#  ('sciences', 77626),
#  ('1972', 77583),
#  ('1906', 77495),
#  ('labor', 77399),
#  ('large', 77087),
#  ('gri', 77016),
#  ('1962', 76933),
#  ('politics', 76858),
#  ('express', 76795),
#  ('jr', 76613),
#  ('security', 76405),
#  ('scholar', 76358),
#  ('base', 76119),
#  ('standing', 76087),
#  ('worth', 75775),
#  ('opinions', 75772),
#  ('islands', 75771),
#  ('1903', 75761),
#  ('union', 75761),
#  ('nasa', 75756),
#  ('1923', 75604),
#  ('great', 75569),
#  ('free', 75110),
#  ('brenham', 75033),
#  ('40', 74960),
#  ('canyon', 74877),
#  ('anthropological', 74734),
#  ('1899', 74646),
#  ('creek', 74628),
#  ('romans', 74564),
#  ('1928', 74549),
#  ('otherwise', 74448),
#  ('france', 74395),
#  ('thorough', 74298),
#  ('background', 74195),
#  ('forests', 74118),
#  ('harvard', 74020),
#  ('1969', 73985),
#  ('artstor', 73982),
#  ('etruscans', 73875),
#  ('1922', 73858),
#  ('aerial', 73811),
#  ('1916', 73791),
#  ('support', 73740),
#  ('1937', 73734),
#  ('cat340573', 73646),
#  ('place', 73577),
#  ('1924', 73514),
#  ('fulton', 73489),
#  ('insects', 73347),
#  ('1946', 73079),
#  ('manuscript', 72832),
#  ('uncg', 72805),
#  ('training', 72779),
#  ('mail', 72687),
#  ('1963', 72645),
#  ('thursday', 72533),
#  ('second', 72314),
#  ('1955', 72212),
#  ('bastrop', 71902),
#  ('avenue', 71864),
#  ('1997', 71741),
#  ('ariz', 71521),
#  ('azlibrary', 71327),
#  ('1965', 71258),
#  ('application', 71055),
#  ('azmemory', 70966),
#  ('info', 70901),
#  ('correspondence', 70645),
#  ('1952', 70592),
#  ('order', 70491),
#  ('practices', 70254),
#  ('1954', 70162),
#  ('1953', 70149),
#  ('palmer', 69983),
#  ('uss', 69834),
#  ('1883', 69703),
#  ('format', 69689),
#  ('many', 69679),
#  ('harris', 69591),
#  ...]

# %%
len(fd.hapaxes())
# Out:
# 2773182

# %%
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
fd.hapaxes()
# Out:
# ['6674009',
#  '6674008',
#  'dfst8607980',
#  '6674005',
#  '6674004',
#  '6674007',
#  '6674006',
#  '6674001',
#  '6674000',
#  '6674003',
#  '6674002',
#  'pl10blk_c48489_a01',
#  'dnsc8903676',
#  '42448917207501000000',
#  'ahc071268004a',
#  '811763050',
#  '9780160791185',
#  'dischr',
#  '003075',
#  'twk36354',
#  'twk36355',
#  'twk36356',
#  'dischi',
#  'twk36350',
#  'twk36351',
#  'twk36352',
#  'twk36353',
#  '003076',
#  'twk36358',
#  'twk36359',
#  'cbs4891295_a01',
#  '59761145',
#  'prauty',
#  '83r_hcr35',
#  'ethruscarum',
#  '2011388147',
#  '2011388146',
#  '40_cfd_noaa_2004_3137_33_2_25_26_04_oeb_reception_dsc_7458',
#  '40_cfd_noaa_2004_3137_33_2_25_26_04_oeb_reception_dsc_7459',
#  'mihoya',
#  '40_cfd_noaa_2004_3137_33_2_25_26_04_oeb_reception_dsc_7457',
#  'wrightsofcolonia00lawr',
#  'ocm50640151',
#  '04741400',
#  '006073691',
#  'railwaymastermec26newy',
#  'proceedingsofaca60acad',
#  'sumrncr',
#  '5694177',
#  'dasc9109575',
#  'ocm53097702',
#  'ocm45266619',
#  'dasc9109573',
#  'kankobatsu',
#  '62421040r',
#  'iillcl',
#  '809562742',
#  'veilstripe',
#  '750398595',
#  '412_dsp_boldvacoastsurvey_058',
#  '412_dsp_boldvacoastsurvey_059',
#  '750398590',
#  '412_dsp_boldvacoastsurvey_054',
#  '412_dsp_boldvacoastsurvey_055',
#  '412_dsp_boldvacoastsurvey_056',
#  '412_dsp_boldvacoastsurvey_057',
#  '412_dsp_boldvacoastsurvey_050',
#  '412_dsp_boldvacoastsurvey_051',
#  '412_dsp_boldvacoastsurvey_052',
#  '412_dsp_boldvacoastsurvey_053',
#  '6413080',
#  'loolis',
#  'p0049_0044_0001_verso',
#  '6413081',
#  '5694354',
#  '5694355',
#  '5694356',
#  '5694357',
#  '5694350',
#  '5694351',
#  '5694352',
#  'lnounts',
#  'jounrey',
#  '5694358',
#  '5694359',
#  'beotis',
#  '128308745',
#  'genealogyoffolso1882chap',
#  'estigatio',
#  '2270037',
#  'ühotographer',
#  '664733554',
#  'biberhof',
#  '6413088',
#  '6413089',
#  'pomfretcookery00unse',
#  'notionsonchorogr00mace',
#  '39999063528458',
#  '39999063528457',
#  '1arec1c',
#  '39999057083980',
#  'ausstellungdeuts02deut',
#  '6651417',
#  '6651416',
#  '6651415',
#  '6651414',
#  '6651413',
#  'milestone1984sout',
#  '6651411',
#  '6651410',
#  '6651419',
#  '6651418',
#  'idx208420084803',
#  'idx208420084802',
#  'idx208420084801',
#  'idx208420084800',
#  'idx208420084807',
#  'idx208420084806',
#  'medallichistoryo01loub',
#  'idx208420084804',
#  'otl0s1',
#  'idx208420084809',
#  'idx208420084808',
#  'annualreportofbo1929bost',
#  'budget1993bost',
#  '9a1156cc726e0fc758155c79e79da649',
#  '6506715',
#  '6506717',
#  '6506716',
#  '6506711',
#  '6506710',
#  '6506713',
#  '6506712',
#  '6506719',
#  '6506718',
#  'memoirespourserv10lamb',
#  'manualofgreekarc00colliala',
#  'mb121_2_4_070f',
#  '40_cfd_noaa_2002_3137_112_dsc_1670',
#  '40_cfd_noaa_2002_3137_112_dsc_1671',
#  'annalesdelasoci45soci',
#  'bilabel',
#  '097540',
#  '097543',
#  '50611157',
#  '881292705',
#  'pl10blk_c48021_a01',
#  '42148441670200000000',
#  'idx208420218408',
#  'thropugh',
#  'annualreportofto1963roll',
#  'antiquitiesofeng08gros_0',
#  'ahc099223002a',
#  '56427797',
#  'wadconews22unse',
#  '42448902600020000000',
#  '39999052973094',
#  'rcinains',
#  'unitedstatestour00nati',
#  '204672',
#  'crindle',
#  'vedrai',
#  'vedran',
#  'naguere',
#  'zv8',
#  '6497408',
#  '6497409',
#  '748279946',
#  '6497404',
#  '6497405',
#  '6497406',
#  '6497407',
#  '6497400',
#  '6497401',
#  '6497402',
#  '6497403',
#  'idx208420180153',
#  'courstheoriqueet00capu',
#  'zv9',
#  '51730397',
#  '809794495',
#  'p0032_2_0071_0001',
#  '508446',
#  'zv6',
#  'rroind',
#  '5839494',
#  '5839496',
#  '5839490',
#  '5839492',
#  'dfst8904985',
#  'dfst8904984',
#  'dfst8904987',
#  'dfst8904986',
#  '5839498',
#  'implicationsofta00unit',
#  'dfst8904983',
#  'dfst8904982',
#  'dieverzierungsku00kuhn',
#  'palmateer',
#  'misc29',
#  'misc28',
#  '681393648',
#  'm51283',
#  'misc23',
#  'misc22',
#  'misc21',
#  'misc20',
#  'misc27',
#  'misc25',
#  'misc24',
#  '278729',
#  '278728',
#  'thomasskidmoresc00skid',
#  '278724',
#  'b637822c220b8f370ce6a7608a4fc6ae',
#  '278726',
#  '278721',
#  '278720',
#  '278723',
#  '278722',
#  'idx208420082423',
#  'idx208420082422',
#  'idx208420082421',
#  'idx208420082427',
#  'idx208420082426',
#  'idx208420082425',
#  'idx208420082424',
#  'idx208420082429',
#  'idx208420082428',
#  'ocm00416328',
#  'sheffieldtimesmj2009unse',
#  '6346717',
#  '6346716',
#  '6346715',
#  '6346714',
#  '6346712',
#  '6346711',
#  '6346710',
#  'dornii',
#  '6346719',
#  '34837942',
#  'вала',
#  '363068',
#  '237045272',
#  'zv3',
#  'fhp_400111432_michael',
#  'overviewofmassac00mass_0',
#  'trabajosdelmuseo28muse',
#  'hju638670f',
#  'wf2b',
#  '3o3p²',
#  'availabale',
#  'm51287',
#  'ciegas',
#  'dnst8408489',
#  'dnst8408488',
#  'dnst8408487',
#  'dnst8408485',
#  'dnst8408484',
#  '9780160784682',
#  'costyme',
#  'wellesleynews5412well',
#  '42448937150090000000',
#  'neuenhahni',
#  'zv1',
#  '39999023587494',
#  'avaa9a',
#  '1126273',
#  '1126270',
#  'ocm35393601',
#  'dnsd0610120',
#  'a991b652ccfaacc850d60337d72bc309',
#  'religionschool00wilm',
#  '42448903400010000000',
#  'annualreport1864swam',
#  '4486369',
#  '40_cfd_bis_2005_8484_20_dsc_6320',
#  '40_cfd_bis_2005_8484_20_dsc_6323',
#  '40_cfd_bis_2005_8484_20_dsc_6322',
#  '40_cfd_bis_2005_8484_20_dsc_6324',
#  '40_cfd_bis_2005_8484_20_dsc_6327',
#  '40_cfd_bis_2005_8484_20_dsc_6329',
#  '5435410',
#  '704436401',
#  'dividethe',
#  '522419',
#  'dasd0609257',
#  'smallbusinessacc00unit',
#  'vacareofchronica00unit',
#  'chcek',
#  'm47410',
#  '19157617',
#  'landfil2',
#  'lo1998008',
#  '19348141008000000000',
#  'russellburg',
#  'lo1998009',
#  'momeier',
#  'ocm54884349',
#  'm51288',
#  '45046368',
#  'cai0513',
#  'fl_1679_fco_171',
#  '755_046_016_01',
#  'aclmittecl',
#  'selentang',
#  '39999063156358',
#  '00958300',
#  'dfst8408469',
#  'dfst8408468',
#  'unclt',
#  'dfst8408464',
#  'dfst8408467',
#  'dfst8408466',
#  'dfst8408461',
#  'dfst8408463',
#  'idx208420133132',
#  'idx208420133133',
#  'idx208420133130',
#  'idx208420133131',
#  'idx208420133136',
#  'idx208420133137',
#  'idx208420133134',
#  'idx208420133135',
#  'acquaforte',
#  'idx208420133138',
#  'idx208420133139',
#  '227464',
#  '227465',
#  'bellestro',
#  '227460',
#  '0xf7bf7a0',
#  '5c4ecef823c4467935e8ab25449a82ad',
#  '08_06_000759',
#  '08_06_000758',
#  'idx208420023088',
#  'idx208420023089',
#  '08_06_000753',
#  '08_06_000752',
#  '08_06_000751',
#  '08_06_000750',
#  '08_06_000757',
#  '08_06_000756',
#  '08_06_000755',
#  '08_06_000754',
#  'culick',
#  '63_6_64_001',
#  '535520',
#  'cleuce',
#  '17cb6dfffe5f9f9ba7cf75b19783abf6',
#  '000621283',
#  'broadsides_bdsnc021665',
#  'lanatomiecompar01roul',
#  'dyamac',
#  'idx208420061172',
#  'idx208420061173',
#  'idx208420061170',
#  'idx208420061171',
#  'idx208420061176',
#  'idx208420061177',
#  'idx208420061174',
#  'idx208420061175',
#  'idx208420061178',
#  'idx208420061179',
#  '163812777',
#  'gm4052',
#  'gm4053',
#  'gm4050',
#  '06223300',
#  'valcan',
#  'gm4057',
#  'gm4055',
#  'gm4058',
#  '00000993_tn_0001',
#  'handbuchderkugel02heinuoft',
#  '11_07_000589',
#  '11_07_000588',
#  '11_07_000583',
#  '11_07_000582',
#  '11_07_000581',
#  '11_07_000580',
#  '11_07_000587',
#  '11_07_000586',
#  '11_07_000585',
#  '11_07_000584',
#  'pl10blk_c48315_004',
#  '04415200',
#  'pennyback',
#  'иллюстраторов',
#  'dnsc8701426',
#  'howesseraphineme00howe',
#  '557120',
#  'potentialeffects00marz',
#  '557123',
#  '557122',
#  '6378288',
#  'marketsizeininno00acem',
#  'dfst8803139',
#  '6378284',
#  'dnsn8205940',
#  '6378286',
#  '6378287',
#  '6378280',
#  '6378281',
#  '6378282',
#  '6378283',
#  'stationbulletin385newh',
#  'dnsc8701420',
#  '557126',
#  'progrchss',
#  '557129',
#  'tobacco_lpa72i00',
#  '4070162',
#  'qg__l',
#  'dasd0720183',
#  '03_dsc_0066_amb_bell_1_',
#  'arrepp',
#  'dasd0720186',
#  'anatomyphysiolog02bell_0',
#  '1041950',
#  'dnsc8701429',
#  '1041956',
#  '1041957',
#  '1041954',
#  '1041955',
#  'antidota',
#  'drouari',
#  'firstthreeyearso1885pere',
#  'southwesternmonu1956depa',
#  'ocm39201020',
#  'stooss',
#  '38994315',
#  'cicousky',
#  '5694353',
#  'stwvey',
#  '08_06_027941',
#  '08_06_027940',
#  '08_06_027943',
#  '08_06_027942',
#  '08_06_027945',
#  '08_06_027944',
#  '08_06_027947',
#  '08_06_027946',
#  '08_06_027949',
#  '08_06_027948',
#  'onelineofdescend1911cros',
#  'bysso',
#  'metris',
#  '58801579',
#  '40804704',
#  '534926',
#  '534927',
#  '534924',
#  '534923',
#  '534920',
#  '534921',
#  'osiandrum',
#  '534929',
#  '5835808',
#  '2049327',
#  'homecong',
#  'rrlls',
#  'journalofhygiene15nutt',
#  'winnipegw',
#  'idx208420265550',
#  'reu00031',
#  'througboot',
#  'ilclpful',
#  '5835807',
#  'comptesrendusheb158acad',
#  '1003428',
#  '183598141',
#  '554942',
#  'salahiyah',
#  'oursimmonsfamily00simm',
#  'kf09a0',
#  'bdry',
#  'bumoon',
#  'wirtschaftgebäude',
#  'bb26840',
#  'alfed',
#  'nc33532',
#  'ocm07537430',
#  '1003427',
#  'rescurcll',
#  'wri004127',
#  '76757878',
#  '814509242',
#  'dfsd0730913',
#  'saltriver1195',
#  'saltriver1194',
#  'dfsd0730912',
#  'strategichousing00chin',
#  '2433912',
#  'pierwszym',
#  '847862621',
#  'dfsd0730910',
#  'clemsonuniversit00cle_fr2',
#  'clemsonuniversit00cle_fr0',
#  'dfsd0730917',
#  '9781411333123',
#  'dfsd0730915',
#  '7303347',
#  '1040757',
#  'drebing',
#  '09653879',
#  'ocm47967579',
#  '2433919',
#  '2271222',
#  '06_10_014476a',
#  '06660900',
#  'annualreportofto1896goff',
#  'ncbddd',
#  'unpeeled',
#  'annualreportsfor1902bris',
#  '85786728',
#  'sesilia',
#  '171270',
#  '39999063529687',
#  '84x48',
#  'la_1603_powell_6198',
#  'bismarckbrunnen',
#  'whygodlovesirish00desm',
#  '320445893',
#  'annalsofhygiene5189penn',
#  'b20456724',
#  '6230544',
#  '40879031',
#  '754799957',
#  'ericeira',
#  'annualreport09newyuoft',
#  '210048455a01',
#  '316796579',
#  '237789201',
#  '237789204',
#  'ocm55036626',
#  'ocm48991355',
#  '003gg',
#  '379991',
#  '43272120',
#  '755_021_018_01',
#  'v12635',
#  'annualreporttown1918hins',
#  'ampelus',
#  'f7riyts',
#  'minacci',
#  'multifoil',
#  'bulletindelasocif0202soci',
#  '101506861',
#  'wellies',
#  '50610162',
#  'strandgebusch',
#  'ocm54407127',
#  'accounto32gooc',
#  'idx208420091687',
#  'shakeup',
#  'salonofnationale1896soci',
#  '881291350',
#  '644553739',
#  '5623710',
#  'dnsd0603004',
#  'dnsd0603006',
#  'dnsd0603007',
#  'dnsd0603000',
#  'dnsd0603001',
#  'dnsd0603002',
#  'cinnabaris',
#  'dnsd0603008',
#  'dnsd0603009',
#  'damonmemorialtod00damo',
#  '630070',
#  'chompré',
#  'kz6030',
#  '03073b59',
#  'koelem',
#  'raz1ng',
#  '6651412',
#  '00004414_tn_0001',
#  'prepositiones',
#  'resolutoria',
#  'srickland',
#  'dnst8502027',
#  '531270990',
#  'zamácola',
#  'jowl',
#  'annualreportvita1975mass',
#  'idx208420114309',
#  '45093507',
#  '45093505',
#  '914888',
#  'naturelo50londuoft',
#  'guja',
#  'sollennizare',
#  '42448902150030000000',
#  '2003016285',
#  '2003016281',
#  '2003016283',
#  '2003016282',
#  'sulpiciae',
#  'annualreportofse136566mass',
#  'indoctrinate',
#  'mb121_2_4_137f',
#  '90779',
#  '90778',
#  '90776',
#  '90774',
#  '90773',
#  '90772',
#  '90770',
#  '800012',
#  '800010',
#  'ocm37432394',
#  'cocorote',
#  '740006917',
#  '830541620',
#  '830541629',
#  'lemoniteuruniver18201825pari',
#  'fayettevillestat19871989',
#  '800018',
#  'consequcntly',
#  '800019',
#  'newluncls',
#  'idx208420253057',
#  'gm0778',
#  '58e0510ebe5daa24e74ba594f40990de',
#  'ấu',
#  'tamvita',
#  'oceanusv3604wood',
#  'dnst8904690',
#  'gm0772',
#  'thongrube',
#  'gm0771',
#  'mch0299',
#  'gm0770',
#  '194908',
#  'expletas',
#  '194906',
#  '194905',
#  '3937967',
#  '194903',
#  '194900',
#  '244440896',
#  '005224531',
#  'gm0775',
#  'gm0774',
#  'c754c',
#  'tespalaikaitesny00dion',
#  'narrtives',
#  '42448942050000000000',
#  '61230579',
#  '612826509',
#  'idx208420095571',
#  'idx208420095570',
#  'idx208420095573',
#  'idx208420095572',
#  'idx208420095575',
#  'idx208420095574',
#  'idx208420095577',
#  'idx208420095576',
#  'idx208420095579',
#  '51037751',
#  '233192257',
#  'dc_bpowersstudio',
#  '42148121016000000000',
#  '36326487',
#  '19900017056',
#  'molanus',
#  '256941',
#  '256943',
#  '006389206',
#  '006389207',
#  '006389203',
#  'industriegebäuden',
#  'annualreporttown1987camp',
#  'pict0848',
#  'chivous',
#  'usiiiess',
#  'annalsofsurgery74philuoft',
#  '08_06_020592',
#  'dnsn8402809',
#  'dnsn8402808',
#  'mch0298',
#  'p0027_0110_0001',
#  'annualization',
#  'dnsn8402803',
#  'lockharts',
#  'dnsn8402801',
#  'dnsn8402800',
#  'dnsn8402807',
#  'dnsn8402806',
#  'dnsn8402805',
#  'dnsn8402804',
#  '40_cfd_os_2003_1201_105_327',
#  'chloroformitspro00murp',
#  'ivestockspecialist',
#  'idx208420258431',
#  'idx208420258430',
#  'idx208420258433',
#  'idx208420258432',
#  'idx208420258435',
#  'idx208420258434',
#  'idx208420258437',
#  'idx208420258436',
#  'idx208420258439',
#  'idx208420258438',
#  'sprachrohr',
#  'dfsd0306400',
#  'sosnovy',
#  'dfsd0306402',
#  '1904238',
#  'dfsd0306404',
#  'tlielli',
#  'dfsd0306406',
#  'dfsd0306407',
#  'dfsd0306408',
#  'dfsd0306409',
#  '6393803',
#  '6393802',
#  '6393805',
#  '6393804',
#  '6393807',
#  'dfsd0207748',
#  '793114487',
#  '7305489',
#  '7305488',
#  'ciolden',
#  '7305486',
#  '7305485',
#  '7305484',
#  '7305482',
#  'pompejiinlebenun00mauaiala',
#  'callicrate',
#  'battlesleadersof04cent',
#  'p0044_0256_30825',
#  'chiritori',
#  '210048001b01',
#  'univers79cnse',
#  '5956228',
#  '9780160773921',
#  'tentcitydevelopm00bost',
#  'ralitifera',
#  'diketopiperazines',
#  '823650653',
#  '05204100',
#  'cratex',
#  '5625754',
#  '5625755',
#  '5625750',
#  'forstmässige',
#  '5625752',
#  '5625753',
#  'craten',
#  '5625758',
#  '5625759',
#  '635551780',
#  '47049120',
#  'gri_33125001428362',
#  'mnlc',
#  '528785605',
#  'idx208420030338',
#  'idx208420030339',
#  'chapaman',
#  'idx208420030332',
#  'idx208420030333',
#  'idx208420030330',
#  'idx208420030331',
#  'idx208420030336',
#  'idx208420030337',
#  'idx208420030334',
#  'idx208420030335',
#  'farmgate',
#  '39463297',
#  '265054052',
#  '03274200',
#  '6656830',
#  '6656831',
#  '50480188',
#  '6656833',
#  '6656834',
#  '6656835',
#  '6656836',
#  '6656837',
#  '6656838',
#  '6656839',
#  'la_1603_grinder_2534',
#  'kammerjungfer',
#  'diauoli',
#  'iiuness',
#  '06_10_002871',
#  '06_10_002870',
#  '06_10_002873',
#  '06_10_002872',
#  '06_10_002875',
#  '06_10_002874',
#  '06_10_002877',
#  '06_10_002876',
#  '06_10_002879',
#  '06_10_002878',
#  'slu_frost_campus_mercantile_plaza_1999_0001',
#  'thirdharbortunne06mass',
#  '23123716',
#  '2002004480',
#  '56519077',
#  'bierfaß',
#  'xyuu',
#  'dnst8510370',
#  '273117',
#  'brownalumnimonth973brow',
#  '6673273',
#  '6673272',
#  '6673271',
#  '6673270',
#  '6673277',
#  '6673276',
#  '6673275',
#  '6673274',
#  'betherun',
#  '6673278',
#  '70901669',
#  '64277111',
#  '276867974',
#  '006365914',
#  'bulletinundergraappa_0',
#  'sesquiterpenoids',
#  'atlpm0118',
#  'atlpm0119',
#  '47082098',
#  'univmary8485nse',
#  'arrieros',
#  'tobacco_hey27a00',
#  'idx208420120426',
#  'idx208420161603',
#  'idx208420161602',
#  'idx208420161601',
#  'idx208420161600',
#  'idx208420161607',
#  'idx208420161606',
#  'idx208420161605',
#  'idx208420161604',
#  'idx208420161609',
#  'idx208420161608',
#  'idx208420120422',
#  'idx208420202439',
#  'ahc170684001a',
#  'nhs_1900_0100',
#  'nhs_1900_0101',
#  'nhs_1900_0102',
#  'nhs_1900_0103',
#  'nhs_1900_0104',
#  'nhs_1900_0105',
#  'nhs_1900_0106',
#  'nhs_1900_0107',
#  'nhs_1900_0108',
#  'nhs_1900_0109',
#  '7fc6908ea4ba9ff089c4c7ce12fdb5bd',
#  '2001432234',
#  '543335',
#  'idx208420120428',
#  'dnsn8804201',
#  'dnsn8804200',
#  '5936127',
#  'db776',
#  'moscho',
#  '00002275_tn_0001',
#  '706489077',
#  'mosche',
#  '5936123',
#  '402570240',
#  '5928368',
#  '5928366',
#  '5928364',
#  '5928362',
#  '5928360',
#  'servizi',
#  '276361077',
#  '620548840',
#  'wellesleynews4021well',
#  '11934002',
#  'baydorfer',
#  '755_125_051_01',
#  '0081_charlie',
#  'laurenza_0097a',
#  'beestaerdige',
#  'reportonwaterfac00kenn',
#  '90b48067_009',
#  '39999063133217',
#  'methodofteaching02roll',
#  'remarksonsomeofp00quin',
#  'dasc0207071',
#  'puyvelde',
#  'dasc0207073',
#  'dasc0207072',
#  'escogar',
#  '90b48067_003',
#  'agricuitura',
#  'agricuiture',
#  'idx208420138380',
#  'idx208420138381',
#  'annualreportofto2009lond',
#  'idx208420138383',
#  'idx208420138384',
#  'idx208420138385',
#  'idx208420138386',
#  'idx208420138387',
#  'idx208420138388',
#  'idx208420138389',
#  '90b48067_007',
#  '39999055338642',
#  'cilllsr',
#  '95338',
#  'gnoged',
#  '882931411',
#  'gebusch',
#  '91016109',
#  'schwankung',
#  'operativegynecol001kell',
#  '95339',
#  'dagogie',
#  '203847',
#  'iv7',
#  '203845',
#  '3990331',
#  'dandelot',
#  '203841',
#  '6650249',
#  '6650248',
#  '34666960',
#  '6650245',
#  '6650244',
#  '6650247',
#  '6650246',
#  '6650241',
#  '6650240',
#  '6650243',
#  '6650242',
#  'cbs4891695_005',
#  '71213200',
#  '苏联的草原',
#  'wthe',
#  'lettertomydearma00chap28',
#  'lettertomydearma00chap29',
#  'lettertomydearma00chap24',
#  'lettertomydearma00chap25',
#  'lettertomydearma00chap26',
#  'lettertomydearma00chap27',
#  'lettertomydearma00chap20',
#  'lettertomydearma00chap21',
#  'lettertomydearma00chap22',
#  'lettertomydearma00chap23',
#  'miller_family_letters_b1f40',
#  '1040491',
#  'wthr',
#  'miller_family_letters_b1f41',
#  'miller_family_letters_b1f42',
#  'chb1264',
#  'miller_family_letters_b1f43',
#  'gimbled',
#  'miller_family_letters_b1f45',
#  'miller_family_letters_b1f46',
#  'miller_family_letters_b1f47',
#  '11111yc',
#  'rudolfoanayasble00tous',
#  'reber_thomas_b2f31_01',
#  'reber_thomas_b2f31_05',
#  'reber_thomas_b2f31_04',
#  'reber_thomas_b2f31_06',
#  'idx208420112703',
#  '861505092',
#  '5491387',
#  '05_1world_1water_1day_1047_11',
#  '9921800320001551',
#  '0160599806',
#  '06_10_014674',
#  '06_10_014675',
#  '06_10_014676',
#  '06_10_014677',
#  '06_10_014670',
#  '06_10_014671',
#  '06_10_014672',
#  '06_10_014673',
#  'tallasie',
#  '06_10_014678',
#  '06_10_014679',
#  'hldebran',
#  '6345349',
#  '6345348',
#  'sermonsdiscourse004atte',
#  '93033833',
#  '6345345',
#  '6345344',
#  '6345347',
#  '6345346',
#  '6345341',
#  '6345340',
#  '6345343',
#  '6345342',
#  '6704197',
#  '6704196',
#  '6704195',
#  '6704194',
#  ...]

# %%
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
texthaps = []
for hap in fd.hapaxes():
    if not hasNumbers(hap):
        texthaps.append(hap)
len(texthaps)
# Out:
# 392117

# %%
len(fd.hapaxes())
# Out:
# 2773182

# %%
texthaps
# Out:
# ['warngell',
#  'culora',
#  'rsctel',
#  'lmong',
#  'pesochnoe',
#  'feuilletonistinnen',
#  'fighterlike',
#  'abhauen',
#  'воспроизведенная',
#  'zuzu',
#  'faulche',
#  'domcapitels',
#  'unzeri',
#  'treeage',
#  'shackleman',
#  'auberon',
#  'zced',
#  'hydrophidae',
#  'zceo',
#  'zces',
#  'inoculator',
#  'faysvillle',
#  'djust',
#  'monalach',
#  'gandolfini',
#  'zhuanqu',
#  'punaise',
#  'ריצפת',
#  'sumti',
#  'ojbarik',
#  'tapagem',
#  'cliequeo',
#  'begründeten',
#  'begründeter',
#  'logological',
#  'tleral',
#  'kaititja',
#  'auctam',
#  'tabaksbeutel',
#  'kuhhirten',
#  'lollment',
#  'evanced',
#  'wiebner',
#  'frequentissime',
#  'guipússcoa',
#  'jingiing',
#  'offbase',
#  'maaws',
#  'staaken',
#  'prebischthor',
#  'machrol',
#  'nrlal',
#  'hamlem',
#  'ultsi',
#  'renselear',
#  'boöjo',
#  'ariant',
#  'partini',
#  'reimb',
#  'reime',
#  'reimp',
#  'itlcli',
#  'emcompasses',
#  'gabnamp',
#  'contingencey',
#  'seriou',
#  'masti',
#  'mastg',
#  'serion',
#  'seriol',
#  'nephrorrhaphie',
#  'зачислен',
#  'ätzung',
#  'printpages',
#  'toimittanut',
#  'gilleth',
#  'wunderliche',
#  'onilitions',
#  'annlial',
#  'ultramarion',
#  'ullcst',
#  'importnnce',
#  'chiquiros',
#  'metrides',
#  'iioltslcs',
#  'weberites',
#  'cvalue',
#  'ionicus',
#  'natisone',
#  'wtore',
#  'verdaken',
#  'clustalw',
#  'chartfin',
#  'ilncle',
#  'ilncll',
#  'hosd',
#  'soehnholz',
#  'sororium',
#  'cynanchica',
#  'moderism',
#  'tonici',
#  'gridmultivariable',
#  'naissin',
#  'daquelles',
#  'nmping',
#  'lnnnp',
#  'heilungsmittel',
#  'beney',
#  'anschliessung',
#  'fonoroff',
#  'johnamerican',
#  'monekana',
#  'nuvada',
#  'ortioii',
#  'aperi',
#  'protecti',
#  'buarque',
#  'gumirakiza',
#  'cheban',
#  'harklus',
#  'idocus',
#  'burinsky',
#  'burpean',
#  'topraksu',
#  'conventionaled',
#  'blowpipes',
#  'brogun',
#  'oyesters',
#  'purgen',
#  'fellhorn',
#  'parademarsch',
#  'jackstein',
#  'pycnodont',
#  'lgens',
#  'rrlto',
#  'contestaction',
#  'oaties',
#  'terceiras',
#  'juemada',
#  'nutricao',
#  'titvm',
#  'polysucrose',
#  'argé',
#  'hohnran',
#  'bewaarschool',
#  'seleccionar',
#  'impfungen',
#  'argr',
#  'awary',
#  'fleckiger',
#  'pinzgauerhof',
#  'fhysics',
#  'beaneis',
#  'ossello',
#  'творчество',
#  'rkclvice',
#  'wassu',
#  'interfacil',
#  'wassy',
#  'wasse',
#  'thigsten',
#  'jenece',
#  'xmulixita',
#  'artsdalen',
#  'farmleben',
#  'nocturnally',
#  'studiorm',
#  'miracolosi',
#  'apokryfiska',
#  'apokryfiske',
#  'clegrec',
#  'ownded',
#  'propbro',
#  'einsbanclry',
#  'gymnohiloides',
#  'neapolitanarum',
#  'stachowiak',
#  'menacees',
#  'maternités',
#  'chold',
#  'cholc',
#  'dulcy',
#  'cerino',
#  'burssa',
#  'tntlel',
#  'scutelos',
#  'clepartineiltal',
#  'sonnenstaat',
#  'depiected',
#  'afrcom',
#  'korneevna',
#  'ruthelda',
#  'lobesare',
#  'tampin',
#  'ipgo',
#  'sarikamis',
#  'polynecisan',
#  'aiqswers',
#  'руководимая',
#  'cadeucus',
#  'risio',
#  'risii',
#  'chogao',
#  'flandorum',
#  'slaresta',
#  'annexée',
#  'weigllcd',
#  'iloses',
#  'annexés',
#  'repressd',
#  'rhra',
#  'emeine',
#  'grittiness',
#  'idevada',
#  'scenographers',
#  'mbagi',
#  'riatc',
#  'laticolia',
#  'riatt',
#  'rasena',
#  'dallascaridades',
#  'homestads',
#  'preschoolguidance',
#  'notenschrift',
#  'bouleversée',
#  'landolfique',
#  'gedenkworte',
#  'ittldecl',
#  'tawnia',
#  'thefirstvampire',
#  'vurieties',
#  'yamarna',
#  'bioavailalability',
#  'macnavox',
#  'kilu',
#  'kilz',
#  'iaoef',
#  'basamakli',
#  'delegitimized',
#  'pylkkänen',
#  'weerkunde',
#  'verdos',
#  'verdot',
#  'nunouam',
#  'kenh',
#  'zotzinger',
#  'tnkcshly',
#  'iiiatle',
#  'organizacijom',
#  'batswain',
#  'qāhirah',
#  'conceptaculi',
#  'icturts',
#  'nipmuc',
#  'dalynn',
#  'westernport',
#  'lepinard',
#  'tuhaere',
#  'opthalmologic',
#  'biudy',
#  'arlier',
#  'clevelopmeiic',
#  'malignas',
#  'olatecl',
#  'kayitah',
#  'weltraums',
#  'slelryve',
#  'ppvtiii',
#  'hemmorhagic',
#  'frequentium',
#  'musski',
#  'hervorgebracht',
#  'tioncd',
#  'forclosed',
#  'deslacan',
#  'innote',
#  'tijne',
#  'altaris',
#  'otoba',
#  'coherece',
#  'mennicke',
#  'zaigung',
#  'oiitiln',
#  'drose',
#  'chamek',
#  'chamel',
#  'dunia',
#  'eepublioaai',
#  'dunit',
#  'pillyvuyt',
#  'binoculaire',
#  'lusick',
#  'governership',
#  'calcifying',
#  'lanasa',
#  'kaserman',
#  'interpretatus',
#  'chamer',
#  'nlfaisr',
#  'roehrich',
#  'whde',
#  'clcptho',
#  'steeby',
#  'roapa',
#  'sommergäste',
#  'hippoppotomus',
#  'niederhessen',
#  'zille',
#  'cyclometers',
#  'encad',
#  'wollhiser',
#  'klapperthal',
#  'covronnee',
#  'suppléement',
#  'anythink',
#  'grores',
#  'gonzalves',
#  'jpeak',
#  'tltgi',
#  'sektor',
#  'mutilus',
#  'stockfurther',
#  'kastely',
#  'pollister',
#  'kitzbüheler',
#  'casimirlewis',
#  'esperamce',
#  'icefall',
#  'superstructum',
#  'complic',
#  'complin',
#  'stopples',
#  'fähnrich',
#  'nsamindex',
#  'fiebres',
#  'llmrket',
#  'zeule',
#  'appyoved',
#  'supervisoral',
#  'indarra',
#  'oscli',
#  'oscls',
#  'associationin',
#  'jaurez',
#  'крыму',
#  'wasserreservoir',
#  'aeguksim',
#  'ihrough',
#  'ihrougl',
#  'sulbyong',
#  'cayler',
#  'cayles',
#  'dohahoe',
#  'hubaard',
#  'coleous',
#  'abjectification',
#  'armija',
#  'peackeepers',
#  'supplew',
#  'erceptible',
#  'wyschogrod',
#  'suppled',
#  'supplem',
#  'habyarimana',
#  'bofford',
#  'jernignan',
#  'navium',
#  'établissant',
#  'cbnrse',
#  'anamour',
#  'mychariapa',
#  'telecon',
#  'curculis',
#  'nkorangstamm',
#  'gaudate',
#  'berlesc',
#  'kshb',
#  'mementau',
#  'tryke',
#  'judgeharold',
#  'shalle',
#  'robertianifolia',
#  'gebetsvereins',
#  'nigfct',
#  '王金绂',
#  'chalapuramschule',
#  'eklekta',
#  'roxiticus',
#  'delendam',
#  'iirtments',
#  'researchs',
#  'kxpenditures',
#  'tesemini',
#  'pilenihp',
#  'suming',
#  'thyrotroptin',
#  'wrning',
#  'millecm',
#  'chétardie',
#  'greenshield',
#  'tinber',
#  'ritfnon',
#  'mitsoshi',
#  'nanofibrous',
#  'kialo',
#  'kialu',
#  'agaat',
#  'analysttm',
#  'gloxinian',
#  'aperson',
#  'buildingings',
#  'gundle',
#  'covnerse',
#  'coustumier',
#  'blephoroptosis',
#  'huburt',
#  'vallois',
#  'censentur',
#  'salvare',
#  'kulambangra',
#  'hohengarten',
#  'plectomerus',
#  'operationenduring',
#  'bederman',
#  'yessin',
#  'veprek',
#  'rezunov',
#  'trases',
#  'tivbeolt',
#  'immortalizes',
#  'doehne',
#  'juichun',
#  'mlative',
#  'saireduced',
#  'glyposate',
#  'kwangsie',
#  'plumets',
#  'schoit',
#  'recrnt',
#  'mohhinora',
#  'rutzich',
#  'iiiinois',
#  'builtl',
#  'linefesty',
#  'builts',
#  'directorsof',
#  'exercitium',
#  'niederahren',
#  'pasadenans',
#  'nygb',
#  'nygc',
#  'coufal',
#  'palmelu',
#  'geernteten',
#  'manchititla',
#  'jangryoul',
#  'rpolizeilichen',
#  'contractecl',
#  'kohlschütter',
#  'filipone',
#  'пятидесятнического',
#  'furtraders',
#  'toeft',
#  'sprilrg',
#  'езд',
#  'rrrubber',
#  'clamores',
#  'harakhti',
#  'wikilib',
#  'estramadura',
#  'hershaft',
#  'coadministered',
#  'gautieres',
#  'ramkrishnan',
#  'mirolabrichthys',
#  'iiilt',
#  'iiily',
#  'cheiuiclal',
#  'iiilc',
#  'iiild',
#  'uisll',
#  'iiilk',
#  'nasii',
#  'southcoastal',
#  'shallengerger',
#  'refired',
#  'carapebus',
#  'calamajue',
#  'russiantelegraph',
#  'sculpptured',
#  'gesichtserscheinungen',
#  'effecuate',
#  'buike',
#  'volmaektheyd',
#  'guncrew',
#  'ния',
#  'executtion',
#  'mirowski',
#  'redicules',
#  'uréthrotomie',
#  'dalicandro',
#  'nizovaia',
#  'upplementary',
#  'ние',
#  'conrpnre',
#  'sinodis',
#  'dccluntt',
#  'nochitongo',
#  'beillicellnlosic',
#  'chlorure',
#  'sercice',
#  'shumajin',
#  'tnrlwy',
#  'unisolable',
#  'meteorologisohe',
#  'ieveioped',
#  'huê',
#  'seeroute',
#  'rhizopodea',
#  'lhotse',
#  'maracayo',
#  'operntion',
#  'sarap',
#  'sarau',
#  'sarak',
#  'sarab',
#  'sarac',
#  'saraf',
#  'waldesruhe',
#  'chaspcl',
#  'maracayú',
#  'iorli',
#  'arrts',
#  'kucharczy',
#  'tonpayiayia',
#  'see___',
#  'wentholt',
#  'droguerie',
#  'esccedinglgr',
#  'dogmatisten',
#  'lindwood',
#  'albouystown',
#  'knotlless',
#  'angelers',
#  'graeve',
#  'okninawa',
#  'impossiblity',
#  'strozzino',
#  'psers',
#  'wcxrcl',
#  'dale____',
#  'lluht',
#  'ofbcial',
#  'volel',
#  'titsloff',
#  'humoralibus',
#  'slioni',
#  'slionr',
#  'sliont',
#  'voleè',
#  'hwjse',
#  'moschner',
#  'socash',
#  'gesichtsempfindungen',
#  'vintas',
#  'haberstroh',
#  'fortsate',
#  'mcangus',
#  'goltere',
#  'merribel',
#  'waterbull',
#  'felsbarre',
#  'emmannel',
#  'gosaku',
#  'madeford',
#  'inconfidencia',
#  'divionensi',
#  'hochgeachtet',
#  'agematched',
#  'linetlt',
#  'panowicz',
#  'своеобразие',
#  'imroed',
#  'sociológica',
#  'siteki',
#  'diaḋaċta',
#  'bibbsville',
#  'mevrtre',
#  'erinnere',
#  'yurie',
#  'pervaporation',
#  'sublabiatum',
#  'jlas',
#  'jlal',
#  'jlaa',
#  'gimferlin',
#  'ettors',
#  'guillemand',
#  'servibe',
#  'radza',
#  'krulewitch',
#  'administrationis',
#  'profundam',
#  'creobel',
#  'srlbnnlso',
#  'waterbuffalo',
#  'nmntudls',
#  'bagatell',
#  'onccntrates',
#  'ordnnce',
#  'socoroco',
#  'veolocity',
#  'epeda',
#  'epedn',
#  'coaclusion',
#  'venduhuis',
#  'relevements',
#  'obselescence',
#  'leubbert',
#  'allassent',
#  'kandinksy',
#  'odontophorus',
#  'umuguzi',
#  'распубликовано',
#  'sublevels',
#  'jianxi',
#  'exaliorum',
#  'laymah',
#  'frauenmissions',
#  'lugdiens',
#  'epithe',
#  'impurityconcentration',
#  'chhnang',
#  'kleinbesitzes',
#  'operand',
#  'mousai',
#  'shalwala',
#  'mountes',
#  'gasner',
#  'gasnes',
#  'tyewritten',
#  'høvding',
#  'spitaldiener',
#  'loush',
#  'dtiprep',
#  'isensc',
#  'powerstation',
#  'melholms',
#  'numerato',
#  'erineo',
#  'fleuronnés',
#  'duré',
#  'logli',
#  'zheltyi',
#  'xkoup',
#  'benen',
#  'преподавателей',
#  'lamborimitropoulos',
#  'matthavlt',
#  'stallclard',
#  'durt',
#  'durh',
#  'durl',
#  'alardge',
#  'aromate',
#  'aromati',
#  'hampfler',
#  'oxop',
#  'dorsifelxion',
#  'toméré',
#  'asegurados',
#  'edenbvrgum',
#  'impulsiver',
#  'impulsives',
#  'bellfontaine',
#  'excellorst',
#  'icran',
#  'chomono',
#  'convertirse',
#  'llote',
#  'meata',
#  'alqeil',
#  'multicycle',
#  'implementof',
#  'medjz',
#  'cimarroncita',
#  'thermographen',
#  'implementor',
#  'parjanssen',
#  'tjrlc',
#  'polygonius',
#  'aepli',
#  'insuiscient',
#  'lehtimaja',
#  'iviechanical',
#  'shutdoml',
#  'mopsuhestenus',
#  'latitiaes',
#  'nominandosi',
#  'satisfaotnr',
#  'arabermischling',
#  'perniciosi',
#  'samoline',
#  'yrtfl',
#  'уволен',
#  'trempleau',
#  'heteroarylpurines',
#  'everyway',
#  'ensberg',
#  'nellts',
#  'nellti',
#  'nelltf',
#  'asiliden',
#  'llllili',
#  'seminaires',
#  'crickenbergerfrankm',
#  'consideración',
#  'clisting',
#  'lauraas',
#  'blanceado',
#  'keyzerlyke',
#  'buchhandliung',
#  'dailgberg',
#  'hgricul',
#  'cotenese',
#  'bissher',
#  'mvision',
#  'swellen',
#  'beweinent',
#  'alttertiäre',
#  'therabada',
#  'hosptialman',
#  'solubiljt',
#  'slavetrade',
#  'mayned',
#  'billikin',
#  'carretoneros',
#  'mayney',
#  'elevaazione',
#  'abusrour',
#  'vigasságok',
#  'humko',
#  'goosbey',
#  'butlyramide',
#  'lightenstone',
#  'andalusiens',
#  'marylandmaryland',
#  'oaxoca',
#  'flatanger',
#  'harzegerode',
#  'cutantés',
#  'dalmarie',
#  'pnllrttl',
#  'kudel',
#  'cuandinosa',
#  'rozic',
#  'curviceps',
#  'methylsiloxane',
#  'drsert',
#  'suscites',
#  'bajgah',
#  'vaigach',
#  'partialcolectomyforcarcinomaoftherectum',
#  'cmrr',
#  'chieken',
#  'mohéli',
#  'ianskie',
#  'incipitheadpiecetitlepiecetailpiece',
#  'berolhistory',
#  'glaucarubin',
#  'buckhhorn',
#  'rubberneck',
#  'davidaho',
#  'actory',
#  'actore',
#  'faehre',
#  'fishcer',
#  'netcong',
#  'gebtry',
#  'psychiatri',
#  'sautordu',
#  'hohert',
#  'raagle',
#  'signtures',
#  'imprnts',
#  'camaldulensium',
#  'luxenbourger',
#  'ascg',
#  'intervieweerosie',
#  'lrncll',
#  'dascomb',
#  'nuline',
#  'douloureuse',
#  'crclas',
#  'fellhorns',
#  'aaxias',
#  'летящие',
#  'gyamena',
#  'procreations',
#  'bcbesisx',
#  'активных',
#  'polskick',
#  'ncvnd',
#  'minsiterial',
#  'comletos',
#  'watis',
#  'belirlemekti',
#  'berie',
#  'beriz',
#  'clcrunncl',
#  'активные',
#  'mealth',
#  'cpscourses',
#  'varjdno',
#  'mmuucchhnneeeeddeedd',
#  'fusains',
#  'jeffbies',
#  'ferienfreuden',
#  'chirichi',
#  'dschaggafrauen',
#  'nanoassembly',
#  'yubilei',
#  'ilicluding',
#  'honghai',
#  'piggies',
#  'halithorpe',
#  'arange',
#  'settaimpe',
#  'couronnemens',
#  'jutlo',
#  'serdtsa',
#  'geosophy',
#  'tjiledoeg',
#  'stergion',
#  'политотдел',
#  'subdelegaciones',
#  'tamoyidae',
#  'journean',
#  'paripanopeus',
#  'compnrisons',
#  'mcginlay',
#  'firefli',
#  'sectiolls',
#  'legionaries',
#  'depurative',
#  'pleasantburg',
#  'bronven',
#  'overlyden',
#  'obscener',
#  'neurypnology',
#  'urenkeln',
#  'pediocetes',
#  'jmrd',
#  'vertravensminner',
#  'postkartenaufdruck',
#  'vaitotai',
#  'psycholo',
#  'finf',
#  'finy',
#  'cöthen',
#  'fint',
#  'finr',
#  'finp',
#  'imprimenda',
#  'loacher',
#  'imprimendi',
#  'elltiye',
#  'repaids',
#  'umsausgabe',
#  'adjuvantibus',
#  'lahmeyer',
#  'zijlla',
#  'jahrestag',
#  'erigena',
#  'verordnet',
#  'munfsch',
#  'golze',
#  'goodliff',
#  'goodlife',
#  'tempelfotos',
#  'administrationbuilt',
#  'sajors',
#  'mirhan',
#  'kukhne',
#  'fencote',
#  'superest',
#  'horányi',
#  'fallcii',
#  'sothos',
#  'hullr',
#  'baruda',
#  'ferrokh',
#  'bewoonderen',
#  'mconsultant',
#  'steinolfson',
#  'marmorei',
#  'mbinzi',
#  'izrr',
#  'marmored',
#  'duelkes',
#  'izrl',
#  'drevotella',
#  'alumninum',
#  'renegado',
#  'illusl',
#  'cherise',
#  'larlr',
#  'morisani',
#  'larlj',
#  'deblon',
#  'bisceglia',
#  'vdsh',
#  'ivetls',
#  'bündigen',
#  'ilkt',
#  'merrilltown',
#  'staydinger',
#  'ilkl',
#  'ilke',
#  'hearingsappunit',
#  'wbi',
#  'mandarahan',
#  'wbx',
#  'rsmg',
#  'amateurishly',
#  'pallcreas',
#  'riptio',
#  'dimenticare',
#  'clodissa',
#  'hlannge',
#  'sepro',
#  'donnavon',
#  'kafferdoktor',
#  'mokching',
#  'muslic',
#  'herrimger',
#  'leafshapes',
#  'fionán',
#  'detric',
#  'bailish',
#  'exartikulationen',
#  'libeling',
#  'establecieron',
#  'onitid',
#  'toloja',
#  'yacuiba',
#  'ugetieren',
#  'achacoso',
#  'wzrostu',
#  'argn',
#  'torsio',
#  'chromodorid',
#  'hoivik',
#  'aaalyzed',
#  'backscatterance',
#  'ralftl',
#  'weltbekannter',
#  'britischer',
#  'katabubuts',
#  'eingeklebtem',
#  'koempel',
#  'coulours',
#  'ncilso',
#  'mentionerl',
#  'aeces',
#  'baleinoptères',
#  'suborclinatecl',
#  'wiliwilinui',
#  'awar_',
#  'hellgelben',
#  'ollitas',
#  'uger',
#  'euprines',
#  'ugel',
#  'wiedergaben',
#  'errorism',
#  'airies',
#  'axisymmertrical',
#  'agotvti',
#  'roytaugfjellet',
#  'antapologia',
#  'páses',
#  'presedimentation',
#  'duokui',
#  'duokun',
#  'teteruck',
#  'prerecruit',
#  'verfalle',
#  'verfalls',
#  'nechstfolgenden',
#  'demonvmq',
#  'piastrini',
#  'carigny',
#  'nvovam',
#  'hispaniolan',
#  'ilclition',
#  'ubahghi',
#  'uindicati',
#  'vorbarbeiten',
#  'reglaient',
#  ...]

# %%
globalhaps = {}

for coll in colls:
    globalhaps[coll] = []
    for hap in fds[coll].hapaxes():
        if hap in texthaps:
            globalhaps[coll].append(hap)
    print(coll)
    print(str(len(globalhaps[coll])))
# Out:
# biodiv
# 12213
# rumsey
# 3516
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-142473e0097f> in <module>()
#       4     globalhaps[coll] = []
#       5     for hap in fds[coll].hapaxes():
# ----> 6         if hap in texthaps:
#       7             globalhaps[coll].append(hap)
#       8     print(coll)
#
# KeyboardInterrupt:
